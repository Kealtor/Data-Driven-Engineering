# %%
import numpy as np
import pandas as pd
from datetime import date
import plotly.express as px
import plotly.graph_objects as go
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing as pp
import matplotlib as mpl
from sklearn.decomposition import PCA
from pandas.plotting import lag_plot, autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
import statsmodels.api as smw
from datetime import timedelta
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.svm import SVR
from sklearn.metrics import r2_score
import tensorflow as tf
from tensorflow import keras
from keras import optimizers, models, layers, regularizers
tf.__version__
from utils.dde_preprocessing_utils import (set_timestamp_index,
remove_duplicates,
remove_columns,
extract_correlations,
prepare_data_sarimax,
create_test_train_split,
create_sarimax_test_train_split,
create_eval_df,
convert_to_sample_time_feature)
from utils.dde_plotting_utils import(
display_double_timestamps,
display_seasonal_decomposition,
plot_predictions,
plot_accuracy,
plot_error_variations,
plot_learning_curves,
)
# %load_ext skip_kernel_extension

# %%
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
mpl.rcParams['figure.figsize'] = [8.0, 8.0]

# %%
SKIP_RETRAIN_NN =True
SKIP_RETRAIN_RNN = True
SKIP_RETRAIN_LSTM = False
SKIP_RETRAIN_ED_LSTM = True

# %% [markdown]
# ## Loading Data

# %%
combined_df = pd.read_csv("preprocessed_data.csv")
combined_df = set_timestamp_index(combined_df,"Unnamed: 0")

# %%
combined_df
# Out:
#                              temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 01:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 02:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 03:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 04:00:00+01:00  -3.464    1002.0        78         0.0        23
# ...                           ...       ...       ...         ...       ...
# 2018-12-31 19:00:00+01:00  12.490    1028.0        62         2.0       140
# 2018-12-31 20:00:00+01:00   9.990    1029.0        71         1.0       242
# 2018-12-31 21:00:00+01:00   8.510    1029.0        81         3.0       300
# 2018-12-31 22:00:00+01:00   6.990    1029.0        81         2.0       310
# 2018-12-31 23:00:00+01:00   5.990    1029.0        75         2.0       300
#
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               447.0
# 2015-01-01 01:00:00+01:00               449.0
# 2015-01-01 02:00:00+01:00               448.0
# 2015-01-01 03:00:00+01:00               438.0
# 2015-01-01 04:00:00+01:00               428.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               297.0
# 2018-12-31 20:00:00+01:00               296.0
# 2018-12-31 21:00:00+01:00               292.0
# 2018-12-31 22:00:00+01:00               293.0
# 2018-12-31 23:00:00+01:00               290.0
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 329.0
# 2015-01-01 01:00:00+01:00                                 328.0
# 2015-01-01 02:00:00+01:00                                 323.0
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 01:00:00+01:00             3436.0      1    1        0
# 2015-01-01 02:00:00+01:00             4062.0      1    1        0
# 2015-01-01 03:00:00+01:00             3937.0      1    1        0
# 2015-01-01 04:00:00+01:00             4356.0      1    1        0
# ...                                      ...    ...  ...      ...
# 2018-12-31 19:00:00+01:00            -4238.0     12   31        0
# 2018-12-31 20:00:00+01:00            -4522.0     12   31        0
# 2018-12-31 21:00:00+01:00            -4084.0     12   31        0
# 2018-12-31 22:00:00+01:00            -3053.0     12   31        0
# 2018-12-31 23:00:00+01:00            -1850.0     12   31        0
#
# [35064 rows x 26 columns]

# %% [markdown]
# # LSTM

# %% [markdown]
# ## Single Step LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = combined_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.StandardScaler(copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
train_start = '2015-01-01'
validation_start = '2017-01-01'
test_start = '2017-03-01'
test_end = '2017-03-06'
feature = 'total load actual'
namespace = 'LSTM'
modeltype = 'LSTM'
feature_df = combined_df[[feature]]
data_x_train0,data_x_val0,data_x_test0,data_y_train0,data_y_val0,data_y_test0 = create_test_train_split(scaled_df,feature_df,train_start,test_start,test_end,validation_start=validation_start)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,24,1,32)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,24,1,32)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,24,1,32)

# %%
print(data_x_train.shape,data_y_train.shape)
print(data_x_val.shape,data_y_val.shape)
print(data_x_test.shape,data_y_test.shape)
# Out:
# (17510, 24, 26) (17510, 1)
# (1382, 24, 26) (1382, 1)
# (70, 24, 26) (70, 1)

# %% [markdown]
# Define LSTM Model

# %%
def build_model_LSTM(data_x_train,data_y_train):
    n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
    model = models.Sequential([
    layers.LSTM(32, return_sequences=True,input_shape=(None, n_features), stateful=False), 
    layers.BatchNormalization(),
    layers.LSTM(32, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(32, stateful=False),
    layers.BatchNormalization(),
    layers.Dense(n_outputs)                     
    ])
    model.compile(optimizer='Adam',loss='mse',metrics='mae') 
    return model

# %% [markdown]
# Definening callback functions

# %%
myCheckpointLSTM= keras.callbacks.ModelCheckpoint(f"./{modeltype}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingLSTM = keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)

# %% [markdown]
# Hypterparameters

# %%
num_epochs = 150
batch_size = 32

# %% [markdown]
# Training the model

# %%
# %%skip $SKIP_RETRAIN_LSTM
#
# model_LSTM = build_model_LSTM(data_x_train,data_y_train)
# history_LSTM = model_LSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) ,
#                                  callbacks=[myCheckpointLSTM,myEarly_stoppingLSTM])#, verbose=0)
# Out:
# Epoch 1/150
# 548/548 [==============================] - 10s 11ms/step - loss: 828805376.0000 - mae: 28432.4922 - val_loss: 905604736.0000 - val_mae: 29682.7559
# Epoch 2/150
# 548/548 [==============================] - 6s 10ms/step - loss: 825397696.0000 - mae: 28384.7207 - val_loss: 898402880.0000 - val_mae: 29579.7012
# Epoch 3/150
# 548/548 [==============================] - 6s 10ms/step - loss: 819384128.0000 - mae: 28296.0117 - val_loss: 887870528.0000 - val_mae: 29426.8164
# Epoch 4/150
# 548/548 [==============================] - 6s 10ms/step - loss: 811167232.0000 - mae: 28172.1113 - val_loss: 874174208.0000 - val_mae: 29222.2871
# Epoch 5/150
# 548/548 [==============================] - 6s 10ms/step - loss: 801115968.0000 - mae: 28017.9336 - val_loss: 863985152.0000 - val_mae: 29078.5840
# Epoch 6/150
# 548/548 [==============================] - 6s 10ms/step - loss: 789463936.0000 - mae: 27836.5156 - val_loss: 847329088.0000 - val_mae: 28825.6738
# Epoch 7/150
# 548/548 [==============================] - 5s 10ms/step - loss: 776448512.0000 - mae: 27630.1172 - val_loss: 828484992.0000 - val_mae: 28527.0586
# Epoch 8/150
# 548/548 [==============================] - 5s 10ms/step - loss: 762200576.0000 - mae: 27400.6191 - val_loss: 807329920.0000 - val_mae: 28192.5508
# Epoch 9/150
# 548/548 [==============================] - 5s 10ms/step - loss: 746897152.0000 - mae: 27149.1562 - val_loss: 787667200.0000 - val_mae: 27876.1875
# Epoch 10/150
# 548/548 [==============================] - 6s 11ms/step - loss: 730632128.0000 - mae: 26876.4258 - val_loss: 766345856.0000 - val_mae: 27528.1426
# Epoch 11/150
# 548/548 [==============================] - 6s 10ms/step - loss: 713438144.0000 - mae: 26583.1387 - val_loss: 744770368.0000 - val_mae: 27153.0801
# Epoch 12/150
# 548/548 [==============================] - 5s 10ms/step - loss: 695534272.0000 - mae: 26270.0723 - val_loss: 724228480.0000 - val_mae: 26802.1133
# Epoch 13/150
# 548/548 [==============================] - 5s 10ms/step - loss: 676900224.0000 - mae: 25936.6309 - val_loss: 692815360.0000 - val_mae: 26246.1855
# Epoch 14/150
# 548/548 [==============================] - 5s 10ms/step - loss: 657719808.0000 - mae: 25584.3828 - val_loss: 678485888.0000 - val_mae: 25986.0371
# Epoch 15/150
# 548/548 [==============================] - 6s 10ms/step - loss: 637969792.0000 - mae: 25212.6504 - val_loss: 646673920.0000 - val_mae: 25392.2520
# Epoch 16/150
# 548/548 [==============================] - 6s 10ms/step - loss: 617795840.0000 - mae: 24821.9746 - val_loss: 618932160.0000 - val_mae: 24849.7461
# Epoch 17/150
# 548/548 [==============================] - 6s 10ms/step - loss: 597364672.0000 - mae: 24413.0508 - val_loss: 605289920.0000 - val_mae: 24580.5352
# Epoch 18/150
# 548/548 [==============================] - 6s 10ms/step - loss: 576368768.0000 - mae: 23985.0234 - val_loss: 569929664.0000 - val_mae: 23857.7266
# Epoch 19/150
# 548/548 [==============================] - 5s 10ms/step - loss: 555050368.0000 - mae: 23538.6836 - val_loss: 545207424.0000 - val_mae: 23333.9805
# Epoch 20/150
# 548/548 [==============================] - 5s 10ms/step - loss: 533271872.0000 - mae: 23073.0938 - val_loss: 529755552.0000 - val_mae: 22999.0449
# Epoch 21/150
# 548/548 [==============================] - 5s 10ms/step - loss: 511138208.0000 - mae: 22587.6016 - val_loss: 502064896.0000 - val_mae: 22388.0684
# Epoch 22/150
# 548/548 [==============================] - 5s 10ms/step - loss: 488580576.0000 - mae: 22083.0020 - val_loss: 484279840.0000 - val_mae: 21987.4805
# Epoch 23/150
# 548/548 [==============================] - 5s 10ms/step - loss: 465735936.0000 - mae: 21560.7715 - val_loss: 455267488.0000 - val_mae: 21318.7676
# Epoch 24/150
# 548/548 [==============================] - 6s 10ms/step - loss: 442721312.0000 - mae: 21020.2344 - val_loss: 438133632.0000 - val_mae: 20909.0957
# Epoch 25/150
# 548/548 [==============================] - 6s 10ms/step - loss: 419592608.0000 - mae: 20462.7461 - val_loss: 411280128.0000 - val_mae: 20258.8184
# Epoch 26/150
# 548/548 [==============================] - 6s 10ms/step - loss: 396370464.0000 - mae: 19887.4980 - val_loss: 388304320.0000 - val_mae: 19684.3379
# Epoch 27/150
# 548/548 [==============================] - 5s 10ms/step - loss: 373134496.0000 - mae: 19296.1797 - val_loss: 370557920.0000 - val_mae: 19224.8203
# Epoch 28/150
# 548/548 [==============================] - 5s 10ms/step - loss: 350020768.0000 - mae: 18687.4629 - val_loss: 343699360.0000 - val_mae: 18517.2656
# Epoch 29/150
# 548/548 [==============================] - 5s 10ms/step - loss: 327099488.0000 - mae: 18063.2695 - val_loss: 322220800.0000 - val_mae: 17925.6426
# Epoch 30/150
# 548/548 [==============================] - 6s 10ms/step - loss: 304467264.0000 - mae: 17423.5977 - val_loss: 300248032.0000 - val_mae: 17307.7129
# Epoch 31/150
# 548/548 [==============================] - 5s 10ms/step - loss: 281974528.0000 - mae: 16767.4668 - val_loss: 274356480.0000 - val_mae: 16537.3770
# Epoch 32/150
# 548/548 [==============================] - 5s 10ms/step - loss: 259967024.0000 - mae: 16097.5166 - val_loss: 253098464.0000 - val_mae: 15882.0205
# Epoch 33/150
# 548/548 [==============================] - 5s 10ms/step - loss: 238339200.0000 - mae: 15412.7822 - val_loss: 231607520.0000 - val_mae: 15189.7637
# Epoch 34/150
# 548/548 [==============================] - 5s 10ms/step - loss: 217283968.0000 - mae: 14714.3975 - val_loss: 213851680.0000 - val_mae: 14589.5322
# Epoch 35/150
# 548/548 [==============================] - 6s 10ms/step - loss: 196853040.0000 - mae: 14002.4746 - val_loss: 192892096.0000 - val_mae: 13861.5371
# Epoch 36/150
# 548/548 [==============================] - 5s 10ms/step - loss: 177133616.0000 - mae: 13278.3311 - val_loss: 172787568.0000 - val_mae: 13111.9736
# Epoch 37/150
# 548/548 [==============================] - 6s 10ms/step - loss: 158194496.0000 - mae: 12542.5010 - val_loss: 157286144.0000 - val_mae: 12510.9004
# Epoch 38/150
# 548/548 [==============================] - 5s 10ms/step - loss: 139933328.0000 - mae: 11796.1133 - val_loss: 135015792.0000 - val_mae: 11582.6602
# Epoch 39/150
# Epoch 59/150
# 548/548 [==============================] - 5s 10ms/step - loss: 744725.5000 - mae: 683.5043 - val_loss: 732330.4375 - val_mae: 519.5250
# Epoch 60/150
# 548/548 [==============================] - 5s 10ms/step - loss: 804967.1250 - mae: 713.8167 - val_loss: 789171.5625 - val_mae: 548.1594
# Epoch 61/150
# 548/548 [==============================] - 5s 10ms/step - loss: 731048.6875 - mae: 680.7762 - val_loss: 709932.6875 - val_mae: 511.9941
# Epoch 62/150
# 548/548 [==============================] - 5s 10ms/step - loss: 680994.0625 - mae: 658.7794 - val_loss: 699304.1875 - val_mae: 515.2155
# Epoch 63/150
# 548/548 [==============================] - 5s 10ms/step - loss: 704138.8750 - mae: 664.8127 - val_loss: 719120.5625 - val_mae: 524.5906
# Epoch 64/150
# 548/548 [==============================] - 5s 10ms/step - loss: 764853.8750 - mae: 689.0560 - val_loss: 772141.4375 - val_mae: 533.3147
# Epoch 65/150
# 548/548 [==============================] - 6s 10ms/step - loss: 761945.5625 - mae: 688.9023 - val_loss: 922246.6875 - val_mae: 573.5796
# Epoch 66/150
# 548/548 [==============================] - 5s 10ms/step - loss: 700260.0000 - mae: 653.7258 - val_loss: 706118.3125 - val_mae: 531.3630
# Epoch 67/150
# 548/548 [==============================] - 5s 10ms/step - loss: 708840.9375 - mae: 668.9189 - val_loss: 714424.0625 - val_mae: 523.4383
# Epoch 68/150
# 548/548 [==============================] - 5s 10ms/step - loss: 746221.0625 - mae: 686.3210 - val_loss: 826214.6875 - val_mae: 545.9018

# %% [markdown]
# Evaluate the training process

# %%
# %%skip $SKIP_RETRAIN_LSTM
#
# histLSTM = pd.DataFrame(history_LSTM.history)
# histLSTM['epoch'] = history_LSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_LSTM
#
# fig = plot_learning_curves(histLSTM,modeltype,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# Load best model

# %%
model_best_LSTM = keras.models.load_model(f"./{modeltype}/my_best_model_{namespace}.h5")
model_best_LSTM.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 32)          7552
# _________________________________________________________________
# batch_normalization_7 (Batch (None, None, 32)          128
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 32)          8320
# _________________________________________________________________
# batch_normalization_8 (Batch (None, None, 32)          128
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32)                128
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 24,609
# Trainable params: 24,417
# Non-trainable params: 192
# _________________________________________________________________

# %%
Y_test_predictions = pd.Series(model_best_LSTM.predict(data_x_test).flatten(),index=y_test_filtered.index)
y_test_filtered = data_y_test0.loc[idx_test]
y_test_filtered =y_test_filtered.squeeze(axis=1)

# %%
eval_df = create_eval_df(Y_test_predictions,y_test_filtered)

# %%
fig = plot_accuracy(eval_df,modeltype,f"./{modeltype}/accuracy_{namespace}.png")

# %%
fig = plot_error_variations(eval_df,modeltype,f"./{modeltype}/error_variations_{namespace}.png")

# %%
abs_error_LSTM = abs(Y_test_predictions - y_test_filtered)/y_test_filtered*100
np.average(abs_error_LSTM)
# Out:
# 1.1866846879292747

# %%
r2_test = r2_score(y_test_filtered, Y_test_predictions)
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.98

# %%
fig = plot_predictions(eval_df,1,modeltype,feature,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# ## Mulitstep LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = combined_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.StandardScaler(copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
scaled_df
# Out:
#                                temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+01:00 -2.807250 -1.254819  0.605043   -0.724273 -0.820537
# 2015-01-01 01:00:00+01:00 -2.807250 -1.254819  0.605043   -0.724273 -0.820537
# 2015-01-01 02:00:00+01:00 -2.916311 -1.171050  0.655861   -1.161697 -1.144428
# 2015-01-01 03:00:00+01:00 -2.916311 -1.171050  0.655861   -1.161697 -1.144428
# 2015-01-01 04:00:00+01:00 -2.916311 -1.171050  0.655861   -1.161697 -1.144428
# ...                             ...       ...       ...         ...       ...
# 2018-12-31 19:00:00+01:00 -0.711034  1.006965 -0.157230   -0.286850 -0.172756
# 2018-12-31 20:00:00+01:00 -1.056602  1.090734  0.300134   -0.724273  0.674344
# 2018-12-31 21:00:00+01:00 -1.261179  1.090734  0.808315    0.150573  1.156028
# 2018-12-31 22:00:00+01:00 -1.471284  1.090734  0.808315   -0.286850  1.239077
# 2018-12-31 23:00:00+01:00 -1.609511  1.090734  0.503406   -0.286850  1.156028
#
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00            0.743671
# 2015-01-01 01:00:00+01:00            0.767106
# 2015-01-01 02:00:00+01:00            0.755388
# 2015-01-01 03:00:00+01:00            0.638217
# 2015-01-01 04:00:00+01:00            0.521046
# ...                                       ...
# 2018-12-31 19:00:00+01:00           -1.013900
# 2018-12-31 20:00:00+01:00           -1.025617
# 2018-12-31 21:00:00+01:00           -1.072486
# 2018-12-31 22:00:00+01:00           -1.060769
# 2018-12-31 23:00:00+01:00           -1.095920
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                             -0.335844
# 2015-01-01 01:00:00+01:00                             -0.338664
# 2015-01-01 02:00:00+01:00                             -0.352763
# 2015-01-01 03:00:00+01:00                             -0.547342
# 2015-01-01 04:00:00+01:00                             -0.736280
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                             -1.263615
# 2018-12-31 20:00:00+01:00                             -1.263615
# 2018-12-31 21:00:00+01:00                             -1.263615
# 2018-12-31 22:00:00+01:00                             -1.263615
# 2018-12-31 23:00:00+01:00                             -1.263615
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00              -0.353717                     0.287706
# 2015-01-01 01:00:00+01:00              -0.193824                     0.254067
# 2015-01-01 02:00:00+01:00              -0.347812                     0.165380
# 2015-01-01 03:00:00+01:00              -0.594464                    -0.063983
# 2015-01-01 04:00:00+01:00              -0.678044                    -0.212304
# 2018-12-31 20:00:00+01:00          -1.728560  1.587925  1.735195 -0.633062
# 2018-12-31 21:00:00+01:00          -1.558911  1.587925  1.735195 -0.633062
# 2018-12-31 22:00:00+01:00          -1.159578  1.587925  1.735195 -0.633062
# 2018-12-31 23:00:00+01:00          -0.693624  1.587925  1.735195 -0.633062
#
# [35064 rows x 26 columns]

# %%
train_start = '2015-01-01'
validation_start = '2017-01-01'
test_start = '2017-03-01'
test_end = '2017-03-14'
feature = 'total load actual'
model_type = 'LSTM'
namespace = 'MS_LSTM_LOAD'
feature_df = combined_df[[feature]]
data_x_train0,data_x_val0,data_x_test0,data_y_train0,data_y_val0,data_y_test0 = create_test_train_split(scaled_df,feature_df,train_start,test_start,test_end,validation_start=validation_start)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,72,24,32)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,72,24,32)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,72,24,32)

# %%
print(data_x_train.shape,data_y_train.shape)
print(data_x_val.shape,data_y_val.shape)
print(data_x_test.shape,data_y_test.shape)
# Out:
# (17416, 72, 26) (17416, 24)
# (1288, 72, 26) (1288, 24)
# (168, 72, 26) (168, 24)

# %% [markdown]
# Define LSTM Model

# %%
def build_model_LSTM(data_x_train,data_y_train):
  n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
  model = models.Sequential([
  layers.LSTM(64, return_sequences=True,input_shape=(None, n_features), stateful=False), 
  layers.BatchNormalization(),
  layers.LSTM(64, return_sequences=True, stateful=False),
  layers.BatchNormalization(),
  layers.LSTM(64, return_sequences=True, stateful=False),
  layers.BatchNormalization(),
  layers.LSTM(64, return_sequences=True, stateful=False),
  layers.BatchNormalization(),
  layers.LSTM(64, return_sequences=True, stateful=False),
  layers.BatchNormalization(),
  layers.LSTM(64, stateful=False),
  layers.Dense(64, kernel_regularizer=regularizers.l2(0.0001), kernel_initializer="he_normal"),
  layers.LeakyReLU(alpha=0.1),
  layers.BatchNormalization(),
  layers.Dense(n_outputs),              
  ])
  model.compile(optimizer='Adam',loss='mse',metrics='mae') 
  return model

# %% [markdown]
# Definening callback functions

# %%
myCheckpointMSLSTM= keras.callbacks.ModelCheckpoint(f"./{model_type}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingMSLSTM = keras.callbacks.EarlyStopping(patience=20,restore_best_weights=True)

# %% [markdown]
# Hypterparameters

# %%
num_epochs = 150
batch_size = 32

# %% [markdown]
# Training the model

# %%
# %%skip $SKIP_RETRAIN_LSTM
#
# model_MSLSTM = build_model_LSTM(data_x_train,data_y_train)
# history_MSLSTM = model_MSLSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) ,
#                                  callbacks=[myCheckpointLSTM,myEarly_stoppingLSTM])
# Out:
# Epoch 1/150
# 545/545 [==============================] - 23s 34ms/step - loss: 829088320.0000 - mae: 28435.8887 - val_loss: 903069824.0000 - val_mae: 29629.6895
# Epoch 41/150
# 545/545 [==============================] - 17s 32ms/step - loss: 12631738.0000 - mae: 3027.6880 - val_loss: 19761984.0000 - val_mae: 3772.5042
# Epoch 42/150
# 545/545 [==============================] - 17s 32ms/step - loss: 12077506.0000 - mae: 2942.9819 - val_loss: 19292994.0000 - val_mae: 3715.7539
# Epoch 43/150
# 545/545 [==============================] - 17s 31ms/step - loss: 11343500.0000 - mae: 2839.8850 - val_loss: 18508270.0000 - val_mae: 3649.3765
# Epoch 44/150
# 545/545 [==============================] - 17s 31ms/step - loss: 10617898.0000 - mae: 2736.4644 - val_loss: 17647912.0000 - val_mae: 3555.4651
# Epoch 45/150
# 545/545 [==============================] - 17s 32ms/step - loss: 10008494.0000 - mae: 2647.2268 - val_loss: 16728869.0000 - val_mae: 3473.0710
# Epoch 46/150
# 545/545 [==============================] - 17s 32ms/step - loss: 9197036.0000 - mae: 2529.1399 - val_loss: 15758256.0000 - val_mae: 3354.0676
# Epoch 47/150
# 545/545 [==============================] - 18s 33ms/step - loss: 8470327.0000 - mae: 2422.1401 - val_loss: 15076993.0000 - val_mae: 3270.3613
# Epoch 48/150
# 545/545 [==============================] - 18s 33ms/step - loss: 7813984.0000 - mae: 2322.9253 - val_loss: 14741068.0000 - val_mae: 3206.4688
# Epoch 49/150
# 545/545 [==============================] - 18s 33ms/step - loss: 7296512.0000 - mae: 2239.7366 - val_loss: 16122673.0000 - val_mae: 3313.5933
# Epoch 50/150
# 545/545 [==============================] - 18s 32ms/step - loss: 6702326.0000 - mae: 2149.5920 - val_loss: 14424240.0000 - val_mae: 3132.5986
# Epoch 51/150
# 545/545 [==============================] - 18s 32ms/step - loss: 6138320.5000 - mae: 2058.8267 - val_loss: 14106214.0000 - val_mae: 3081.5906
# Epoch 52/150
# 545/545 [==============================] - 18s 32ms/step - loss: 5795252.0000 - mae: 2000.9177 - val_loss: 13513819.0000 - val_mae: 3025.1301
# Epoch 53/150
# 545/545 [==============================] - 17s 32ms/step - loss: 5492019.5000 - mae: 1949.0273 - val_loss: 13394356.0000 - val_mae: 2983.6958
# Epoch 54/150
# 545/545 [==============================] - 17s 32ms/step - loss: 5236855.5000 - mae: 1902.7368 - val_loss: 13560611.0000 - val_mae: 2998.7910
# Epoch 55/150
# 545/545 [==============================] - 17s 32ms/step - loss: 5014001.5000 - mae: 1860.7534 - val_loss: 13593059.0000 - val_mae: 2996.9329
# Epoch 56/150
# 545/545 [==============================] - 17s 32ms/step - loss: 4878905.0000 - mae: 1833.8809 - val_loss: 13038145.0000 - val_mae: 2921.5864
# Epoch 57/150
# 545/545 [==============================] - 17s 32ms/step - loss: 4792510.0000 - mae: 1815.1229 - val_loss: 14986269.0000 - val_mae: 3074.4026
# Epoch 58/150
# 545/545 [==============================] - 18s 32ms/step - loss: 4742095.0000 - mae: 1801.7841 - val_loss: 13964954.0000 - val_mae: 2984.2383
# Epoch 59/150
# 545/545 [==============================] - 18s 33ms/step - loss: 4692559.5000 - mae: 1789.8345 - val_loss: 14155595.0000 - val_mae: 3011.6179
# Epoch 60/150
# Epoch 80/150
# 545/545 [==============================] - 24s 45ms/step - loss: 1370855.2500 - mae: 918.5183 - val_loss: 11667962.0000 - val_mae: 2593.2581
# Epoch 81/150
# 545/545 [==============================] - 24s 44ms/step - loss: 1333470.1250 - mae: 907.3946 - val_loss: 12652165.0000 - val_mae: 2669.9465
# Epoch 82/150
# 545/545 [==============================] - 26s 48ms/step - loss: 1321858.0000 - mae: 904.9479 - val_loss: 11641654.0000 - val_mae: 2548.6392
# Epoch 83/150
# 545/545 [==============================] - 26s 47ms/step - loss: 1282466.8750 - mae: 891.0112 - val_loss: 12437900.0000 - val_mae: 2645.7722
# Epoch 84/150
# 545/545 [==============================] - 26s 47ms/step - loss: 1276572.7500 - mae: 887.9828 - val_loss: 11809061.0000 - val_mae: 2585.4055
# Epoch 85/150
# 545/545 [==============================] - 24s 44ms/step - loss: 1311416.0000 - mae: 899.5089 - val_loss: 11100900.0000 - val_mae: 2501.7651
# Epoch 86/150
# 545/545 [==============================] - 25s 46ms/step - loss: 1259881.5000 - mae: 885.4099 - val_loss: 11451984.0000 - val_mae: 2546.5007
# Epoch 87/150
# 545/545 [==============================] - 26s 47ms/step - loss: 1215322.3750 - mae: 868.7797 - val_loss: 11317383.0000 - val_mae: 2515.3867
# Epoch 88/150
# 545/545 [==============================] - 25s 47ms/step - loss: 1198552.0000 - mae: 862.9875 - val_loss: 11691257.0000 - val_mae: 2565.4575

# %% [markdown]
# Evaluate the training process

# %%
# %%skip $SKIP_RETRAIN_LSTM
#
# histMSLSTM = pd.DataFrame(history_MSLSTM.history)
# histMSLSTM['epoch'] = history_MSLSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_LSTM
#
# fig = plot_learning_curves(histMSLSTM,model_type,f'./{model_type}/learningcurve_{namespace}.png')
# fig.show()
# Out:
# <string>:3: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# Load best model

# %%
model_best_MS_LSTM = keras.models.load_model(f"./{model_type}/my_best_model_{namespace}.h5")
model_best_MS_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 64)          23296
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 64)          256
# _________________________________________________________________
# dropout (Dropout)            (None, None, 64)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64)          256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 64)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 64)          256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 64)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# batch_normalization_3 (Batch (None, None, 64)          256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, 64)          0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# batch_normalization_4 (Batch (None, None, 64)          256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, None, 64)          0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                1560
# =================================================================
# Total params: 195,672
# Trainable params: 194,904
# Non-trainable params: 768
# _________________________________________________________________

# %%
i=1
case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))

Y_test_predictions = pd.Series(model_best_MS_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
y_test_filtered = data_y_test0.loc[Y_test_predictions.index]

# %%
eval_df = create_eval_df(Y_test_predictions,y_test_filtered)

# %%
fig = plot_accuracy(eval_df,model_type,f"./{model_type}/accuracy_{namespace}.png")
fig.show()
# Out:
# <ipython-input-158-f128fcf0dccf>:2: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
fig = plot_error_variations(eval_df,model_type,f"./{model_type}/error_variations_{namespace}.png")
fig.show()
# Out:
# <ipython-input-159-05c98d64636b>:2: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
abs_error_MSLSTM = abs(Y_test_predictions - y_test_filtered)/y_test_filtered*100
np.average(abs_error_MSLSTM)
# Out:
# nan

# %%
r2_test = r2_score(y_test_filtered, Y_test_predictions)
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.79

# %%
fig = plot_predictions(eval_df,1,model_type,feature,f"./{model_type}/predictions_{namespace}")
fig.show()
# Out:
# <ipython-input-162-c54bd844a7ce>:2: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
idx_prediction = pd.date_range(start=idx_test[0],freq='h',periods=len(idx_test)+24)
y_test_filtered2 = data_y_test0.loc[idx_prediction]

# %%
fig = go.Figure()
df_pred =pd.DataFrame(index=y_test_filtered2.index)
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=y_test_filtered2[feature]))
for i in range(len(data_x_test)):
    case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
    Y_test_predictions = pd.Series(model_best_MS_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
    df_pred[f'pred_{i}'] = Y_test_predictions
    fig.add_trace(go.Scatter(x = Y_test_predictions.index,y=Y_test_predictions,mode='markers'))

df_pred['mean'] = df_pred.mean(axis=1)
df_pred['median'] = df_pred.median(axis=1)
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=df_pred['mean']))
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=df_pred['median']))
fig.show()
eval_df2  =create_eval_df(df_pred['mean'],y_test_filtered2)

# %%
#Calculating R2 value:
r2_test = r2_score(y_test_filtered2[:-1],df_pred['mean'][:-1])
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.77
