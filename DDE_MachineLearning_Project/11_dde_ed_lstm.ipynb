# %%
import numpy as np
import pandas as pd
from datetime import date
import plotly.express as px
import plotly.graph_objects as go
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing as pp
import matplotlib as mpl
from sklearn.decomposition import PCA
from pandas.plotting import lag_plot, autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
import statsmodels.api as smw
from datetime import timedelta
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.svm import SVR
from sklearn.metrics import r2_score
# ML Algorithms to be used
import tensorflow as tf
from tensorflow import keras
from keras import optimizers, models, layers, regularizers
tf.__version__
from utils.dde_preprocessing_utils import (set_timestamp_index,
remove_duplicates,
remove_columns,
extract_correlations,
prepare_data_sarimax,
create_test_train_split,
create_sarimax_test_train_split,
create_eval_df,
convert_to_sample_time_feature,
convert_from_differencing,
make_multiple_predictions,
calculate_r2_scores,
apply_differencing)
from utils.dde_plotting_utils import(
display_double_timestamps,
display_seasonal_decomposition,
plot_predictions,
plot_accuracy,
plot_error_variations,
plot_learning_curves,
plot_multiple_predictions,
)
# %load_ext skip_kernel_extension

# %%
import keras_tuner as kt
from scipy.signal import savgol_filter

# %%
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
mpl.rcParams['figure.figsize'] = [8.0, 8.0]
tf.random.set_seed(2022)

# %%
SKIP_RETRAIN_NN =True
SKIP_RETRAIN_RNN = True
SKIP_RETRAIN_LSTM = True
SKIP_RETRAIN_ED_LSTM = False

# %% [markdown]
# ## Loading Data

# %%
bench_df = pd.read_csv("energy_dataset.csv")
bench_df = set_timestamp_index(bench_df,"time")
bench_df = bench_df['price day ahead']

# %%
base_df = pd.read_csv("extended_preprocessed_data.csv")
base_df = set_timestamp_index(base_df,"Unnamed: 0")

# %%
base_df
# Out:
#                              temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 01:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 02:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 03:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 04:00:00+01:00  -3.464    1002.0        78         0.0        23
# ...                           ...       ...       ...         ...       ...
# 2018-12-31 19:00:00+01:00  12.490    1028.0        62         2.0       140
# 2018-12-31 20:00:00+01:00   9.990    1029.0        71         1.0       242
# 2018-12-31 21:00:00+01:00   8.510    1029.0        81         3.0       300
# 2018-12-31 22:00:00+01:00   6.990    1029.0        81         2.0       310
# 2018-12-31 23:00:00+01:00   5.990    1029.0        75         2.0       300
#
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               447.0
# 2015-01-01 01:00:00+01:00               449.0
# 2015-01-01 02:00:00+01:00               448.0
# 2015-01-01 03:00:00+01:00               438.0
# 2015-01-01 04:00:00+01:00               428.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               297.0
# 2018-12-31 20:00:00+01:00               296.0
# 2018-12-31 21:00:00+01:00               292.0
# 2018-12-31 22:00:00+01:00               293.0
# 2018-12-31 23:00:00+01:00               290.0
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 329.0
# 2018-12-31 22:00:00+01:00         69.89     22748.0            -3053.0
# 2018-12-31 23:00:00+01:00         69.88     22605.0            -1850.0
#
#                            energy_stored  month  day  weekend  hour
# 2015-01-01 00:00:00+01:00         2866.0      1    1        0     0
# 2015-01-01 01:00:00+01:00         6302.0      1    1        0     1
# 2015-01-01 02:00:00+01:00        10364.0      1    1        0     2
# 2015-01-01 03:00:00+01:00        14301.0      1    1        0     3
# 2015-01-01 04:00:00+01:00        18657.0      1    1        0     4
# ...                                  ...    ...  ...      ...   ...
# 2018-12-31 19:00:00+01:00     -2062312.5     12   31        0    19
# 2018-12-31 20:00:00+01:00     -2066834.5     12   31        0    20
# 2018-12-31 21:00:00+01:00     -2070918.5     12   31        0    21
# 2018-12-31 22:00:00+01:00     -2073971.5     12   31        0    22
# 2018-12-31 23:00:00+01:00     -2075821.5     12   31        0    23
#
# [35064 rows x 28 columns]

# %%
base_df['price actual'] = savgol_filter(base_df['price actual'],7,4)

# %%
diff_df = apply_differencing(base_df,['month','day','weekend','hour'])
diff_df.index = diff_df.index.tz_convert('utc')

# %%
diff_df
# Out:
#                             temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+00:00  0.000       0.0       0.0         0.0       0.0
# 2015-01-01 01:00:00+00:00 -0.789       1.0       1.0        -1.0     -39.0
# 2015-01-01 02:00:00+00:00  0.000       0.0       0.0         0.0       0.0
# 2015-01-01 03:00:00+00:00  0.000       0.0       0.0         0.0       0.0
# 2015-01-01 04:00:00+00:00  0.606       2.0      -7.0         2.0     298.0
# ...                          ...       ...       ...         ...       ...
# 2018-12-31 18:00:00+00:00 -3.510       0.0      18.0        -1.0       0.0
# 2018-12-31 19:00:00+00:00 -2.500       1.0       9.0        -1.0     102.0
# 2018-12-31 20:00:00+00:00 -1.480       0.0      10.0         2.0      58.0
# 2018-12-31 21:00:00+00:00 -1.520       0.0       0.0        -1.0      10.0
# 2018-12-31 22:00:00+00:00 -1.000       0.0      -6.0         0.0     -10.0
#
#                            generation biomass  \
# 2015-01-01 00:00:00+00:00                 2.0
# 2015-01-01 01:00:00+00:00                -1.0
# 2015-01-01 02:00:00+00:00               -10.0
# 2015-01-01 03:00:00+00:00               -10.0
# 2015-01-01 04:00:00+00:00               -18.0
# ...                                       ...
# 2018-12-31 18:00:00+00:00                 4.0
# 2018-12-31 19:00:00+00:00                -1.0
# 2018-12-31 20:00:00+00:00                -4.0
# 2018-12-31 21:00:00+00:00                 1.0
# 2018-12-31 22:00:00+00:00                -3.0
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+00:00                                  -1.0
# 2015-01-01 01:00:00+00:00                                  -5.0
# 2015-01-01 02:00:00+00:00                                 -69.0
# 2015-01-01 03:00:00+00:00                                 -67.0
# 2015-01-01 04:00:00+00:00                                  -9.0
# ...                                                         ...
# 2018-12-31 18:00:00+00:00                                   0.0
# 2018-12-31 19:00:00+00:00                                   0.0
# 2018-12-31 20:00:00+00:00                                   0.0
# 2018-12-31 21:00:00+00:00                                   0.0
# 2015-01-01 04:00:00+00:00         4326.0      1    1        0     5
# ...                                  ...    ...  ...      ...   ...
# 2018-12-31 18:00:00+00:00        -4238.0     12   31        0    19
# 2018-12-31 19:00:00+00:00        -4522.0     12   31        0    20
# 2018-12-31 20:00:00+00:00        -4084.0     12   31        0    21
# 2018-12-31 21:00:00+00:00        -3053.0     12   31        0    22
# 2018-12-31 22:00:00+00:00        -1850.0     12   31        0    23
#
# [35063 rows x 28 columns]

# %% [markdown]
# # Encode- Decoder + LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = diff_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.MinMaxScaler(feature_range=(-1,1),copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
train_start = '2015-01-01'
validation_start = '2018-11-01'
test_start = '2018-12-01'
test_end = '2018-12-19'
feature = 'price actual'
namespace= 'MS_EDLSTM_Price16'
modeltype = 'EDLSTM'
batch_size = 32
num_epochs = 80

feature_df = diff_df[[feature]]
data_x_train0,data_x_val0,data_x_test0,data_y_train0,data_y_val0,data_y_test0 = create_test_train_split(scaled_df,feature_df,train_start,test_start,test_end,validation_start=validation_start)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,24*14,24,batch_size)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,24*14,24,batch_size)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,24*14,24,batch_size)

# %%
print(data_x_train.shape,data_y_train.shape)
print(data_x_val.shape,data_y_val.shape)
print(data_x_test.shape,data_y_test.shape)
# Out:
# (33216, 336, 28) (33216, 24)
# (320, 336, 28) (320, 24)
# (32, 336, 28) (32, 24)

# %% [markdown]
# Define LSTM Model

# %%
def build_model_ED_LSTM():
    n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
    model = models.Sequential()
    # Encoder
    model.add(layers.LSTM(64, return_sequences=True,input_shape=(None, n_features), stateful=False)) 
    model.add(layers.BatchNormalization())
    
    model.add(layers.LSTM(64, return_sequences=False, stateful=False)) 
    model.add(layers.BatchNormalization())  
    
    # Repeat Vector
    model.add(layers.RepeatVector(n_outputs))
    
    # Decoder
    model.add(layers.LSTM(64, return_sequences=True,stateful=False))
    model.add(layers.BatchNormalization())
        
    model.add(layers.LSTM(64, return_sequences=True,stateful=False))
    model.add(layers.BatchNormalization())

    # End
    model.add(layers.TimeDistributed(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), kernel_initializer="he_normal")))
    model.add(layers.TimeDistributed(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), kernel_initializer="he_normal")))
    
    model.add(layers.TimeDistributed(layers.LeakyReLU(alpha=0.1)))                     
    model.add(layers.TimeDistributed(layers.BatchNormalization()))
    model.add(layers.TimeDistributed(layers.Dense(1)))                     
                
    model.compile(optimizer='Adam',loss='mse',metrics='mae') 
    return model

# %%
myCheckpointLSTM= keras.callbacks.ModelCheckpoint(f"./{modeltype}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingLSTM = keras.callbacks.EarlyStopping(patience=20,restore_best_weights=True)

# %%
initial_learning_rate = 0.005

decay = initial_learning_rate/num_epochs

def scheduler(epoch,lr):
    return lr*1/(1+decay*epoch)

myLearningRate_LSTM = keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# model_ED_LSTM= build_model_ED_LSTM()
# history_ED_LSTM = model_ED_LSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) ,
#                                  callbacks=[myCheckpointLSTM,myLearningRate_LSTM])#,myEarly_stoppingLSTM
# Out:
# Epoch 1/80
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 1038/1038 [==============================] - 47s 41ms/step - loss: 8.1703 - mae: 2.0253 - val_loss: 3.3590 - val_mae: 1.3871
# Epoch 2/80
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0009999375514004886.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 5.0389 - mae: 1.5892 - val_loss: 3.1568 - val_mae: 1.3156
# Epoch 3/80
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0009998125559001429.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 4.3964 - mae: 1.4926 - val_loss: 3.3799 - val_mae: 1.3825
# Epoch 4/80
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0009996250727128545.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 3.9392 - mae: 1.4193 - val_loss: 3.0137 - val_mae: 1.3191
# Epoch 5/80
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.000999375229938362.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 3.6940 - mae: 1.3769 - val_loss: 2.4340 - val_mae: 1.1875
# Epoch 6/80
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0009990630392654359.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 3.4751 - mae: 1.3367 - val_loss: 3.7551 - val_mae: 1.4866
# Epoch 7/80
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0009986885123799238.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 3.4161 - mae: 1.3261 - val_loss: 2.2228 - val_mae: 1.1417
# Epoch 8/80
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009982517773291675.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 3.1824 - mae: 1.2843 - val_loss: 2.2528 - val_mae: 1.1552
# Epoch 9/80
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0009977528457713687.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 3.0819 - mae: 1.2672 - val_loss: 2.6718 - val_mae: 1.2457
# Epoch 10/80
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0009971919620615664.
# 1038/1038 [==============================] - 43s 41ms/step - loss: 2.9845 - mae: 1.2493 - val_loss: 2.2451 - val_mae: 1.1457
# Epoch 11/80
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0009965691378085333.
# 1038/1038 [==============================] - 40s 39ms/step - loss: 2.9748 - mae: 1.2491 - val_loss: 2.1521 - val_mae: 1.1190
# Epoch 12/80
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0009958845009534843.
# 1038/1038 [==============================] - 40s 38ms/step - loss: 3.0835 - mae: 1.2694 - val_loss: 2.2315 - val_mae: 1.1657
# Epoch 13/80
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0009951381794056713.
# 1038/1038 [==============================] - 41s 39ms/step - loss: 2.7826 - mae: 1.2129 - val_loss: 2.1813 - val_mae: 1.1434
# Epoch 14/80
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.000994330301042396.
# 1038/1038 [==============================] - 40s 38ms/step - loss: 2.7054 - mae: 1.1997 - val_loss: 2.1297 - val_mae: 1.1200
# Epoch 15/80
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.0009263680360088305.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 1.2456 - mae: 0.8417 - val_loss: 2.4290 - val_mae: 1.1633
# Epoch 51/80
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0009234821731427747.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.1875 - mae: 0.8249 - val_loss: 2.7743 - val_mae: 1.2429
# Epoch 52/80
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0009205479307840431.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.1837 - mae: 0.8231 - val_loss: 2.7665 - val_mae: 1.2318
# Epoch 53/80
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0009175658401462939.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.2110 - mae: 0.8289 - val_loss: 2.9755 - val_mae: 1.3007
# Epoch 54/80
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0009145364323108209.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.2277 - mae: 0.8330 - val_loss: 2.5894 - val_mae: 1.1967
# Epoch 55/80
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0009114602382265945.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.1267 - mae: 0.8052 - val_loss: 2.6924 - val_mae: 1.2184
# Epoch 56/80
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0009083378467185591.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.1393 - mae: 0.8078 - val_loss: 2.7809 - val_mae: 1.2519
# Epoch 57/80
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0009051697304556782.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 1.1566 - mae: 0.8115 - val_loss: 2.7923 - val_mae: 1.2402
# Epoch 58/80
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0009019565359922635.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.1052 - mae: 0.7967 - val_loss: 2.7614 - val_mae: 1.2484
# Epoch 59/80
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0008986987357293109.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 1.2001 - mae: 0.8230 - val_loss: 2.5052 - val_mae: 1.1905
# Epoch 60/80
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.000895396975931577.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.0982 - mae: 0.7924 - val_loss: 2.6847 - val_mae: 1.2350
# Epoch 61/80
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.00089205178672246.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.0669 - mae: 0.7829 - val_loss: 2.7708 - val_mae: 1.2583
# Epoch 62/80
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0008886637560799175.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 1.0537 - mae: 0.7787 - val_loss: 2.5722 - val_mae: 1.2046
# Epoch 63/80
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0008852334718354803.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 1.1086 - mae: 0.7938 - val_loss: 2.8056 - val_mae: 1.2520
# Epoch 64/80
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.000881761521674298.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 1.1180 - mae: 0.7952 - val_loss: 2.4519 - val_mae: 1.1803
# Epoch 65/80
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.000878248551110941.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 1.0236 - mae: 0.7675 - val_loss: 2.4742 - val_mae: 1.1892
# Epoch 66/80
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0008746950895549573.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.0358 - mae: 0.7711 - val_loss: 2.7434 - val_mae: 1.2470
# Epoch 67/80
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0008711017822211667.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 1.1002 - mae: 0.7894 - val_loss: 2.5137 - val_mae: 1.1892
# Epoch 68/80
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.000867469274163758.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.0785 - mae: 0.7817 - val_loss: 2.4212 - val_mae: 1.1662
# Epoch 69/80
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0008637981523150142.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 1.1007 - mae: 0.7872 - val_loss: 2.5117 - val_mae: 1.1985
# Epoch 70/80
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0008600890034611146.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 1.0158 - mae: 0.7626 - val_loss: 2.4001 - val_mae: 1.1684
# Epoch 71/80
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0008563425301504046.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.0093 - mae: 0.7595 - val_loss: 2.5575 - val_mae: 1.1790
# Epoch 72/80
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0008525593188553575.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 1.0323 - mae: 0.7648 - val_loss: 2.7308 - val_mae: 1.2349
# Epoch 73/80
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0008487400138493852.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 1.0447 - mae: 0.7689 - val_loss: 2.4910 - val_mae: 1.1927
# Epoch 74/80
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0008448852013022677.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 0.9603 - mae: 0.7432 - val_loss: 2.6830 - val_mae: 1.2184
# Epoch 75/80
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0008409955831172974.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 1.0317 - mae: 0.7645 - val_loss: 2.5226 - val_mae: 1.1809
# Epoch 76/80
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.000837071803087024.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 0.9322 - mae: 0.7340 - val_loss: 2.4792 - val_mae: 1.1643
# Epoch 77/80
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0008331145048438094.
# 1038/1038 [==============================] - 41s 40ms/step - loss: 0.9770 - mae: 0.7462 - val_loss: 2.3988 - val_mae: 1.1626
# Epoch 78/80
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0008291243318598788.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 0.9709 - mae: 0.7446 - val_loss: 2.6510 - val_mae: 1.2137
# Epoch 79/80
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0008251019853726447.
# 1038/1038 [==============================] - 42s 41ms/step - loss: 0.9306 - mae: 0.7325 - val_loss: 2.4751 - val_mae: 1.1795
# Epoch 80/80
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0008210480506017259.
# 1038/1038 [==============================] - 42s 40ms/step - loss: 0.9059 - mae: 0.7237 - val_loss: 3.0798 - val_mae: 1.3244

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# histEDLSTM = pd.DataFrame(history_ED_LSTM.history)
# histEDLSTM['epoch'] = history_ED_LSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# fig = plot_learning_curves(histEDLSTM,modeltype,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# Load best model

# %%
model_best_ED_LSTM = keras.models.load_model(f"./{modeltype}/my_best_model_{namespace}.h5")
model_best_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 64)          23808
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 64)          256
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 64)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 64)            256
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 64)            4160
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 24, 64)            4160
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 24, 64)            0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 24, 64)            256
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 24, 1)             65
# =================================================================
# Total params: 132,545
# Trainable params: 131,905
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# Evaluate differencing Performance

# %%
i=0
case_test = data_x_val[i].reshape((1,data_x_val[0].shape[0], data_x_val[0].shape[1]))
Y_test_predictions_diff = pd.Series(model_best_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_val[i],freq='h',periods=24))
y_test_filtered_diff = data_y_val0.loc[Y_test_predictions_diff.index]
y_test_filtered_diff = y_test_filtered_diff.squeeze(axis=1)

# %%
eval_df_diff = create_eval_df(Y_test_predictions_diff,y_test_filtered_diff)

# %%
fig = plot_accuracy(eval_df_diff,modeltype,f"./{modeltype}/diff_accuracy_{namespace}.png")

# %%
fig = plot_error_variations(eval_df_diff,modeltype,f"./{modeltype}/diff_error_variations_{namespace}.png")

# %%
abs_error_ED_LSTM = abs(Y_test_predictions_diff - y_test_filtered_diff)/y_test_filtered_diff*100
np.average(abs_error_ED_LSTM)
# Out:
# 37.43761021243949

# %%
r2_test = r2_score(y_test_filtered_diff, Y_test_predictions_diff)
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.71

# %%
fig=plot_predictions(eval_df_diff,1,modeltype,feature,f"./{modeltype}/diff_predictions_{namespace}.png")

# %%
df_pred_diff = make_multiple_predictions(model_best_ED_LSTM,idx_test,data_x_test,data_y_test0,feature,convert=False)

# %%
eval_df_diff = create_eval_df(df_pred_diff['mean'],df_pred_diff['Actual'])

# %%
fig = plot_accuracy(eval_df_diff,modeltype,f"./{modeltype}/accuracy_diff_{namespace}.png")

# %%
# fig = plot_error_variations(eval_df_diff,modeltype,f"./{modeltype}/error_variations_diff_{namespace}.png")

# %%
fig=plot_predictions(eval_df_diff,1,modeltype,feature,f"./{modeltype}/predictions_diff_{namespace}.png")

# %%
r2_test = r2_score(df_pred_diff['Actual'][:-1], df_pred_diff['mean'][:-1])
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.81

# %% [markdown]
# Reverting differencing

# %%
df_pred = make_multiple_predictions(model_best_ED_LSTM,idx_val,data_x_val,base_df,feature,convert=True)

# %%
eval_df = create_eval_df(df_pred['mean'],df_pred['Actual'])

# %%
fig = plot_accuracy(eval_df,modeltype,f"./{modeltype}/accuracy_{namespace}.png")

# %%
fig = plot_error_variations(eval_df,modeltype,f"./{modeltype}/error_variations_{namespace}.png")

# %%
r2_test = r2_score(df_pred['Actual'][:-1],df_pred['mean'][:-1],)
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.77

# %%
fig=plot_multiple_predictions(df_pred,f"./{modeltype}/multiple_predictions_bench_{namespace}.png",add_traces=False)

# %%
r2 = calculate_r2_scores(df_pred)
plt.figure()
plt.plot(r2)

# %% [markdown]
# Comparing to Benchmark

# %%
eval_df_bench = create_eval_df(bench_df[idx_val[0]:idx_val[-1]+timedelta(hours=24)],df_pred['Actual'])
eval_df_bench
# Out:
#                            Prediction     Actual
# 2018-11-15 00:00:00+00:00       51.95  56.390390
# 2018-11-15 01:00:00+00:00       51.27  54.210216
# 2018-11-15 02:00:00+00:00       50.29  54.110996
# 2018-11-15 03:00:00+00:00       51.03  53.517792
# 2018-11-15 04:00:00+00:00       53.17  58.875714
# ...                               ...        ...
# 2018-11-29 03:00:00+00:00       46.67  49.630000
# 2018-11-29 04:00:00+00:00       49.64  53.904848
# 2018-11-29 05:00:00+00:00       58.33  61.519437
# 2018-11-29 06:00:00+00:00       65.24  68.689264
# 2018-11-29 07:00:00+00:00       67.33  71.647706
#
# [344 rows x 2 columns]

# %%
r2_test = r2_score(eval_df_bench['Prediction'][:-1], eval_df_bench['Actual'][:-1])
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.55

# %%
df_pred_24h = df_pred.iloc[:,0::24]
df_pred_24h['total'] = df_pred_24h.mean(axis=1)
df_pred_24h = df_pred_24h['total'].dropna()

# %%
fig = plt.figure(figsize=(16,8))
plt.plot(df_pred['Actual'],label = 'Actual')
plt.plot(df_pred['mean'], label= 'Prediction')
plt.plot(bench_df[idx_val[0]:idx_val[-1]+timedelta(hours=24)], label = 'Benchmark')
# plt.plot(df_pred_24h,label='only24h')
plt.legend()
plt.xlim(idx_val[0],idx_val[0]+timedelta(hours=24*14-1))
# Out:
# (17850.0, 17863.958333333332)

# %% [markdown]
# Weighted Mean

# %%
df_pred_wm = df_pred.copy(deep=True)
df_pred_wm = remove_columns(df_pred_wm,['mean','Actual'])

# %%
df_pred_wm = df_pred_wm.iloc[:-1,:]

# %%
df_pred_wm = df_pred_wm.iloc[23:-23,:]

# %%
idx = df_pred_wm.index

# %%
cols = [f'pred_{x}h' for x in range(24,0,-1)]
new_df = pd.DataFrame()
liste=[]
for row in df_pred_wm.iterrows():
    a = list(row)
    new_series = list(a[1].dropna())
    liste.append(new_series)
weights = [x/24 for x in range(1,25,1)]
print(weights)
# weights = [x/sum(weights) for x in weights]
# print(weights)
new_list = []
for item in liste:
    new_list.append(np.average(item,weights=weights))
    
    
df_wp = pd.DataFrame(new_list,index=idx,columns=['Weighted Average Prediction'])
# Out:
# [0.041666666666666664, 0.08333333333333333, 0.125, 0.16666666666666666, 0.20833333333333334, 0.25, 0.2916666666666667, 0.3333333333333333, 0.375, 0.4166666666666667, 0.4583333333333333, 0.5, 0.5416666666666666, 0.5833333333333334, 0.625, 0.6666666666666666, 0.7083333333333334, 0.75, 0.7916666666666666, 0.8333333333333334, 0.875, 0.9166666666666666, 0.9583333333333334, 1.0]

# %%
fig = plt.figure(figsize=(16,8))
plt.plot(df_pred['Actual'],label = 'Actual')
# plt.plot(df_pred['mean'], label= 'Prediction')
# plt.plot(bench_df[idx_val[0]:idx_val[-1]+timedelta(hours=24)], label = 'Benchmark')
plt.plot(df_wp,label='Weighted Average')
plt.legend()
