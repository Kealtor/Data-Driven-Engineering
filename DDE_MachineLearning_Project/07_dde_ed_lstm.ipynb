# %%
import numpy as np
import pandas as pd
from datetime import date
import plotly.express as px
import plotly.graph_objects as go
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing as pp
import matplotlib as mpl
from sklearn.decomposition import PCA
from pandas.plotting import lag_plot, autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
import statsmodels.api as smw
from datetime import timedelta
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.svm import SVR
from sklearn.metrics import r2_score
# ML Algorithms to be used
import tensorflow as tf
from tensorflow import keras
from keras import optimizers, models, layers, regularizers
tf.__version__
from utils.dde_preprocessing_utils import (set_timestamp_index,
remove_duplicates,
remove_columns,
extract_correlations,
prepare_data_sarimax,
create_test_train_split,
create_sarimax_test_train_split,
create_eval_df,
convert_to_sample_time_feature)
from utils.dde_plotting_utils import(
display_double_timestamps,
display_seasonal_decomposition,
plot_predictions,
plot_accuracy,
plot_error_variations,
plot_learning_curves,
)
# %load_ext skip_kernel_extension

# %%
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
tf.random.set_seed('2022')
mpl.rcParams['figure.figsize'] = [8.0, 8.0]

# %%
SKIP_RETRAIN_NN =True
SKIP_RETRAIN_RNN = True
SKIP_RETRAIN_LSTM = True
SKIP_RETRAIN_ED_LSTM = False

# %% [markdown]
# ## Loading Data

# %%
combined_df = pd.read_csv("preprocessed_data.csv")
combined_df = set_timestamp_index(combined_df,"Unnamed: 0")

# %%
combined_df
# Out:
#                              temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 01:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 02:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 03:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 04:00:00+01:00  -3.464    1002.0        78         0.0        23
# ...                           ...       ...       ...         ...       ...
# 2018-12-31 19:00:00+01:00  12.490    1028.0        62         2.0       140
# 2018-12-31 20:00:00+01:00   9.990    1029.0        71         1.0       242
# 2018-12-31 21:00:00+01:00   8.510    1029.0        81         3.0       300
# 2018-12-31 22:00:00+01:00   6.990    1029.0        81         2.0       310
# 2018-12-31 23:00:00+01:00   5.990    1029.0        75         2.0       300
#
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               447.0
# 2015-01-01 01:00:00+01:00               449.0
# 2015-01-01 02:00:00+01:00               448.0
# 2015-01-01 03:00:00+01:00               438.0
# 2015-01-01 04:00:00+01:00               428.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               297.0
# 2018-12-31 20:00:00+01:00               296.0
# 2018-12-31 21:00:00+01:00               292.0
# 2018-12-31 22:00:00+01:00               293.0
# 2018-12-31 23:00:00+01:00               290.0
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 329.0
# 2015-01-01 01:00:00+01:00                                 328.0
# 2015-01-01 02:00:00+01:00                                 323.0
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 04:00:00+01:00                                 187.0
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00                 4844.0                       4821.0
# 2015-01-01 01:00:00+01:00                 5196.0                       4755.0
# 2015-01-01 02:00:00+01:00                 4857.0                       4581.0
# 2015-01-01 03:00:00+01:00                 4314.0                       4131.0
# 2015-01-01 04:00:00+01:00                 4130.0                       3840.0
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7634.0                       2628.0
# 2018-12-31 20:00:00+01:00                 7241.0                       2566.0
# 2018-12-31 21:00:00+01:00                 7025.0                       2422.0
# 2018-12-31 22:00:00+01:00                 6562.0                       2293.0
# 2018-12-31 23:00:00+01:00                 6926.0                       2166.0
#
#                            generation fossil oil  ...  generation solar  \
# 2015-01-01 00:00:00+01:00                  162.0  ...              49.0
# 2015-01-01 01:00:00+01:00                  158.0  ...              50.0
# 2015-01-01 02:00:00+01:00                  157.0  ...              50.0
# 2015-01-01 03:00:00+01:00                  160.0  ...              50.0
# 2015-01-01 04:00:00+01:00                  156.0  ...              42.0
# ...                                          ...  ...               ...
# 2018-12-31 19:00:00+01:00                  178.0  ...              85.0
# 2018-12-31 20:00:00+01:00                  174.0  ...              33.0
# 2018-12-31 21:00:00+01:00                  168.0  ...              31.0
# 2018-12-31 22:00:00+01:00                  163.0  ...              31.0
# 2018-12-31 23:00:00+01:00                  163.0  ...              31.0
#
#                            generation waste  generation wind onshore  \
# 2015-01-01 00:00:00+01:00             196.0                   6378.0
# 2015-01-01 01:00:00+01:00             195.0                   5890.0
# 2015-01-01 02:00:00+01:00             196.0                   5461.0
# 2015-01-01 03:00:00+01:00             191.0                   5238.0
# 2015-01-01 04:00:00+01:00             189.0                   4935.0
# ...                                     ...                      ...
# 2018-12-31 19:00:00+01:00             277.0                   3113.0
# 2018-12-31 20:00:00+01:00             280.0                   3288.0
# 2018-12-31 21:00:00+01:00             286.0                   3503.0
# 2018-12-31 22:00:00+01:00             287.0                   3586.0
# 2018-12-31 23:00:00+01:00             287.0                   3651.0
#
#                            total load actual  price actual  generation  \
# 2015-01-01 00:00:00+01:00            25385.0         65.41     28251.0
# 2015-01-01 01:00:00+01:00            24382.0         64.92     27818.0
# 2015-01-01 02:00:00+01:00            22734.0         64.48     26796.0
# 2015-01-01 03:00:00+01:00            21286.0         59.32     25223.0
# 2015-01-01 04:00:00+01:00            20264.0         56.04     24620.0
# ...                                      ...           ...         ...
# 2018-12-31 19:00:00+01:00            30653.0         77.02     26415.0
# 2018-12-31 20:00:00+01:00            29735.0         76.16     25213.0
# 2018-12-31 21:00:00+01:00            28071.0         74.30     23987.0
# 2018-12-31 22:00:00+01:00            25801.0         69.89     22748.0
# 2018-12-31 23:00:00+01:00            24455.0         69.88     22605.0
#
#                            energy_difference  month  day  weekend
# 2015-01-01 00:00:00+01:00             2866.0      1    1        0
# 2015-01-01 01:00:00+01:00             3436.0      1    1        0
# 2015-01-01 02:00:00+01:00             4062.0      1    1        0
# 2015-01-01 03:00:00+01:00             3937.0      1    1        0
# 2015-01-01 04:00:00+01:00             4356.0      1    1        0
# ...                                      ...    ...  ...      ...
# 2018-12-31 19:00:00+01:00            -4238.0     12   31        0
# 2018-12-31 20:00:00+01:00            -4522.0     12   31        0
# 2018-12-31 21:00:00+01:00            -4084.0     12   31        0
# 2018-12-31 22:00:00+01:00            -3053.0     12   31        0
# 2018-12-31 23:00:00+01:00            -1850.0     12   31        0
#
# [35064 rows x 26 columns]

# %% [markdown]
# # Encode- Decoder + LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = combined_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.StandardScaler(copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
train_start = '2015-01-01'
validation_start = '2017-01-01'
test_start = '2017-03-01'
test_end = '2017-03-14'
feature = 'total load actual'
namespace= 'MS_EDLSTM'
modeltype = 'EDLSTM'
feature_df = combined_df[[feature]]
data_x_train0,data_x_val0,data_x_test0,data_y_train0,data_y_val0,data_y_test0 = create_test_train_split(scaled_df,feature_df,train_start,test_start,test_end,validation_start=validation_start)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,72,24,32)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,72,24,32)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,72,24,32)

# %%
print(data_x_train.shape,data_y_train.shape)
print(data_x_val.shape,data_y_val.shape)
print(data_x_test.shape,data_y_test.shape)
# Out:
# (17416, 72, 26) (17416, 24)
# (1288, 72, 26) (1288, 24)
# (168, 72, 26) (168, 24)

# %% [markdown]
# Define ED LSTM Model

# %%
def build_model_ED_LSTM(data_x_train,data_y_train):
    n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
    model = models.Sequential([
    layers.LSTM(80, return_sequences=True,input_shape=(None, n_features), stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(64, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(32, return_sequences=False, stateful=False),
    layers.BatchNormalization(),
    layers.RepeatVector(n_outputs),
    # define decoder:
    layers.LSTM(32, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(64, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(80, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.TimeDistributed(layers.Dense(1))                     
    ])
    model.compile(optimizer='Adam',loss='mse',metrics='mae') 
    return model

# %% [markdown]
# Definening callback functions

# %%
myCheckpointEDLSTM= keras.callbacks.ModelCheckpoint(f"./{modeltype}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingEDLSTM = keras.callbacks.EarlyStopping(patience=20,restore_best_weights=True)

# %% [markdown]
# Hypterparameters

# %%
num_epochs = 150
batch_size = 32

# %% [markdown]
# Training the model

# %%
model_ED_LSTM = build_model_ED_LSTM(data_x_train,data_y_train)
model_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 80)          34240
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 80)          320
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 64)          37120
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64)          256
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 32)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 24, 32)            8320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 32)            128
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 24, 64)            24832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 24, 80)            46400
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 80)            320
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 1)             81
# =================================================================
# Total params: 164,817
# Trainable params: 164,113
# Non-trainable params: 704
# _________________________________________________________________

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
#
# history_ED_LSTM = model_ED_LSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) ,
#                                  callbacks=[myCheckpointEDLSTM,myEarly_stoppingEDLSTM])
# Out:
# Epoch 1/150
# 545/545 [==============================] - 27s 36ms/step - loss: 828687360.0000 - mae: 28431.0234 - val_loss: 903931200.0000 - val_mae: 29650.3633 1s - loss: 82889331
# Epoch 2/150
# 545/545 [==============================] - 18s 33ms/step - loss: 820240064.0000 - mae: 28312.3535 - val_loss: 888123904.0000 - val_mae: 29428.3672
# Epoch 3/150
# 545/545 [==============================] - 17s 32ms/step - loss: 805213184.0000 - mae: 28089.9277 - val_loss: 870809216.0000 - val_mae: 29180.5117
# Epoch 4/150
# 545/545 [==============================] - 18s 32ms/step - loss: 785290944.0000 - mae: 27783.2402 - val_loss: 843418880.0000 - val_mae: 28753.3477
# Epoch 5/150
# 545/545 [==============================] - 18s 34ms/step - loss: 761518784.0000 - mae: 27404.2832 - val_loss: 810718528.0000 - val_mae: 28229.5254
# Epoch 6/150
# 545/545 [==============================] - 17s 32ms/step - loss: 734703360.0000 - mae: 26961.4219 - val_loss: 772064768.0000 - val_mae: 27576.5371
# Epoch 7/150
# 545/545 [==============================] - 18s 34ms/step - loss: 705565696.0000 - mae: 26461.2461 - val_loss: 718699264.0000 - val_mae: 26644.8750
# Epoch 8/150
# 545/545 [==============================] - 20s 36ms/step - loss: 674592896.0000 - mae: 25907.7012 - val_loss: 674807488.0000 - val_mae: 25836.5469
# Epoch 9/150
# 545/545 [==============================] - 19s 36ms/step - loss: 642308928.0000 - mae: 25304.5078 - val_loss: 625176704.0000 - val_mae: 24867.8672
# Epoch 10/150
# 545/545 [==============================] - 20s 37ms/step - loss: 608948672.0000 - mae: 24653.9434 - val_loss: 609809472.0000 - val_mae: 24552.1172
# Epoch 11/150
# 545/545 [==============================] - 19s 35ms/step - loss: 574815744.0000 - mae: 23956.3750 - val_loss: 548290944.0000 - val_mae: 23274.2168
# Epoch 12/150
# 545/545 [==============================] - 18s 34ms/step - loss: 539534912.0000 - mae: 23212.1953 - val_loss: 521017664.0000 - val_mae: 22695.4023
# Epoch 13/150
# 545/545 [==============================] - 18s 34ms/step - loss: 503380864.0000 - mae: 22420.2949 - val_loss: 476065568.0000 - val_mae: 21674.4316
# Epoch 14/150
# 545/545 [==============================] - 19s 34ms/step - loss: 466522048.0000 - mae: 21583.3652 - val_loss: 450216000.0000 - val_mae: 21068.7012
# Epoch 15/150
# 545/545 [==============================] - 19s 34ms/step - loss: 429357952.0000 - mae: 20704.0527 - val_loss: 406216800.0000 - val_mae: 19998.0488
# Epoch 16/150
# 545/545 [==============================] - 18s 34ms/step - loss: 392032832.0000 - mae: 19783.7734 - val_loss: 380902240.0000 - val_mae: 19350.4492
# Epoch 17/150
# 545/545 [==============================] - 19s 35ms/step - loss: 354996448.0000 - mae: 18824.0723 - val_loss: 337963744.0000 - val_mae: 18208.4121
# Epoch 18/150
# 545/545 [==============================] - 17s 31ms/step - loss: 318511648.0000 - mae: 17828.9961 - val_loss: 301573888.0000 - val_mae: 17163.8379
# Epoch 19/150
# 545/545 [==============================] - 16s 28ms/step - loss: 282843968.0000 - mae: 16798.8828 - val_loss: 267360752.0000 - val_mae: 16163.4609
# Epoch 20/150
# 545/545 [==============================] - 15s 27ms/step - loss: 248247904.0000 - mae: 15737.1025 - val_loss: 234273056.0000 - val_mae: 15113.3477
# Epoch 21/150
# 545/545 [==============================] - 15s 27ms/step - loss: 215094864.0000 - mae: 14645.4189 - val_loss: 200037504.0000 - val_mae: 13926.2666
# Epoch 22/150
# 545/545 [==============================] - 15s 27ms/step - loss: 183606224.0000 - mae: 13527.9873 - val_loss: 170435072.0000 - val_mae: 12826.6719
# Epoch 23/150
# 545/545 [==============================] - 15s 27ms/step - loss: 154031616.0000 - mae: 12388.3633 - val_loss: 146965888.0000 - val_mae: 11869.1865
# Epoch 24/150
# 545/545 [==============================] - 14s 25ms/step - loss: 126715152.0000 - mae: 11231.1182 - val_loss: 122278024.0000 - val_mae: 10767.1318
# Epoch 25/150
# 545/545 [==============================] - 14s 25ms/step - loss: 101854656.0000 - mae: 10059.1611 - val_loss: 95563344.0000 - val_mae: 9435.6133
# Epoch 26/150
# 545/545 [==============================] - 14s 26ms/step - loss: 79480488.0000 - mae: 8883.3301 - val_loss: 75763800.0000 - val_mae: 8325.1338
# Epoch 27/150
# 545/545 [==============================] - 14s 25ms/step - loss: 60033392.0000 - mae: 7711.2651 - val_loss: 57397872.0000 - val_mae: 7146.3325
# Epoch 28/150
# 545/545 [==============================] - 14s 25ms/step - loss: 43493412.0000 - mae: 6552.1733 - val_loss: 42786280.0000 - val_mae: 6093.2661
# Epoch 29/150
# 545/545 [==============================] - 14s 25ms/step - loss: 29925518.0000 - mae: 5418.1064 - val_loss: 33597908.0000 - val_mae: 5265.6069
# Epoch 30/150
# 545/545 [==============================] - 14s 25ms/step - loss: 19267036.0000 - mae: 4331.7729 - val_loss: 22805710.0000 - val_mae: 4179.6626
# Epoch 31/150
# 545/545 [==============================] - 14s 25ms/step - loss: 11526076.0000 - mae: 3308.2778 - val_loss: 14287419.0000 - val_mae: 3215.6980
# Epoch 32/150
# 545/545 [==============================] - 14s 25ms/step - loss: 6190107.0000 - mae: 2382.2112 - val_loss: 10079388.0000 - val_mae: 2540.5247
# Epoch 33/150
# 545/545 [==============================] - 14s 25ms/step - loss: 2960789.7500 - mae: 1590.2809 - val_loss: 7952710.0000 - val_mae: 2135.9033
# Epoch 34/150
# 545/545 [==============================] - 14s 25ms/step - loss: 1321011.6250 - mae: 991.0809 - val_loss: 7373003.5000 - val_mae: 2030.1115
# Epoch 35/150
# 545/545 [==============================] - 14s 25ms/step - loss: 659463.5000 - mae: 638.8994 - val_loss: 6529867.5000 - val_mae: 1793.5400
# Epoch 36/150
# 545/545 [==============================] - 14s 25ms/step - loss: 437013.5312 - mae: 509.6182 - val_loss: 6408188.0000 - val_mae: 1766.4993
# Epoch 37/150
# 545/545 [==============================] - 14s 26ms/step - loss: 511537.6250 - mae: 536.6403 - val_loss: 7095935.0000 - val_mae: 1847.1293
# Epoch 38/150
# 545/545 [==============================] - 14s 25ms/step - loss: 417433.4062 - mae: 490.7204 - val_loss: 6621189.0000 - val_mae: 1802.3895
# Epoch 39/150
# 545/545 [==============================] - 14s 26ms/step - loss: 384034.7812 - mae: 474.2242 - val_loss: 6934819.0000 - val_mae: 1852.3618
# Epoch 40/150
# 545/545 [==============================] - 14s 25ms/step - loss: 357137.1250 - mae: 460.0426 - val_loss: 7074630.0000 - val_mae: 1883.9851
# Epoch 41/150
# 545/545 [==============================] - 14s 25ms/step - loss: 460957.4688 - mae: 507.1616 - val_loss: 7160674.5000 - val_mae: 1883.0823
# Epoch 42/150
# 545/545 [==============================] - 13s 25ms/step - loss: 356353.5938 - mae: 454.9046 - val_loss: 6508388.5000 - val_mae: 1793.7480
# Epoch 43/150
# 545/545 [==============================] - 14s 26ms/step - loss: 429860.9688 - mae: 502.0220 - val_loss: 7203242.0000 - val_mae: 1887.6842
# Epoch 44/150
# 545/545 [==============================] - 14s 26ms/step - loss: 386377.0625 - mae: 475.7347 - val_loss: 6733091.0000 - val_mae: 1813.4315
# Epoch 45/150
# 545/545 [==============================] - 14s 26ms/step - loss: 382975.3125 - mae: 474.4810 - val_loss: 6452718.5000 - val_mae: 1786.8213
# Epoch 46/150
# 545/545 [==============================] - 14s 25ms/step - loss: 490280.4375 - mae: 523.1764 - val_loss: 6393252.0000 - val_mae: 1764.3865
# Epoch 47/150
# 545/545 [==============================] - 14s 25ms/step - loss: 385360.4062 - mae: 468.9070 - val_loss: 6095985.5000 - val_mae: 1737.2626
# Epoch 48/150
# 545/545 [==============================] - 14s 25ms/step - loss: 374167.3438 - mae: 468.6641 - val_loss: 6644179.0000 - val_mae: 1804.7958
# Epoch 49/150
# 545/545 [==============================] - 13s 25ms/step - loss: 364918.9062 - mae: 463.7066 - val_loss: 6128179.0000 - val_mae: 1729.8657
# Epoch 50/150
# 545/545 [==============================] - 14s 25ms/step - loss: 373056.3438 - mae: 467.4631 - val_loss: 6397848.5000 - val_mae: 1783.2941
# Epoch 51/150
# 545/545 [==============================] - 14s 26ms/step - loss: 369129.3750 - mae: 460.6057 - val_loss: 5907545.5000 - val_mae: 1705.8470
# Epoch 52/150
# 545/545 [==============================] - 14s 25ms/step - loss: 406600.9688 - mae: 476.1829 - val_loss: 6134022.0000 - val_mae: 1708.6661
# Epoch 53/150
# 545/545 [==============================] - 14s 25ms/step - loss: 360125.0938 - mae: 455.5639 - val_loss: 7512936.0000 - val_mae: 1919.7507
# Epoch 54/150
# 545/545 [==============================] - 14s 25ms/step - loss: 386940.1562 - mae: 472.0998 - val_loss: 6758312.0000 - val_mae: 1846.7069
# Epoch 55/150
# 545/545 [==============================] - 14s 26ms/step - loss: 373899.2188 - mae: 466.9183 - val_loss: 6563194.5000 - val_mae: 1818.1285
# Epoch 56/150
# 545/545 [==============================] - 14s 25ms/step - loss: 385294.8438 - mae: 473.9925 - val_loss: 6305834.5000 - val_mae: 1811.6608
# Epoch 57/150
# 545/545 [==============================] - 13s 25ms/step - loss: 390386.1875 - mae: 472.2607 - val_loss: 6102843.0000 - val_mae: 1732.8013
# Epoch 58/150
# 545/545 [==============================] - 14s 25ms/step - loss: 345984.2812 - mae: 452.7811 - val_loss: 6120294.5000 - val_mae: 1724.6077
# Epoch 59/150
# 545/545 [==============================] - 13s 24ms/step - loss: 382249.5000 - mae: 469.0721 - val_loss: 6359812.5000 - val_mae: 1759.7826
# Epoch 60/150
# 545/545 [==============================] - 13s 24ms/step - loss: 480618.1562 - mae: 517.2571 - val_loss: 7122626.0000 - val_mae: 1872.0779
# Epoch 61/150
# 545/545 [==============================] - 13s 25ms/step - loss: 334989.1875 - mae: 445.1661 - val_loss: 6378418.0000 - val_mae: 1772.5747
# Epoch 62/150
# 545/545 [==============================] - 13s 24ms/step - loss: 396836.1875 - mae: 472.2843 - val_loss: 6355001.0000 - val_mae: 1779.4843
# Epoch 63/150
# 545/545 [==============================] - 13s 24ms/step - loss: 350784.9688 - mae: 455.3810 - val_loss: 6198556.0000 - val_mae: 1759.8129
# Epoch 64/150
# 545/545 [==============================] - 13s 24ms/step - loss: 430316.8125 - mae: 489.7675 - val_loss: 6508441.5000 - val_mae: 1813.4595
# Epoch 65/150
# 545/545 [==============================] - 14s 25ms/step - loss: 329008.7812 - mae: 446.0211 - val_loss: 6261273.5000 - val_mae: 1793.7772
# Epoch 66/150
# 545/545 [==============================] - 14s 25ms/step - loss: 314728.3438 - mae: 432.5244 - val_loss: 6405036.0000 - val_mae: 1797.0928
# Epoch 67/150
# 545/545 [==============================] - 14s 26ms/step - loss: 389268.5938 - mae: 474.6921 - val_loss: 6452727.0000 - val_mae: 1772.4513
# Epoch 68/150
# 545/545 [==============================] - 14s 25ms/step - loss: 490493.6875 - mae: 519.4235 - val_loss: 5932972.5000 - val_mae: 1690.7845
# Epoch 69/150
# 545/545 [==============================] - 13s 25ms/step - loss: 318479.0000 - mae: 436.1860 - val_loss: 6154086.0000 - val_mae: 1741.5319
# Epoch 70/150
# 545/545 [==============================] - 13s 24ms/step - loss: 373325.2812 - mae: 470.0302 - val_loss: 6548471.0000 - val_mae: 1781.7095
# Epoch 71/150
# 545/545 [==============================] - 14s 25ms/step - loss: 403234.4375 - mae: 482.0912 - val_loss: 6502445.5000 - val_mae: 1771.4808

# %% [markdown]
# Evaluate the training process

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
#
# histEDLSTM = pd.DataFrame(history_ED_LSTM.history)
# histEDLSTM['epoch'] = history_ED_LSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
#
# fig = plot_learning_curves(histEDLSTM,modeltype,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# Load best model

# %%
#Calling back the best model:
model_best_ED_LSTM = keras.models.load_model(f"./{modeltype}/my_best_model_{namespace}.h5")
model_best_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 80)          34240
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 80)          320
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 64)          37120
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64)          256
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 32)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 24, 32)            8320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 32)            128
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 24, 64)            24832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 24, 80)            46400
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 80)            320
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 1)             81
# =================================================================
# Total params: 164,817
# Trainable params: 164,113
# Non-trainable params: 704
# _________________________________________________________________

# %%
i=1
case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))

Y_test_predictions = pd.Series(model_best_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
y_test_filtered = data_y_test0.loc[Y_test_predictions.index]

# %%
eval_df = create_eval_df(Y_test_predictions,y_test_filtered)

# %%
fig = plot_accuracy(eval_df,modeltype,f"./{modeltype}/accuracy_{namespace}.png")

# %%
fig = plot_error_variations(eval_df,modeltype,f"./{modeltype}/error_variations_{namespace}.png")

# %%
abs_error_ED_LSTM = abs(Y_test_predictions - y_test_filtered)/y_test_filtered*100
np.average(abs_error_ED_LSTM)
# Out:
# nan

# %%
r2_test = r2_score(y_test_filtered, Y_test_predictions)
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.52

# %%
fig=plot_predictions(eval_df,1,modeltype,feature,f"./{modeltype}/predictions_{namespace}.png")

# %%
idx_prediction = pd.date_range(start=idx_test[0],freq='h',periods=len(idx_test)+24)
y_test_filtered2 = data_y_test0.loc[idx_prediction]

# %%
fig = go.Figure()
df_pred =pd.DataFrame(index=y_test_filtered2.index)
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=y_test_filtered2[feature]))
for i in range(len(data_x_test)):
    case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
    Y_test_predictions = pd.Series(model_best_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
    df_pred[f'pred_{i}'] = Y_test_predictions
    fig.add_trace(go.Scatter(x = Y_test_predictions.index,y=Y_test_predictions,mode='markers'))

df_pred['mean'] = df_pred.mean(axis=1)
df_pred['median'] = df_pred.median(axis=1)
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=df_pred['mean']))
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=df_pred['median']))
fig.show()
eval_df2  =create_eval_df(df_pred['mean'],y_test_filtered2)

# %%
r2_test = r2_score(y_test_filtered2[:-1],df_pred['mean'][:-1])
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.56
