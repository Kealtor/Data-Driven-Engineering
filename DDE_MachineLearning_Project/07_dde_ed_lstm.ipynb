# %%
import numpy as np
import pandas as pd
from datetime import date
import plotly.express as px
import plotly.graph_objects as go
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing as pp
import matplotlib as mpl
from sklearn.decomposition import PCA
from pandas.plotting import lag_plot, autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
import statsmodels.api as smw
from datetime import timedelta
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.svm import SVR
from sklearn.metrics import r2_score
# ML Algorithms to be used
import tensorflow as tf
from tensorflow import keras
from keras import optimizers, models, layers, regularizers
tf.__version__
from utils.dde_preprocessing_utils import (set_timestamp_index,
remove_duplicates,
remove_columns,
extract_correlations,
prepare_data_sarimax,
create_test_train_split,
create_sarimax_test_train_split,
create_eval_df,
convert_to_sample_time_feature)
from utils.dde_plotting_utils import(
display_double_timestamps,
display_seasonal_decomposition,
plot_predictions,
plot_accuracy,
plot_error_variations,
plot_learning_curves,
)
# %load_ext skip_kernel_extension

# %%
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
mpl.rcParams['figure.figsize'] = [8.0, 8.0]

# %%
SKIP_RETRAIN_NN =True
SKIP_RETRAIN_RNN = True
SKIP_RETRAIN_LSTM = True
SKIP_RETRAIN_ED_LSTM = False

# %% [markdown]
# ## Loading Data

# %%
combined_df = pd.read_csv("preprocessed_data.csv")
combined_df = set_timestamp_index(combined_df,"Unnamed: 0")

# %%
combined_df
# Out:
#                              temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 01:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 02:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 03:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 04:00:00+01:00  -3.464    1002.0        78         0.0        23
# ...                           ...       ...       ...         ...       ...
# 2018-12-31 19:00:00+01:00  12.490    1028.0        62         2.0       140
# 2018-12-31 20:00:00+01:00   9.990    1029.0        71         1.0       242
# 2018-12-31 21:00:00+01:00   8.510    1029.0        81         3.0       300
# 2018-12-31 22:00:00+01:00   6.990    1029.0        81         2.0       310
# 2018-12-31 23:00:00+01:00   5.990    1029.0        75         2.0       300
#
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               447.0
# 2015-01-01 01:00:00+01:00               449.0
# 2015-01-01 02:00:00+01:00               448.0
# 2015-01-01 03:00:00+01:00               438.0
# 2015-01-01 04:00:00+01:00               428.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               297.0
# 2018-12-31 20:00:00+01:00               296.0
# 2018-12-31 21:00:00+01:00               292.0
# 2018-12-31 22:00:00+01:00               293.0
# 2018-12-31 23:00:00+01:00               290.0
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 329.0
# 2015-01-01 01:00:00+01:00                                 328.0
# 2015-01-01 02:00:00+01:00                                 323.0
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 04:00:00+01:00                                 187.0
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00                 4844.0                       4821.0
# 2015-01-01 01:00:00+01:00                 5196.0                       4755.0
# 2015-01-01 02:00:00+01:00                 4857.0                       4581.0
# 2015-01-01 03:00:00+01:00                 4314.0                       4131.0
# 2015-01-01 04:00:00+01:00                 4130.0                       3840.0
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7634.0                       2628.0
# 2018-12-31 20:00:00+01:00                 7241.0                       2566.0
# 2018-12-31 21:00:00+01:00                 7025.0                       2422.0
# 2018-12-31 22:00:00+01:00                 6562.0                       2293.0
# 2018-12-31 23:00:00+01:00                 6926.0                       2166.0
#
#                            generation fossil oil  ...  generation solar  \
# 2015-01-01 00:00:00+01:00                  162.0  ...              49.0
# 2015-01-01 01:00:00+01:00                  158.0  ...              50.0
# 2015-01-01 02:00:00+01:00                  157.0  ...              50.0
# 2015-01-01 03:00:00+01:00                  160.0  ...              50.0
# 2015-01-01 04:00:00+01:00                  156.0  ...              42.0
# ...                                          ...  ...               ...
# 2018-12-31 19:00:00+01:00                  178.0  ...              85.0
# 2018-12-31 20:00:00+01:00                  174.0  ...              33.0
# 2018-12-31 21:00:00+01:00                  168.0  ...              31.0
# 2018-12-31 22:00:00+01:00                  163.0  ...              31.0
# 2018-12-31 23:00:00+01:00                  163.0  ...              31.0
#
#                            generation waste  generation wind onshore  \
# 2015-01-01 00:00:00+01:00             196.0                   6378.0
# 2015-01-01 01:00:00+01:00             195.0                   5890.0
# 2015-01-01 02:00:00+01:00             196.0                   5461.0
# 2015-01-01 03:00:00+01:00             191.0                   5238.0
# 2015-01-01 04:00:00+01:00             189.0                   4935.0
# ...                                     ...                      ...
# 2018-12-31 19:00:00+01:00             277.0                   3113.0
# 2018-12-31 20:00:00+01:00             280.0                   3288.0
# 2018-12-31 21:00:00+01:00             286.0                   3503.0
# 2018-12-31 22:00:00+01:00             287.0                   3586.0
# 2018-12-31 23:00:00+01:00             287.0                   3651.0
#
#                            total load actual  price actual  generation  \
# 2015-01-01 00:00:00+01:00            25385.0         65.41     28251.0
# 2015-01-01 01:00:00+01:00            24382.0         64.92     27818.0
# 2015-01-01 02:00:00+01:00            22734.0         64.48     26796.0
# 2015-01-01 03:00:00+01:00            21286.0         59.32     25223.0
# 2015-01-01 04:00:00+01:00            20264.0         56.04     24620.0
# ...                                      ...           ...         ...
# 2018-12-31 19:00:00+01:00            30653.0         77.02     26415.0
# 2018-12-31 20:00:00+01:00            29735.0         76.16     25213.0
# 2018-12-31 21:00:00+01:00            28071.0         74.30     23987.0
# 2018-12-31 22:00:00+01:00            25801.0         69.89     22748.0
# 2018-12-31 23:00:00+01:00            24455.0         69.88     22605.0
#
#                            energy_difference  month  day  weekend
# 2015-01-01 00:00:00+01:00             2866.0      1    1        0
# 2015-01-01 01:00:00+01:00             3436.0      1    1        0
# 2015-01-01 02:00:00+01:00             4062.0      1    1        0
# 2015-01-01 03:00:00+01:00             3937.0      1    1        0
# 2015-01-01 04:00:00+01:00             4356.0      1    1        0
# ...                                      ...    ...  ...      ...
# 2018-12-31 19:00:00+01:00            -4238.0     12   31        0
# 2018-12-31 20:00:00+01:00            -4522.0     12   31        0
# 2018-12-31 21:00:00+01:00            -4084.0     12   31        0
# 2018-12-31 22:00:00+01:00            -3053.0     12   31        0
# 2018-12-31 23:00:00+01:00            -1850.0     12   31        0
#
# [35064 rows x 26 columns]

# %% [markdown]
# # Encode- Decoder + LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = combined_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.StandardScaler(copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
train_start = '2015-01-01'
validation_start = '2017-01-01'
test_start = '2017-03-01'
test_end = '2017-03-14'
feature = 'total load actual'
namespace= 'MS_EDLSTM_LOAD'
modeltype = 'EDLSTM'
feature_df = combined_df[[feature]]
data_x_train0,data_x_val0,data_x_test0,data_y_train0,data_y_val0,data_y_test0 = create_test_train_split(scaled_df,feature_df,train_start,test_start,test_end,validation_start=validation_start)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,72,24,32)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,72,24,32)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,72,24,32)

# %%
print(data_x_train.shape,data_y_train.shape)
print(data_x_val.shape,data_y_val.shape)
print(data_x_test.shape,data_y_test.shape)
# Out:
# (17416, 72, 26) (17416, 24)
# (1288, 72, 26) (1288, 24)
# (168, 72, 26) (168, 24)

# %% [markdown]
# Define ED LSTM Model

# %%
def build_model_ED_LSTM(data_x_train,data_y_train):
    n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
    model = models.Sequential([
    layers.LSTM(80, return_sequences=True,input_shape=(None, n_features), stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(64, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(32, return_sequences=False, stateful=False),
    layers.BatchNormalization(),
    layers.RepeatVector(n_outputs),
    # define decoder:
    layers.LSTM(32, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(64, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.LSTM(80, return_sequences=True, stateful=False),
    layers.BatchNormalization(),
    layers.TimeDistributed(layers.Dense(1))                     
    ])
    model.compile(optimizer='Adam',loss='mse',metrics='mae') 
    return model

# %% [markdown]
# Definening callback functions

# %%
myCheckpointEDLSTM= keras.callbacks.ModelCheckpoint(f"./{modeltype}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingEDLSTM = keras.callbacks.EarlyStopping(patience=20,restore_best_weights=True)

# %% [markdown]
# Hypterparameters

# %%
num_epochs = 150
batch_size = 32

# %% [markdown]
# Training the model

# %%
model_ED_LSTM = build_model_ED_LSTM(data_x_train,data_y_train)
model_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 80)          34240
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 80)          320
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 64)          37120
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64)          256
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 32)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 24, 32)            8320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 32)            128
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 24, 64)            24832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 24, 80)            46400
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 80)            320
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 1)             81
# =================================================================
# Total params: 164,817
# Trainable params: 164,113
# Non-trainable params: 704
# _________________________________________________________________

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
#
# history_ED_LSTM = model_ED_LSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) ,
#                                  callbacks=[myCheckpointEDLSTM,myEarly_stoppingEDLSTM])
# Out:
# Epoch 1/150
# 545/545 [==============================] - 21s 28ms/step - loss: 828704192.0000 - mae: 28431.1016 - val_loss: 904238144.0000 - val_mae: 29653.3594
# Epoch 2/150
# 545/545 [==============================] - 14s 25ms/step - loss: 820300224.0000 - mae: 28312.5566 - val_loss: 887825152.0000 - val_mae: 29416.7305
# Epoch 3/150
# 545/545 [==============================] - 13s 24ms/step - loss: 805220480.0000 - mae: 28089.7207 - val_loss: 864304512.0000 - val_mae: 29056.3223
# Epoch 4/150
# 545/545 [==============================] - 14s 25ms/step - loss: 785278912.0000 - mae: 27782.7324 - val_loss: 836138752.0000 - val_mae: 28620.9434
# Epoch 5/150
# 545/545 [==============================] - 14s 25ms/step - loss: 761493952.0000 - mae: 27403.4668 - val_loss: 807444096.0000 - val_mae: 28160.4883
# Epoch 6/150
# 545/545 [==============================] - 14s 25ms/step - loss: 734695168.0000 - mae: 26960.6016 - val_loss: 757089856.0000 - val_mae: 27299.7539
# Epoch 7/150
# 545/545 [==============================] - 14s 25ms/step - loss: 705525824.0000 - mae: 26460.1777 - val_loss: 738269120.0000 - val_mae: 26984.4414
# Epoch 8/150
# 545/545 [==============================] - 14s 25ms/step - loss: 674542912.0000 - mae: 25906.7480 - val_loss: 693837696.0000 - val_mae: 26186.0781
# Epoch 9/150
# 545/545 [==============================] - 13s 25ms/step - loss: 642251776.0000 - mae: 25303.3340 - val_loss: 635602304.0000 - val_mae: 25041.7168
# Epoch 10/150
# 545/545 [==============================] - 13s 25ms/step - loss: 608912832.0000 - mae: 24652.2363 - val_loss: 590385344.0000 - val_mae: 24136.6211
# Epoch 11/150
# 545/545 [==============================] - 14s 25ms/step - loss: 574660160.0000 - mae: 23954.7812 - val_loss: 560034624.0000 - val_mae: 23504.5508
# Epoch 12/150
# 545/545 [==============================] - 14s 25ms/step - loss: 539473216.0000 - mae: 23210.5801 - val_loss: 525660032.0000 - val_mae: 22740.6934
# Epoch 13/150
# 545/545 [==============================] - 14s 25ms/step - loss: 503320448.0000 - mae: 22418.5898 - val_loss: 494470080.0000 - val_mae: 22063.8379
# Epoch 14/150
# 545/545 [==============================] - 14s 25ms/step - loss: 466503584.0000 - mae: 21581.1973 - val_loss: 432069952.0000 - val_mae: 20578.4785
# Epoch 15/150
# 545/545 [==============================] - 14s 25ms/step - loss: 429301504.0000 - mae: 20701.9844 - val_loss: 407058880.0000 - val_mae: 19979.4238
# Epoch 16/150
# 545/545 [==============================] - 13s 25ms/step - loss: 391999520.0000 - mae: 19781.6289 - val_loss: 374648768.0000 - val_mae: 19163.0566
# Epoch 17/150
# 545/545 [==============================] - 14s 25ms/step - loss: 354944960.0000 - mae: 18822.5801 - val_loss: 327735328.0000 - val_mae: 17898.4766
# Epoch 18/150
# 545/545 [==============================] - 14s 25ms/step - loss: 318440256.0000 - mae: 17827.2324 - val_loss: 295322944.0000 - val_mae: 16974.1094
# Epoch 19/150
# 545/545 [==============================] - 14s 26ms/step - loss: 282865600.0000 - mae: 16796.7188 - val_loss: 258498480.0000 - val_mae: 15839.0811
# Epoch 20/150
# 545/545 [==============================] - 14s 25ms/step - loss: 248206688.0000 - mae: 15735.1250 - val_loss: 224388880.0000 - val_mae: 14713.9102
# Epoch 21/150
# 545/545 [==============================] - 14s 26ms/step - loss: 215039808.0000 - mae: 14643.3721 - val_loss: 194704560.0000 - val_mae: 13674.4531
# Epoch 22/150
# 545/545 [==============================] - 14s 25ms/step - loss: 183601392.0000 - mae: 13525.5889 - val_loss: 172647280.0000 - val_mae: 12807.9639
# Epoch 23/150
# 545/545 [==============================] - 13s 25ms/step - loss: 154021776.0000 - mae: 12386.3232 - val_loss: 139198672.0000 - val_mae: 11467.0098
# Epoch 24/150
# 545/545 [==============================] - 14s 25ms/step - loss: 126631656.0000 - mae: 11227.8789 - val_loss: 112391976.0000 - val_mae: 10209.4434
# Epoch 25/150
# 545/545 [==============================] - 14s 25ms/step - loss: 101751032.0000 - mae: 10057.6025 - val_loss: 87805456.0000 - val_mae: 8923.2900
# Epoch 26/150
# 545/545 [==============================] - 14s 25ms/step - loss: 79489360.0000 - mae: 8882.1484 - val_loss: 71183104.0000 - val_mae: 8012.0010
# Epoch 27/150
# 545/545 [==============================] - 14s 25ms/step - loss: 59981052.0000 - mae: 7709.4912 - val_loss: 54501444.0000 - val_mae: 6903.5063
# Epoch 28/150
# 545/545 [==============================] - 13s 25ms/step - loss: 43618700.0000 - mae: 6548.4932 - val_loss: 40888936.0000 - val_mae: 5837.1963
# Epoch 29/150
# 545/545 [==============================] - 13s 24ms/step - loss: 29851468.0000 - mae: 5415.8682 - val_loss: 30858946.0000 - val_mae: 4956.6035
# Epoch 30/150
# 545/545 [==============================] - 13s 25ms/step - loss: 19252708.0000 - mae: 4329.2725 - val_loss: 21955310.0000 - val_mae: 4075.4873
# Epoch 31/150
# 545/545 [==============================] - 13s 24ms/step - loss: 11421378.0000 - mae: 3303.9412 - val_loss: 15422578.0000 - val_mae: 3251.6414
# Epoch 32/150
# 545/545 [==============================] - 14s 25ms/step - loss: 6122803.5000 - mae: 2379.6873 - val_loss: 11191819.0000 - val_mae: 2663.7070
# Epoch 33/150
# 545/545 [==============================] - 13s 25ms/step - loss: 2942625.5000 - mae: 1587.5483 - val_loss: 8801075.0000 - val_mae: 2261.7385
# Epoch 34/150
# 545/545 [==============================] - 13s 25ms/step - loss: 1423841.6250 - mae: 1012.1367 - val_loss: 10228607.0000 - val_mae: 2381.3777
# Epoch 35/150
# 545/545 [==============================] - 14s 25ms/step - loss: 759073.8125 - mae: 678.2709 - val_loss: 8439124.0000 - val_mae: 2094.9587
# Epoch 36/150
# 545/545 [==============================] - 13s 25ms/step - loss: 435367.3750 - mae: 510.9962 - val_loss: 8491696.0000 - val_mae: 2084.2607
# Epoch 37/150
# 545/545 [==============================] - 13s 25ms/step - loss: 464465.5312 - mae: 519.0013 - val_loss: 8593034.0000 - val_mae: 2097.1587
# Epoch 38/150
# 545/545 [==============================] - 13s 25ms/step - loss: 442209.5312 - mae: 499.2236 - val_loss: 9691301.0000 - val_mae: 2236.5261
# Epoch 39/150
# 545/545 [==============================] - 14s 25ms/step - loss: 452506.7500 - mae: 509.4938 - val_loss: 10070801.0000 - val_mae: 2263.0891
# Epoch 40/150
# 545/545 [==============================] - 14s 25ms/step - loss: 390487.9375 - mae: 479.7370 - val_loss: 8577945.0000 - val_mae: 2079.8733
# Epoch 41/150
# 545/545 [==============================] - 13s 24ms/step - loss: 548578.5625 - mae: 554.3336 - val_loss: 7513584.0000 - val_mae: 1977.7096
# Epoch 42/150
# 545/545 [==============================] - 13s 24ms/step - loss: 371029.7812 - mae: 466.7148 - val_loss: 7646876.0000 - val_mae: 2013.1270
# Epoch 43/150
# 545/545 [==============================] - 13s 24ms/step - loss: 384098.1250 - mae: 477.5138 - val_loss: 7619565.5000 - val_mae: 1998.5099
# Epoch 44/150
# 545/545 [==============================] - 14s 25ms/step - loss: 434523.8125 - mae: 501.2762 - val_loss: 7034001.5000 - val_mae: 1954.6223
# Epoch 45/150
# 545/545 [==============================] - 13s 24ms/step - loss: 408896.3750 - mae: 485.6128 - val_loss: 9000974.0000 - val_mae: 2208.1826
# Epoch 46/150
# 545/545 [==============================] - 14s 25ms/step - loss: 458061.5625 - mae: 506.5018 - val_loss: 7712662.5000 - val_mae: 2009.0305
# Epoch 47/150
# 545/545 [==============================] - 13s 25ms/step - loss: 376581.7188 - mae: 468.4906 - val_loss: 7372660.0000 - val_mae: 2014.9799
# Epoch 48/150
# 545/545 [==============================] - 14s 25ms/step - loss: 412177.1250 - mae: 490.2080 - val_loss: 7238182.0000 - val_mae: 1941.0262
# Epoch 49/150
# 545/545 [==============================] - 13s 24ms/step - loss: 385268.0312 - mae: 466.1140 - val_loss: 7483097.0000 - val_mae: 1955.5920
# Epoch 50/150
# 545/545 [==============================] - 13s 25ms/step - loss: 370023.3438 - mae: 464.0469 - val_loss: 7893525.5000 - val_mae: 2027.2197
# Epoch 51/150
# 545/545 [==============================] - 13s 24ms/step - loss: 600625.6250 - mae: 562.5753 - val_loss: 6795381.5000 - val_mae: 1853.6759
# Epoch 52/150
# 545/545 [==============================] - 13s 24ms/step - loss: 396836.2500 - mae: 479.2919 - val_loss: 6981046.0000 - val_mae: 1889.1770
# Epoch 53/150
# 545/545 [==============================] - 13s 25ms/step - loss: 338074.5938 - mae: 443.6157 - val_loss: 6574249.5000 - val_mae: 1826.9647
# Epoch 54/150
# 545/545 [==============================] - 13s 24ms/step - loss: 414630.9688 - mae: 486.9709 - val_loss: 7108029.0000 - val_mae: 1925.5258
# Epoch 55/150
# 545/545 [==============================] - 14s 25ms/step - loss: 405953.8125 - mae: 479.6611 - val_loss: 6836761.5000 - val_mae: 1915.1353
# Epoch 56/150
# 545/545 [==============================] - 14s 25ms/step - loss: 354458.2500 - mae: 457.0875 - val_loss: 6811292.0000 - val_mae: 1867.7910
# Epoch 57/150
# 545/545 [==============================] - 13s 25ms/step - loss: 368751.6250 - mae: 464.0786 - val_loss: 6792592.0000 - val_mae: 1886.7799
# Epoch 58/150
# 545/545 [==============================] - 13s 25ms/step - loss: 385737.4375 - mae: 470.2658 - val_loss: 8039000.0000 - val_mae: 2020.5627
# Epoch 59/150
# 545/545 [==============================] - 14s 25ms/step - loss: 443713.7500 - mae: 496.4689 - val_loss: 7696653.5000 - val_mae: 1978.4412
# Epoch 60/150
# 545/545 [==============================] - 13s 25ms/step - loss: 358435.8750 - mae: 461.7596 - val_loss: 7286595.0000 - val_mae: 1949.8331
# Epoch 61/150
# 545/545 [==============================] - 13s 25ms/step - loss: 384116.3750 - mae: 466.8629 - val_loss: 7229148.0000 - val_mae: 1913.1318
# Epoch 62/150
# 545/545 [==============================] - 14s 25ms/step - loss: 338435.1875 - mae: 444.5578 - val_loss: 6700093.0000 - val_mae: 1830.8372
# Epoch 63/150
# 545/545 [==============================] - 13s 24ms/step - loss: 346655.5000 - mae: 451.6004 - val_loss: 7101110.0000 - val_mae: 1863.8210
# Epoch 64/150
# 545/545 [==============================] - 13s 25ms/step - loss: 312629.8750 - mae: 430.6487 - val_loss: 7099505.5000 - val_mae: 1884.9382
# Epoch 65/150
# 545/545 [==============================] - 13s 24ms/step - loss: 413412.8125 - mae: 480.4597 - val_loss: 6709544.5000 - val_mae: 1835.5404
# Epoch 66/150
# 545/545 [==============================] - 13s 24ms/step - loss: 437979.6250 - mae: 494.9835 - val_loss: 6868289.0000 - val_mae: 1888.1838
# Epoch 67/150
# 545/545 [==============================] - 13s 24ms/step - loss: 374050.4688 - mae: 468.4757 - val_loss: 6428996.0000 - val_mae: 1820.8724
# Epoch 68/150
# 545/545 [==============================] - 13s 25ms/step - loss: 328119.9688 - mae: 445.5977 - val_loss: 6436578.5000 - val_mae: 1816.7467
# Epoch 69/150
# 545/545 [==============================] - 13s 24ms/step - loss: 307058.3750 - mae: 427.6122 - val_loss: 6393864.5000 - val_mae: 1796.8961
# Epoch 70/150
# 545/545 [==============================] - 13s 24ms/step - loss: 357991.4062 - mae: 455.6074 - val_loss: 6185141.5000 - val_mae: 1761.3599
# Epoch 71/150
# 545/545 [==============================] - 13s 24ms/step - loss: 398287.5625 - mae: 474.0675 - val_loss: 8513288.0000 - val_mae: 2083.6990
# Epoch 72/150
# 545/545 [==============================] - 13s 24ms/step - loss: 358509.6875 - mae: 461.0851 - val_loss: 7712669.5000 - val_mae: 1984.0353
# Epoch 73/150
# 545/545 [==============================] - 14s 25ms/step - loss: 394498.8438 - mae: 473.2270 - val_loss: 7395387.0000 - val_mae: 1982.8397
# Epoch 74/150
# 545/545 [==============================] - 13s 25ms/step - loss: 409834.1875 - mae: 489.0238 - val_loss: 6762577.0000 - val_mae: 1870.0958
# Epoch 75/150
# 545/545 [==============================] - 13s 25ms/step - loss: 374087.4375 - mae: 462.1125 - val_loss: 7013835.5000 - val_mae: 1905.4454
# Epoch 76/150
# 545/545 [==============================] - 13s 24ms/step - loss: 367336.0938 - mae: 458.4187 - val_loss: 6612935.0000 - val_mae: 1860.2277
# Epoch 77/150
# 545/545 [==============================] - 13s 25ms/step - loss: 323429.4062 - mae: 439.8408 - val_loss: 6123038.5000 - val_mae: 1778.2562
# Epoch 78/150
# 545/545 [==============================] - 13s 25ms/step - loss: 344172.1250 - mae: 455.5093 - val_loss: 6171939.0000 - val_mae: 1798.8033
# Epoch 79/150
# 545/545 [==============================] - 14s 25ms/step - loss: 497349.1562 - mae: 519.0275 - val_loss: 7102540.5000 - val_mae: 1912.8226
# Epoch 80/150
# 545/545 [==============================] - 13s 24ms/step - loss: 370833.7812 - mae: 467.3094 - val_loss: 6736018.5000 - val_mae: 1877.1003
# Epoch 81/150
# 545/545 [==============================] - 13s 24ms/step - loss: 322079.3750 - mae: 441.0711 - val_loss: 6778854.5000 - val_mae: 1890.0049
# Epoch 82/150
# 545/545 [==============================] - 13s 24ms/step - loss: 320727.0625 - mae: 443.3342 - val_loss: 6883684.0000 - val_mae: 1910.9604
# Epoch 83/150
# 545/545 [==============================] - 13s 25ms/step - loss: 340396.4375 - mae: 450.5720 - val_loss: 6128895.5000 - val_mae: 1758.5784
# Epoch 84/150
# 545/545 [==============================] - 13s 25ms/step - loss: 353505.3125 - mae: 457.7633 - val_loss: 6426837.5000 - val_mae: 1822.1733
# Epoch 85/150
# 545/545 [==============================] - 13s 24ms/step - loss: 277027.2188 - mae: 412.3772 - val_loss: 6521954.0000 - val_mae: 1835.7540
# Epoch 86/150
# 545/545 [==============================] - 13s 24ms/step - loss: 457929.6250 - mae: 502.6761 - val_loss: 7066796.5000 - val_mae: 1915.9806
# Epoch 87/150
# 545/545 [==============================] - 13s 24ms/step - loss: 376927.4375 - mae: 470.4082 - val_loss: 7131835.5000 - val_mae: 1918.7487
# Epoch 88/150
# 545/545 [==============================] - 13s 24ms/step - loss: 314622.9375 - mae: 426.1299 - val_loss: 6517458.5000 - val_mae: 1813.6947
# Epoch 89/150
# 545/545 [==============================] - 13s 25ms/step - loss: 366792.0000 - mae: 462.8961 - val_loss: 7050381.5000 - val_mae: 1977.1976
# Epoch 90/150
# 545/545 [==============================] - 13s 25ms/step - loss: 323676.6562 - mae: 443.1746 - val_loss: 6348090.5000 - val_mae: 1820.8694
# Epoch 91/150
# 545/545 [==============================] - 14s 25ms/step - loss: 300627.1875 - mae: 430.8094 - val_loss: 6390075.5000 - val_mae: 1842.3989
# Epoch 92/150
# 545/545 [==============================] - 13s 25ms/step - loss: 308527.9688 - mae: 434.4183 - val_loss: 6327537.5000 - val_mae: 1825.7062
# Epoch 93/150
# 545/545 [==============================] - 14s 25ms/step - loss: 394220.0000 - mae: 479.1792 - val_loss: 5954950.0000 - val_mae: 1736.6677
# Epoch 94/150
# 545/545 [==============================] - 14s 25ms/step - loss: 475003.5312 - mae: 507.8806 - val_loss: 6380403.5000 - val_mae: 1795.4769
# Epoch 95/150
# 545/545 [==============================] - 13s 24ms/step - loss: 331561.4375 - mae: 440.6375 - val_loss: 6493889.5000 - val_mae: 1818.1277
# Epoch 96/150
# 545/545 [==============================] - 13s 24ms/step - loss: 384924.2188 - mae: 464.8482 - val_loss: 6395329.0000 - val_mae: 1793.5082
# Epoch 97/150
# 545/545 [==============================] - 13s 24ms/step - loss: 338582.5000 - mae: 449.3370 - val_loss: 6221621.0000 - val_mae: 1756.2911
# Epoch 98/150
# 545/545 [==============================] - 14s 25ms/step - loss: 285866.3438 - mae: 419.2774 - val_loss: 6440716.5000 - val_mae: 1791.3102
# Epoch 99/150
# 545/545 [==============================] - 14s 25ms/step - loss: 346461.8438 - mae: 444.9981 - val_loss: 6949090.0000 - val_mae: 1869.3612
# Epoch 100/150
# 545/545 [==============================] - 14s 25ms/step - loss: 305319.1250 - mae: 423.2361 - val_loss: 7017326.5000 - val_mae: 1899.4598
# Epoch 101/150
# 545/545 [==============================] - 13s 25ms/step - loss: 283177.9375 - mae: 419.1118 - val_loss: 6991382.5000 - val_mae: 1847.6741
# Epoch 102/150
# 545/545 [==============================] - 14s 26ms/step - loss: 392965.7812 - mae: 474.8395 - val_loss: 7684576.0000 - val_mae: 1990.6920
# Epoch 103/150
# 545/545 [==============================] - 14s 25ms/step - loss: 448164.2188 - mae: 510.8392 - val_loss: 8106986.5000 - val_mae: 2010.5823
# Epoch 104/150
# 545/545 [==============================] - 14s 26ms/step - loss: 295360.2500 - mae: 423.8560 - val_loss: 7526678.5000 - val_mae: 1961.7523
# Epoch 105/150
# 545/545 [==============================] - 14s 26ms/step - loss: 298924.1562 - mae: 429.9967 - val_loss: 7173547.0000 - val_mae: 1934.9448
# Epoch 106/150
# 545/545 [==============================] - 14s 26ms/step - loss: 286502.5625 - mae: 421.7853 - val_loss: 7326111.0000 - val_mae: 1957.1896
# Epoch 107/150
# 545/545 [==============================] - 14s 25ms/step - loss: 333515.9688 - mae: 445.5895 - val_loss: 7549073.5000 - val_mae: 1970.6101
# Epoch 108/150
# 545/545 [==============================] - 14s 25ms/step - loss: 492492.0938 - mae: 515.6257 - val_loss: 6474817.0000 - val_mae: 1817.0177
# Epoch 109/150
# 545/545 [==============================] - 13s 25ms/step - loss: 497636.9688 - mae: 515.1239 - val_loss: 7301966.5000 - val_mae: 1980.7734
# Epoch 110/150
# 545/545 [==============================] - 13s 24ms/step - loss: 383264.9062 - mae: 474.6783 - val_loss: 7311110.5000 - val_mae: 1954.7247
# Epoch 111/150
# 545/545 [==============================] - 13s 24ms/step - loss: 319750.6875 - mae: 437.7203 - val_loss: 7270659.0000 - val_mae: 1954.1625
# Epoch 112/150
# 545/545 [==============================] - 13s 25ms/step - loss: 293049.2188 - mae: 422.3948 - val_loss: 7439754.5000 - val_mae: 1984.6490
# Epoch 113/150
# 545/545 [==============================] - 13s 25ms/step - loss: 336701.4062 - mae: 447.7958 - val_loss: 7695445.0000 - val_mae: 1943.7438

# %% [markdown]
# Evaluate the training process

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
#
# histEDLSTM = pd.DataFrame(history_ED_LSTM.history)
# histEDLSTM['epoch'] = history_ED_LSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
#
# fig = plot_learning_curves(histEDLSTM,modeltype,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# Load best model

# %%
#Calling back the best model:
model_best_ED_LSTM = keras.models.load_model(f"./{modeltype}/my_best_model_{namespace}.h5")
model_best_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 80)          34240
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 80)          320
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 64)          37120
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64)          256
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 32)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 24, 32)            8320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 32)            128
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 24, 64)            24832
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 24, 80)            46400
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 80)            320
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 1)             81
# =================================================================
# Total params: 164,817
# Trainable params: 164,113
# Non-trainable params: 704
# _________________________________________________________________

# %%
i=1
case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))

Y_test_predictions = pd.Series(model_best_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
y_test_filtered = data_y_test0.loc[Y_test_predictions.index]

# %%
eval_df = create_eval_df(Y_test_predictions,y_test_filtered)

# %%
fig = plot_accuracy(eval_df,modeltype,f"./{modeltype}/accuracy_{namespace}.png")

# %%
abs_error_ED_LSTM = abs(Y_test_predictions - y_test_filtered)/y_test_filtered*100
np.average(abs_error_ED_LSTM)
# Out:
# nan

# %%
r2_test = r2_score(y_test_filtered, Y_test_predictions)
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.32

# %%
fig=plot_predictions(eval_df,1,modeltype,feature,f"./{modeltype}/predictions_{namespace}.png")

# %%
idx_prediction = pd.date_range(start=idx_test[0],freq='h',periods=len(idx_test)+24)
y_test_filtered2 = data_y_test0.loc[idx_prediction]

# %%
fig = go.Figure()
df_pred =pd.DataFrame(index=y_test_filtered2.index)
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=y_test_filtered2[feature]))
for i in range(len(data_x_test)):
    case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
    Y_test_predictions = pd.Series(model_best_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
    df_pred[f'pred_{i}'] = Y_test_predictions
    fig.add_trace(go.Scatter(x = Y_test_predictions.index,y=Y_test_predictions,mode='markers'))

df_pred['mean'] = df_pred.mean(axis=1)
df_pred['median'] = df_pred.median(axis=1)
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=df_pred['mean']))
fig.add_trace(go.Scatter(x = y_test_filtered2.index,y=df_pred['median']))
fig.show()
eval_df2  =create_eval_df(df_pred['mean'],y_test_filtered2)

# %%
r2_test = r2_score(y_test_filtered2[:-1],df_pred['mean'][:-1])
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.62
