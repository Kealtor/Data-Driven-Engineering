# %%
import numpy as np
from datetime import timedelta
import pandas as pd
from pandas.plotting import lag_plot, autocorrelation_plot
from datetime import date
import yaml

import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import matplotlib as mpl

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
import statsmodels.api as smw
from statsmodels.tsa.statespace.sarimax import SARIMAX

from scipy.signal import savgol_filter
import sklearn
from sklearn import preprocessing as pp
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from sklearn.metrics import r2_score

import tensorflow as tf
from tensorflow import keras
from keras import optimizers, models, layers, regularizers
import keras_tuner as kt
tf.__version__
# Out:
# '2.6.0'

# %%
# %load_ext skip_kernel_extension

# %%
from utils.dde_preprocessing_utils import (set_timestamp_index,
remove_duplicates,
remove_columns,
extract_correlations,
prepare_data_sarimax,
create_test_train_split,
create_sarimax_test_train_split,
create_eval_df,
convert_to_sample_time_feature,
convert_from_differencing,
make_multiple_predictions,
calculate_r2_scores,
apply_differencing,
create_split,
apply_savgol_filter)
from utils.dde_plotting_utils import(
display_double_timestamps,
display_seasonal_decomposition,
plot_predictions,
plot_accuracy,
plot_error_variations,
plot_learning_curves,
plot_multiple_predictions,
plot_evaluation
)

# %%
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
mpl.rcParams['figure.figsize'] = [16.0, 8.0]
tf.random.set_seed(2022)

# %%
SKIP_RETRAIN_NN =True
SKIP_RETRAIN_RNN = True
SKIP_RETRAIN_LSTM = True
SKIP_RETRAIN_ED_LSTM = True

# %% [markdown]
# ## Loading Data

# %%
with open('parameter.yaml','r') as f:
    parameter_dict = yaml.safe_load(f)
parameter_dict.keys()
# Out:
# dict_keys(['generation', 'share', 'time', 'weather'])

# %% [markdown]
# Benchmark data set

# %%
# bench_df = pd.read_csv("energy_dataset.csv")
# bench_df = set_timestamp_index(bench_df,"time")
# bench_df = bench_df['price day ahead']
# bench_df = bench_df.rename('Benchmark')

# %% [markdown]
# Base data set

# %%
energy_df = pd.read_csv("energy_dataset_cleaned.csv")
energy_df = set_timestamp_index(energy_df,"Unnamed: 0")

# %%
weather_df = pd.read_csv("weather_dataset_madrid.csv")
weather_df = set_timestamp_index(weather_df,"Unnamed: 0")

# %%
additional_feature_df = pd.read_csv("additional_feature_dataset.csv")
additional_feature_df = set_timestamp_index(additional_feature_df,"Unnamed: 0")

# %%
transfer_df = pd.read_csv("transfer_dataset_cleaned.csv")
transfer_df = set_timestamp_index(transfer_df,"Unnamed: 0")

# %%
time_df = pd.read_csv("time_dataset.csv")
time_df = set_timestamp_index(time_df,"Unnamed: 0")

# %%
base_df = pd.concat([energy_df,weather_df,additional_feature_df,transfer_df],axis=1)

# %%
base_df
# Out:
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               447.0
# 2015-01-01 01:00:00+01:00               449.0
# 2015-01-01 02:00:00+01:00               448.0
# 2015-01-01 03:00:00+01:00               438.0
# 2015-01-01 04:00:00+01:00               428.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               297.0
# 2018-12-31 20:00:00+01:00               296.0
# 2018-12-31 21:00:00+01:00               292.0
# 2018-12-31 22:00:00+01:00               293.0
# 2018-12-31 23:00:00+01:00               290.0
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 329.0
# 2015-01-01 01:00:00+01:00                                 328.0
# 2015-01-01 02:00:00+01:00                                 323.0
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 04:00:00+01:00                                 187.0
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00                 4844.0                       4821.0
# 2015-01-01 01:00:00+01:00                 5196.0                       4755.0
# 2015-01-01 02:00:00+01:00                 4857.0                       4581.0
# 2015-01-01 03:00:00+01:00                 4314.0                       4131.0
# 2015-01-01 04:00:00+01:00                 4130.0                       3840.0
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7634.0                       2628.0
# 2018-12-31 20:00:00+01:00                 7241.0                       2566.0
# 2018-12-31 21:00:00+01:00                 7025.0                       2422.0
# 2018-12-31 22:00:00+01:00                 6562.0                       2293.0
# 2018-12-31 23:00:00+01:00                 6926.0                       2166.0
#
#                            generation fossil oil  \
# 2015-01-01 00:00:00+01:00                  162.0
# 2015-01-01 01:00:00+01:00                  158.0
# 2015-01-01 02:00:00+01:00                  157.0
# 2015-01-01 03:00:00+01:00                  160.0
# 2015-01-01 04:00:00+01:00                  156.0
# ...                                          ...
# 2018-12-31 19:00:00+01:00                  178.0
# 2018-12-31 20:00:00+01:00                  174.0
# 2018-12-31 21:00:00+01:00                  168.0
# 2018-12-31 22:00:00+01:00                  163.0
# 2018-12-31 23:00:00+01:00                  163.0
#
#                            generation hydro pumped storage  \
# 2015-01-01 00:00:00+01:00                            863.0
# 2015-01-01 01:00:00+01:00                            920.0
# 2015-01-01 02:00:00+01:00                           1164.0
# 2015-01-01 03:00:00+01:00                           1503.0
# 2015-01-01 04:00:00+01:00                           1826.0
# ...                                                    ...
# 2018-12-31 19:00:00+01:00                              1.0
# 2018-12-31 20:00:00+01:00                              1.0
# 2018-12-31 21:00:00+01:00                             50.0
# 2018-12-31 22:00:00+01:00                            108.0
# 2018-12-31 23:00:00+01:00                            108.0
#
#                            generation hydro run-of-river and poundage  \
# 2015-01-01 00:00:00+01:00                                      1051.0
# 2015-01-01 01:00:00+01:00                                      1009.0
# 2015-01-01 02:00:00+01:00                                       973.0
# 2015-01-01 03:00:00+01:00                                       949.0
# 2015-01-01 04:00:00+01:00                                       953.0
# ...                                                               ...
# 2018-12-31 19:00:00+01:00                                      1135.0
# 2018-12-31 20:00:00+01:00                                      1172.0
# 2018-12-31 21:00:00+01:00                                      1148.0
# 2018-12-31 22:00:00+01:00                                      1128.0
# 2018-12-31 23:00:00+01:00                                      1069.0
#
#                            generation hydro water reservoir  \
# 2015-01-01 00:00:00+01:00                            1899.0
# 2015-01-01 01:00:00+01:00                            1658.0
# 2015-01-01 02:00:00+01:00                            1371.0
# 2015-01-01 03:00:00+01:00                             779.0
# 2015-01-01 04:00:00+01:00                             720.0
# ...                                                     ...
# 2018-12-31 19:00:00+01:00                            4836.0
# 2018-12-31 20:00:00+01:00                            3931.0
# 2018-12-31 21:00:00+01:00                            2831.0
# 2018-12-31 22:00:00+01:00                            2068.0
# 2018-12-31 23:00:00+01:00                            1686.0
#
#                            generation nuclear  generation other  ...  \
# 2015-01-01 00:00:00+01:00              7096.0              43.0  ...
# 2015-01-01 01:00:00+01:00              7096.0              43.0  ...
# 2015-01-01 02:00:00+01:00              7099.0              43.0  ...
# 2015-01-01 03:00:00+01:00              7098.0              43.0  ...
# 2015-01-01 04:00:00+01:00              7097.0              43.0  ...
# ...                                       ...               ...  ...
# 2018-12-31 19:00:00+01:00              6073.0              63.0  ...
# 2018-12-31 20:00:00+01:00              6074.0              62.0  ...
# 2018-12-31 21:00:00+01:00              6076.0              61.0  ...
# 2018-12-31 22:00:00+01:00              6075.0              61.0  ...
# 2018-12-31 23:00:00+01:00              6075.0              61.0  ...
#
#                            share hydro run-of-river and poundage  \
# 2015-01-01 00:00:00+01:00                               0.037202
# 2015-01-01 01:00:00+01:00                               0.036271
# 2015-01-01 02:00:00+01:00                               0.036311
# 2015-01-01 03:00:00+01:00                               0.037624
# 2015-01-01 04:00:00+01:00                               0.038708
# ...                                                          ...
# 2018-12-31 19:00:00+01:00                               0.042968
# 2018-12-31 20:00:00+01:00                               0.046484
# 2018-12-31 21:00:00+01:00                               0.047859
# 2018-12-31 22:00:00+01:00                               0.049587
# 2018-12-31 23:00:00+01:00                               0.047290
#
#                            share hydro water reservoir  share nuclear  \
# 2015-01-01 00:00:00+01:00                     0.067219       0.251177
# 2015-01-01 01:00:00+01:00                     0.059602       0.255087
# 2015-01-01 02:00:00+01:00                     0.051164       0.264928
# 2015-01-01 03:00:00+01:00                     0.030885       0.281410
# 2015-01-01 04:00:00+01:00                     0.029245       0.288262
# ...                                                ...            ...
# 2018-12-31 19:00:00+01:00                     0.183078       0.229907
# 2018-12-31 20:00:00+01:00                     0.155912       0.240907
# 2018-12-31 21:00:00+01:00                     0.118022       0.253304
# 2018-12-31 22:00:00+01:00                     0.090909       0.267056
# 2018-12-31 23:00:00+01:00                     0.074585       0.268746
#
#                            share other  share other renewable  share solar  \
# 2015-01-01 00:00:00+01:00     0.001522               0.002584     0.001734
# 2015-01-01 01:00:00+01:00     0.001546               0.002552     0.001797
# 2015-01-01 02:00:00+01:00     0.001605               0.002724     0.001866
# 2015-01-01 03:00:00+01:00     0.001705               0.002973     0.001982
# 2015-01-01 04:00:00+01:00     0.001747               0.003006     0.001706
# ...                                ...                    ...          ...
# 2018-12-31 19:00:00+01:00     0.002385               0.003596     0.003218
# 2018-12-31 20:00:00+01:00     0.002459               0.003768     0.001309
# 2018-12-31 21:00:00+01:00     0.002543               0.003919     0.001292
# 2018-12-31 22:00:00+01:00     0.002682               0.004088     0.001363
# 2018-12-31 23:00:00+01:00     0.002699               0.004070     0.001371
#
#                            share waste  share wind onshore  \
# 2015-01-01 00:00:00+01:00     0.006938            0.225762
# 2015-01-01 01:00:00+01:00     0.007010            0.211733
# 2015-01-01 02:00:00+01:00     0.007315            0.203799
# 2015-01-01 03:00:00+01:00     0.007572            0.207668
# 2015-01-01 04:00:00+01:00     0.007677            0.200447
# ...                                ...                 ...
# 2018-12-31 19:00:00+01:00     0.010486            0.117850
# 2018-12-31 20:00:00+01:00     0.011105            0.130409
# 2018-12-31 21:00:00+01:00     0.011923            0.146037
# 2018-12-31 22:00:00+01:00     0.012616            0.157640
# 2018-12-31 23:00:00+01:00     0.012696            0.161513
#
#                            energy_exchange_PT  energy_exchange_FR
# 2015-01-01 00:00:00+01:00              -285.0               933.0
# 2015-01-01 01:00:00+01:00                53.0              1119.0
# 2015-01-01 02:00:00+01:00               682.0               954.0
# 2015-01-01 03:00:00+01:00               976.0                13.0
# 2015-01-01 04:00:00+01:00              1011.0              -238.0
# ...                                       ...                 ...
# 2018-12-31 19:00:00+01:00             -1102.0             -3232.0
# 2018-12-31 20:00:00+01:00             -1099.0             -3377.0
# 2018-12-31 21:00:00+01:00             -1329.0             -3460.0
# 2018-12-31 22:00:00+01:00              -937.0             -3429.0
# 2018-12-31 23:00:00+01:00                25.0             -3416.0
#
# [35064 rows x 40 columns]

# %% [markdown]
# Apply Savitzky Golay Filter

# %%
savgol_df = apply_savgol_filter(base_df,5,1)

# %%
savgol_df
# Out:
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               451.8
# 2015-01-01 01:00:00+01:00               446.9
# 2015-01-01 02:00:00+01:00               442.0
# 2015-01-01 03:00:00+01:00               434.6
# 2015-01-01 04:00:00+01:00               425.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               295.2
# 2018-12-31 20:00:00+01:00               294.2
# 2018-12-31 21:00:00+01:00               293.6
# 2018-12-31 22:00:00+01:00               291.9
# 2018-12-31 23:00:00+01:00               290.2
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 355.8
# 2015-01-01 01:00:00+01:00                                 320.0
# 2015-01-01 02:00:00+01:00                                 284.2
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 04:00:00+01:00                                 222.8
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00                 5130.2                       4942.8
# 2015-01-01 01:00:00+01:00                 4899.2                       4684.2
# 2015-01-01 02:00:00+01:00                 4668.2                       4425.6
# 2015-01-01 03:00:00+01:00                 4507.0                       4179.4
# 2015-01-01 04:00:00+01:00                 4275.8                       3902.0
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7277.0                       2560.6
# 2018-12-31 20:00:00+01:00                 7211.0                       2502.6
# 2018-12-31 21:00:00+01:00                 7077.6                       2415.0
# 2018-12-31 22:00:00+01:00                 6868.1                       2295.3
# 2018-12-31 23:00:00+01:00                 6658.6                       2175.6
#
#                            generation fossil oil  \
# 2015-01-01 00:00:00+01:00                  160.6
# 2015-01-01 01:00:00+01:00                  159.6
# 2015-01-01 02:00:00+01:00                  158.6
# 2015-01-01 03:00:00+01:00                  157.4
# 2015-01-01 04:00:00+01:00                  157.4
# ...                                          ...
# 2018-12-31 19:00:00+01:00                  175.0
# 2018-12-31 20:00:00+01:00                  172.2
# 2018-12-31 21:00:00+01:00                  169.2
# 2018-12-31 22:00:00+01:00                  165.1
# 2018-12-31 23:00:00+01:00                  161.0
#
#                            generation hydro pumped storage  \
# 2015-01-01 00:00:00+01:00                            753.4
# 2015-01-01 01:00:00+01:00                           1004.3
# 2015-01-01 02:00:00+01:00                           1255.2
# 2015-01-01 03:00:00+01:00                           1504.4
# 2015-01-01 04:00:00+01:00                           1742.0
# ...                                                    ...
# 2018-12-31 19:00:00+01:00                             35.4
# 2018-12-31 20:00:00+01:00                             32.2
# 2018-12-31 21:00:00+01:00                             53.6
# 2018-12-31 22:00:00+01:00                             85.7
# 2018-12-31 23:00:00+01:00                            117.8
#
#                            generation hydro run-of-river and poundage  \
# 2015-01-01 00:00:00+01:00                                      1038.2
# 2015-01-01 01:00:00+01:00                                      1012.6
# 2015-01-01 02:00:00+01:00                                       987.0
# 2015-01-01 03:00:00+01:00                                       967.2
# 2015-01-01 04:00:00+01:00                                       957.6
# ...                                                               ...
# 2018-12-31 19:00:00+01:00                                      1134.8
# 2018-12-31 20:00:00+01:00                                      1142.8
# 2018-12-31 21:00:00+01:00                                      1130.4
# 2018-12-31 22:00:00+01:00                                      1112.8
# 2018-12-31 23:00:00+01:00                                      1095.2
#
#                            generation hydro water reservoir  \
# 2015-01-01 00:00:00+01:00                            1932.8
# 2015-01-01 01:00:00+01:00                            1609.1
# 2015-01-01 02:00:00+01:00                            1285.4
# 2015-01-01 03:00:00+01:00                            1054.2
# 2015-01-01 04:00:00+01:00                             892.2
# ...                                                     ...
# 2018-12-31 19:00:00+01:00                            3653.4
# 2018-12-31 20:00:00+01:00                            3534.2
# 2018-12-31 21:00:00+01:00                            3070.4
# 2018-12-31 22:00:00+01:00                            2254.1
# 2018-12-31 23:00:00+01:00                            1437.8
#
#                            generation nuclear  generation other  ...  \
# 2015-01-01 00:00:00+01:00              7096.4              43.0  ...
# 2015-01-01 01:00:00+01:00              7096.8              43.0  ...
# 2015-01-01 02:00:00+01:00              7097.2              43.0  ...
# 2015-01-01 03:00:00+01:00              7097.6              43.0  ...
# 2015-01-01 04:00:00+01:00              7098.0              43.0  ...
# ...                                       ...               ...  ...
# 2018-12-31 19:00:00+01:00              6073.4              61.6  ...
# 2018-12-31 20:00:00+01:00              6074.0              61.6  ...
# 2018-12-31 21:00:00+01:00              6074.6              61.6  ...
# 2018-12-31 22:00:00+01:00              6075.1              61.1  ...
# 2018-12-31 23:00:00+01:00              6075.6              60.6  ...
#
#                            share hydro run-of-river and poundage  \
# 2015-01-01 00:00:00+01:00                               0.036351
# 2015-01-01 01:00:00+01:00                               0.036787
# 2015-01-01 02:00:00+01:00                               0.037224
# 2015-01-01 03:00:00+01:00                               0.037641
# 2015-01-01 04:00:00+01:00                               0.038432
# ...                                                          ...
# 2018-12-31 19:00:00+01:00                               0.045304
# 2018-12-31 20:00:00+01:00                               0.046237
# 2018-12-31 21:00:00+01:00                               0.046838
# 2018-12-31 22:00:00+01:00                               0.048012
# 2018-12-31 23:00:00+01:00                               0.049187
#
#                            share hydro water reservoir  share nuclear  \
# 2015-01-01 00:00:00+01:00                     0.068556       0.248074
# 2015-01-01 01:00:00+01:00                     0.058089       0.258123
# 2015-01-01 02:00:00+01:00                     0.047623       0.268173
# 2015-01-01 03:00:00+01:00                     0.040312       0.276523
# 2015-01-01 04:00:00+01:00                     0.035491       0.284933
# ...                                                ...            ...
# 2018-12-31 19:00:00+01:00                     0.144767       0.242519
# 2018-12-31 20:00:00+01:00                     0.140950       0.245790
# 2018-12-31 21:00:00+01:00                     0.124501       0.251984
# 2018-12-31 22:00:00+01:00                     0.096302       0.262367
# 2018-12-31 23:00:00+01:00                     0.068104       0.272749
#
#                            share other  share other renewable  share solar  \
# 2015-01-01 00:00:00+01:00     0.001503               0.002515     0.001792
# 2015-01-01 01:00:00+01:00     0.001564               0.002641     0.001804
# 2015-01-01 02:00:00+01:00     0.001625               0.002768     0.001817
# 2015-01-01 03:00:00+01:00     0.001675               0.002862     0.001751
# 2015-01-01 04:00:00+01:00     0.001726               0.002971     0.001676
# ...                                ...                    ...          ...
# 2018-12-31 19:00:00+01:00     0.002459               0.003762     0.014147
# 2018-12-31 20:00:00+01:00     0.002491               0.003795     0.003520
# 2018-12-31 21:00:00+01:00     0.002553               0.003888     0.001711
# 2018-12-31 22:00:00+01:00     0.002638               0.004015     0.001347
# 2018-12-31 23:00:00+01:00     0.002723               0.004142     0.000983
#
#                            share waste  share wind onshore  \
# 2015-01-01 00:00:00+01:00     0.006894            0.220821
# 2015-01-01 01:00:00+01:00     0.007098            0.215351
# 2015-01-01 02:00:00+01:00     0.007302            0.209882
# 2015-01-01 03:00:00+01:00     0.007466            0.202846
# 2015-01-01 04:00:00+01:00     0.007622            0.197313
# ...                                ...                 ...
# 2018-12-31 19:00:00+01:00     0.011411            0.123036
# 2018-12-31 20:00:00+01:00     0.011490            0.133507
# 2018-12-31 21:00:00+01:00     0.011766            0.142690
# 2018-12-31 22:00:00+01:00     0.012359            0.154146
# 2018-12-31 23:00:00+01:00     0.012952            0.165601
#
#                            energy_exchange_PT  energy_exchange_FR
# 2015-01-01 00:00:00+01:00              -215.6              1245.8
# 2015-01-01 01:00:00+01:00               135.9               901.0
# 2015-01-01 02:00:00+01:00               487.4               556.2
# 2015-01-01 03:00:00+01:00               759.2               178.6
# 2015-01-01 04:00:00+01:00               933.8              -297.2
# ...                                       ...                 ...
# 2018-12-31 19:00:00+01:00              -871.0             -2831.8
# 2018-12-31 20:00:00+01:00             -1213.6             -2892.2
# 2018-12-31 21:00:00+01:00              -888.4             -3382.8
# 2018-12-31 22:00:00+01:00              -646.8             -3424.8
# 2018-12-31 23:00:00+01:00              -405.2             -3466.8
#
# [35064 rows x 40 columns]

# %%
def apply_rolling_mean_std(df, window):
    mean_df = df.rolling(window).mean()
    std_df = df.rolling(window).std()
    rename_map_mean = {}
    rename_map_std = {}
    for col in df.columns:
        rename_map_mean[col] = col + "_mean_" + str(window)
        rename_map_std[col] = col + "_std_" + str(window)
    mean_df.rename(columns=rename_map_mean,inplace=True)
    std_df.rename(columns=rename_map_std,inplace=True)
    stat_df = pd.concat([mean_df,std_df],axis=1)
    return stat_df

# %%
base_24 = apply_rolling_mean_std(savgol_df[['price actual']],24)
base_48 = apply_rolling_mean_std(savgol_df[['price actual']],48)
base_168 = apply_rolling_mean_std(savgol_df[['price actual']],24*7)
base_336 = apply_rolling_mean_std(savgol_df[['price actual']],24*14)

# %%
extended_df = pd.concat([savgol_df,base_24,base_48,base_168,base_336],axis=1)#
extended_df
# Out:
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               451.8
# 2015-01-01 01:00:00+01:00               446.9
# 2015-01-01 02:00:00+01:00               442.0
# 2015-01-01 03:00:00+01:00               434.6
# 2015-01-01 04:00:00+01:00               425.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               295.2
# 2018-12-31 20:00:00+01:00               294.2
# 2018-12-31 21:00:00+01:00               293.6
# 2018-12-31 22:00:00+01:00               291.9
# 2018-12-31 23:00:00+01:00               290.2
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 355.8
# 2015-01-01 01:00:00+01:00                                 320.0
# 2015-01-01 02:00:00+01:00                                 284.2
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 04:00:00+01:00                                 222.8
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00                 5130.2                       4942.8
# 2015-01-01 01:00:00+01:00                 4899.2                       4684.2
# 2015-01-01 02:00:00+01:00                 4668.2                       4425.6
# 2015-01-01 03:00:00+01:00                 4507.0                       4179.4
# 2015-01-01 04:00:00+01:00                 4275.8                       3902.0
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7277.0                       2560.6
# 2018-12-31 20:00:00+01:00                 7211.0                       2502.6
# 2018-12-31 21:00:00+01:00                 7077.6                       2415.0
# 2018-12-31 22:00:00+01:00                 6868.1                       2295.3
# 2018-12-31 23:00:00+01:00                 6658.6                       2175.6
#
#                            generation fossil oil  \
# 2015-01-01 00:00:00+01:00                  160.6
# 2015-01-01 01:00:00+01:00                  159.6
# 2015-01-01 02:00:00+01:00                  158.6
# 2015-01-01 03:00:00+01:00                  157.4
# 2015-01-01 04:00:00+01:00                  157.4
# ...                                          ...
# 2018-12-31 19:00:00+01:00                  175.0
# 2018-12-31 20:00:00+01:00                  172.2
# 2018-12-31 21:00:00+01:00                  169.2
# 2018-12-31 22:00:00+01:00                  165.1
# 2018-12-31 23:00:00+01:00                  161.0
#
#                            generation hydro pumped storage  \
# 2015-01-01 00:00:00+01:00                            753.4
# 2015-01-01 01:00:00+01:00                           1004.3
# 2015-01-01 02:00:00+01:00                           1255.2
# 2015-01-01 03:00:00+01:00                           1504.4
# 2015-01-01 04:00:00+01:00                           1742.0
# ...                                                    ...
# 2018-12-31 19:00:00+01:00                             35.4
# 2018-12-31 20:00:00+01:00                             32.2
# 2018-12-31 21:00:00+01:00                             53.6
# 2018-12-31 22:00:00+01:00                             85.7
# 2018-12-31 23:00:00+01:00                            117.8
#
#                            generation hydro run-of-river and poundage  \
# 2015-01-01 00:00:00+01:00                                      1038.2
# 2015-01-01 01:00:00+01:00                                      1012.6
# 2015-01-01 02:00:00+01:00                                       987.0
# 2015-01-01 03:00:00+01:00                                       967.2
# 2015-01-01 04:00:00+01:00                                       957.6
# ...                                                               ...
# 2018-12-31 19:00:00+01:00                                      1134.8
# 2018-12-31 20:00:00+01:00                                      1142.8
# 2018-12-31 21:00:00+01:00                                      1130.4
# 2018-12-31 22:00:00+01:00                                      1112.8
# 2018-12-31 23:00:00+01:00                                      1095.2
#
#                            generation hydro water reservoir  \
# 2015-01-01 00:00:00+01:00                            1932.8
# 2015-01-01 01:00:00+01:00                            1609.1
# 2015-01-01 02:00:00+01:00                            1285.4
# 2015-01-01 03:00:00+01:00                            1054.2
# 2015-01-01 04:00:00+01:00                             892.2
# ...                                                     ...
# 2018-12-31 19:00:00+01:00                            3653.4
# 2018-12-31 20:00:00+01:00                            3534.2
# 2018-12-31 21:00:00+01:00                            3070.4
# 2018-12-31 22:00:00+01:00                            2254.1
# 2018-12-31 23:00:00+01:00                            1437.8
#
#                            generation nuclear  generation other  ...  \
# 2015-01-01 00:00:00+01:00              7096.4              43.0  ...
# 2015-01-01 01:00:00+01:00              7096.8              43.0  ...
# 2015-01-01 02:00:00+01:00              7097.2              43.0  ...
# 2015-01-01 03:00:00+01:00              7097.6              43.0  ...
# 2015-01-01 04:00:00+01:00              7098.0              43.0  ...
# ...                                       ...               ...  ...
# 2018-12-31 19:00:00+01:00              6073.4              61.6  ...
# 2018-12-31 20:00:00+01:00              6074.0              61.6  ...
# 2018-12-31 21:00:00+01:00              6074.6              61.6  ...
# 2018-12-31 22:00:00+01:00              6075.1              61.1  ...
# 2018-12-31 23:00:00+01:00              6075.6              60.6  ...
#
#                            energy_exchange_PT  energy_exchange_FR  \
# 2015-01-01 00:00:00+01:00              -215.6              1245.8
# 2015-01-01 01:00:00+01:00               135.9               901.0
# 2015-01-01 02:00:00+01:00               487.4               556.2
# 2015-01-01 03:00:00+01:00               759.2               178.6
# 2015-01-01 04:00:00+01:00               933.8              -297.2
# ...                                       ...                 ...
# 2018-12-31 19:00:00+01:00              -871.0             -2831.8
# 2018-12-31 20:00:00+01:00             -1213.6             -2892.2
# 2018-12-31 21:00:00+01:00              -888.4             -3382.8
# 2018-12-31 22:00:00+01:00              -646.8             -3424.8
# 2018-12-31 23:00:00+01:00              -405.2             -3466.8
#
#                            price actual_mean_24  price actual_std_24  \
# 2015-01-01 00:00:00+01:00                   NaN                  NaN
# 2015-01-01 01:00:00+01:00                   NaN                  NaN
# 2015-01-01 02:00:00+01:00                   NaN                  NaN
# 2015-01-01 03:00:00+01:00                   NaN                  NaN
# 2015-01-01 04:00:00+01:00                   NaN                  NaN
# ...                                         ...                  ...
# 2018-12-31 19:00:00+01:00             68.169167             5.808531
# 2018-12-31 20:00:00+01:00             68.271417             5.909575
# 2018-12-31 21:00:00+01:00             68.325417             5.952362
# 2018-12-31 22:00:00+01:00             68.326875             5.953142
# 2018-12-31 23:00:00+01:00             68.351292             5.956171
#
#                            price actual_mean_48  price actual_std_48  \
# 2015-01-01 00:00:00+01:00                   NaN                  NaN
# 2015-01-01 01:00:00+01:00                   NaN                  NaN
# 2015-01-01 02:00:00+01:00                   NaN                  NaN
# 2015-01-01 03:00:00+01:00                   NaN                  NaN
# 2015-01-01 04:00:00+01:00                   NaN                  NaN
# ...                                         ...                  ...
# 2018-12-31 19:00:00+01:00             66.151042             5.959060
# 2018-12-31 20:00:00+01:00             66.250083             6.067028
# 2018-12-31 21:00:00+01:00             66.326000             6.134889
# 2018-12-31 22:00:00+01:00             66.374229             6.166021
# 2018-12-31 23:00:00+01:00             66.433937             6.180866
#
#                            price actual_mean_168  price actual_std_168  \
# 2015-01-01 00:00:00+01:00                    NaN                   NaN
# 2015-01-01 01:00:00+01:00                    NaN                   NaN
# 2015-01-01 02:00:00+01:00                    NaN                   NaN
# 2015-01-01 03:00:00+01:00                    NaN                   NaN
# 2015-01-01 04:00:00+01:00                    NaN                   NaN
# ...                                          ...                   ...
# 2018-12-31 19:00:00+01:00              67.842774              5.973681
# 2018-12-31 20:00:00+01:00              67.848381              5.979985
# 2018-12-31 21:00:00+01:00              67.852250              5.983417
# 2018-12-31 22:00:00+01:00              67.847839              5.980513
# 2018-12-31 23:00:00+01:00              67.836804              5.976010
#
#                            price actual_mean_336  price actual_std_336
# 2015-01-01 00:00:00+01:00                    NaN                   NaN
# 2015-01-01 01:00:00+01:00                    NaN                   NaN
# 2015-01-01 02:00:00+01:00                    NaN                   NaN
# 2015-01-01 03:00:00+01:00                    NaN                   NaN
# 2015-01-01 04:00:00+01:00                    NaN                   NaN
# ...                                          ...                   ...
# 2018-12-31 19:00:00+01:00              67.682292              5.844615
# 2018-12-31 20:00:00+01:00              67.679220              5.840486
# 2018-12-31 21:00:00+01:00              67.680113              5.841347
# 2018-12-31 22:00:00+01:00              67.688015              5.844580
# 2018-12-31 23:00:00+01:00              67.704199              5.841593
#
# [35064 rows x 48 columns]

# %% [markdown]
# Apply Differencing

# %%
diff_df = apply_differencing(extended_df)

# %%
diff_df
# Out:
#                            generation biomass_diff  \
# 2015-01-01 00:00:00+01:00                      NaN
# 2015-01-01 01:00:00+01:00                     -4.9
# 2015-01-01 02:00:00+01:00                     -4.9
# 2015-01-01 03:00:00+01:00                     -7.4
# 2015-01-01 04:00:00+01:00                     -9.6
# ...                                            ...
# 2018-12-31 19:00:00+01:00                     -1.6
# 2018-12-31 20:00:00+01:00                     -1.0
# 2018-12-31 21:00:00+01:00                     -0.6
# 2018-12-31 22:00:00+01:00                     -1.7
# 2018-12-31 23:00:00+01:00                     -1.7
#
#                            generation fossil brown coal/lignite_diff  \
# 2015-01-01 00:00:00+01:00                                        NaN
# 2015-01-01 01:00:00+01:00                                      -35.8
# 2015-01-01 02:00:00+01:00                                      -35.8
# 2015-01-01 03:00:00+01:00                                      -30.2
# 2015-01-01 04:00:00+01:00                                      -31.2
# ...                                                              ...
# 2018-12-31 19:00:00+01:00                                        0.0
# 2018-12-31 20:00:00+01:00                                        0.0
# 2018-12-31 21:00:00+01:00                                        0.0
# 2018-12-31 22:00:00+01:00                                        0.0
# 2018-12-31 23:00:00+01:00                                        0.0
#
#                            generation fossil gas_diff  \
# 2015-01-01 00:00:00+01:00                         NaN
# 2015-01-01 01:00:00+01:00                      -231.0
# 2015-01-01 02:00:00+01:00                      -231.0
# 2015-01-01 03:00:00+01:00                      -161.2
# 2015-01-01 04:00:00+01:00                      -231.2
# ...                                               ...
# 2018-12-31 19:00:00+01:00                       129.2
# 2018-12-31 20:00:00+01:00                       -66.0
# 2018-12-31 21:00:00+01:00                      -133.4
# 2018-12-31 22:00:00+01:00                      -209.5
# 2018-12-31 23:00:00+01:00                      -209.5
#
#                            generation fossil hard coal_diff  \
# 2015-01-01 00:00:00+01:00                               NaN
# 2015-01-01 01:00:00+01:00                            -258.6
# 2015-01-01 02:00:00+01:00                            -258.6
# 2015-01-01 03:00:00+01:00                            -246.2
# 2015-01-01 04:00:00+01:00                            -277.4
# ...                                                     ...
# 2018-12-31 19:00:00+01:00                             -16.2
# 2018-12-31 20:00:00+01:00                             -58.0
# 2018-12-31 21:00:00+01:00                             -87.6
# 2018-12-31 22:00:00+01:00                            -119.7
# 2018-12-31 23:00:00+01:00                            -119.7
#
#                            generation fossil oil_diff  \
# 2015-01-01 00:00:00+01:00                         NaN
# 2015-01-01 01:00:00+01:00                        -1.0
# 2015-01-01 02:00:00+01:00                        -1.0
# 2015-01-01 03:00:00+01:00                        -1.2
# 2015-01-01 04:00:00+01:00                         0.0
# ...                                               ...
# 2018-12-31 19:00:00+01:00                        -2.0
# 2018-12-31 20:00:00+01:00                        -2.8
# 2018-12-31 21:00:00+01:00                        -3.0
# 2018-12-31 22:00:00+01:00                        -4.1
# 2018-12-31 23:00:00+01:00                        -4.1
#
#                            generation hydro pumped storage_diff  \
# 2015-01-01 00:00:00+01:00                                   NaN
# 2015-01-01 01:00:00+01:00                                 250.9
# 2015-01-01 02:00:00+01:00                                 250.9
# 2015-01-01 03:00:00+01:00                                 249.2
# 2015-01-01 04:00:00+01:00                                 237.6
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                 -54.6
# 2018-12-31 20:00:00+01:00                                  -3.2
# 2018-12-31 21:00:00+01:00                                  21.4
# 2018-12-31 22:00:00+01:00                                  32.1
# 2018-12-31 23:00:00+01:00                                  32.1
#
#                            generation hydro run-of-river and poundage_diff  \
# 2015-01-01 00:00:00+01:00                                              NaN
# 2015-01-01 01:00:00+01:00                                            -25.6
# 2015-01-01 02:00:00+01:00                                            -25.6
# 2015-01-01 03:00:00+01:00                                            -19.8
# 2015-01-01 04:00:00+01:00                                             -9.6
# ...                                                                    ...
# 2018-12-31 19:00:00+01:00                                             20.0
# 2018-12-31 20:00:00+01:00                                              8.0
# 2018-12-31 21:00:00+01:00                                            -12.4
# 2018-12-31 22:00:00+01:00                                            -17.6
# 2018-12-31 23:00:00+01:00                                            -17.6
#
#                            generation hydro water reservoir_diff  \
# 2015-01-01 00:00:00+01:00                                    NaN
# 2015-01-01 01:00:00+01:00                                 -323.7
# 2015-01-01 02:00:00+01:00                                 -323.7
# 2015-01-01 03:00:00+01:00                                 -231.2
# 2015-01-01 04:00:00+01:00                                 -162.0
# ...                                                          ...
# 2018-12-31 19:00:00+01:00                                  162.8
# 2018-12-31 20:00:00+01:00                                 -119.2
# 2018-12-31 21:00:00+01:00                                 -463.8
# 2018-12-31 22:00:00+01:00                                 -816.3
# 2018-12-31 23:00:00+01:00                                 -816.3
#
#                            generation nuclear_diff  generation other_diff  \
# 2015-01-01 00:00:00+01:00                      NaN                    NaN
# 2015-01-01 01:00:00+01:00                      0.4           7.105427e-15
# 2015-01-01 02:00:00+01:00                      0.4           7.105427e-15
# 2015-01-01 03:00:00+01:00                      0.4           0.000000e+00
# 2015-01-01 04:00:00+01:00                      0.4           0.000000e+00
# ...                                            ...                    ...
# 2018-12-31 19:00:00+01:00                      0.8          -7.105427e-15
# 2018-12-31 20:00:00+01:00                      0.6           7.105427e-15
# 2018-12-31 21:00:00+01:00                      0.6          -7.105427e-15
# 2018-12-31 22:00:00+01:00                      0.5          -5.000000e-01
# 2018-12-31 23:00:00+01:00                      0.5          -5.000000e-01
#
#                            ...  energy_exchange_PT_diff  \
# 2015-01-01 00:00:00+01:00  ...                      NaN
# 2015-01-01 01:00:00+01:00  ...                    351.5
# 2015-01-01 02:00:00+01:00  ...                    351.5
# 2015-01-01 03:00:00+01:00  ...                    271.8
# 2015-01-01 04:00:00+01:00  ...                    174.6
# ...                        ...                      ...
# 2018-12-31 19:00:00+01:00  ...                   -429.4
# 2018-12-31 20:00:00+01:00  ...                   -342.6
# 2018-12-31 21:00:00+01:00  ...                    325.2
# 2018-12-31 22:00:00+01:00  ...                    241.6
# 2018-12-31 23:00:00+01:00  ...                    241.6
#
#                            energy_exchange_FR_diff  price actual_mean_24_diff  \
# 2015-01-01 00:00:00+01:00                      NaN                        NaN
# 2015-01-01 01:00:00+01:00                   -344.8                        NaN
# 2015-01-01 02:00:00+01:00                   -344.8                        NaN
# 2015-01-01 03:00:00+01:00                   -377.6                        NaN
# 2015-01-01 04:00:00+01:00                   -475.8                        NaN
# ...                                            ...                        ...
# 2018-12-31 19:00:00+01:00                    -18.8                   0.176917
# 2018-12-31 20:00:00+01:00                    -60.4                   0.102250
# 2018-12-31 21:00:00+01:00                   -490.6                   0.054000
# 2018-12-31 22:00:00+01:00                    -42.0                   0.001458
# 2018-12-31 23:00:00+01:00                    -42.0                   0.024417
#
#                            price actual_std_24_diff  \
# 2015-01-01 00:00:00+01:00                       NaN
# 2015-01-01 01:00:00+01:00                       NaN
# 2015-01-01 02:00:00+01:00                       NaN
# 2015-01-01 03:00:00+01:00                       NaN
# 2015-01-01 04:00:00+01:00                       NaN
# ...                                             ...
# 2018-12-31 19:00:00+01:00                  0.188683
# 2018-12-31 20:00:00+01:00                  0.101044
# 2018-12-31 21:00:00+01:00                  0.042787
# 2018-12-31 22:00:00+01:00                  0.000780
# 2018-12-31 23:00:00+01:00                  0.003029
#
#                            price actual_mean_48_diff  \
# 2015-01-01 00:00:00+01:00                        NaN
# 2015-01-01 01:00:00+01:00                        NaN
# 2015-01-01 02:00:00+01:00                        NaN
# 2015-01-01 03:00:00+01:00                        NaN
# 2015-01-01 04:00:00+01:00                        NaN
# ...                                              ...
# 2018-12-31 19:00:00+01:00                   0.139458
# 2018-12-31 20:00:00+01:00                   0.099042
# 2018-12-31 21:00:00+01:00                   0.075917
# 2018-12-31 22:00:00+01:00                   0.048229
# 2018-12-31 23:00:00+01:00                   0.059708
#
#                            price actual_std_48_diff  \
# 2015-01-01 00:00:00+01:00                       NaN
# 2015-01-01 01:00:00+01:00                       NaN
# 2015-01-01 02:00:00+01:00                       NaN
# 2015-01-01 03:00:00+01:00                       NaN
# 2015-01-01 04:00:00+01:00                       NaN
# ...                                             ...
# 2018-12-31 19:00:00+01:00                  0.160275
# 2018-12-31 20:00:00+01:00                  0.107968
# 2018-12-31 21:00:00+01:00                  0.067861
# 2018-12-31 22:00:00+01:00                  0.031132
# 2018-12-31 23:00:00+01:00                  0.014845
#
#                            price actual_mean_168_diff  \
# 2015-01-01 00:00:00+01:00                         NaN
# 2015-01-01 01:00:00+01:00                         NaN
# 2015-01-01 02:00:00+01:00                         NaN
# 2015-01-01 03:00:00+01:00                         NaN
# 2015-01-01 04:00:00+01:00                         NaN
# ...                                               ...
# 2018-12-31 19:00:00+01:00                    0.007238
# 2018-12-31 20:00:00+01:00                    0.005607
# 2018-12-31 21:00:00+01:00                    0.003869
# 2018-12-31 22:00:00+01:00                   -0.004411
# 2018-12-31 23:00:00+01:00                   -0.011036
#
#                            price actual_std_168_diff  \
# 2015-01-01 00:00:00+01:00                        NaN
# 2015-01-01 01:00:00+01:00                        NaN
# 2015-01-01 02:00:00+01:00                        NaN
# 2015-01-01 03:00:00+01:00                        NaN
# 2015-01-01 04:00:00+01:00                        NaN
# ...                                              ...
# 2018-12-31 19:00:00+01:00                   0.009267
# 2018-12-31 20:00:00+01:00                   0.006304
# 2018-12-31 21:00:00+01:00                   0.003432
# 2018-12-31 22:00:00+01:00                  -0.002904
# 2018-12-31 23:00:00+01:00                  -0.004503
#
#                            price actual_mean_336_diff  \
# 2015-01-01 00:00:00+01:00                         NaN
# 2015-01-01 01:00:00+01:00                         NaN
# 2015-01-01 02:00:00+01:00                         NaN
# 2015-01-01 03:00:00+01:00                         NaN
# 2015-01-01 04:00:00+01:00                         NaN
# ...                                               ...
# 2018-12-31 19:00:00+01:00                   -0.003315
# 2018-12-31 20:00:00+01:00                   -0.003071
# 2018-12-31 21:00:00+01:00                    0.000893
# 2018-12-31 22:00:00+01:00                    0.007902
# 2018-12-31 23:00:00+01:00                    0.016185
#
#                            price actual_std_336_diff
# 2015-01-01 00:00:00+01:00                        NaN
# 2015-01-01 01:00:00+01:00                        NaN
# 2015-01-01 02:00:00+01:00                        NaN
# 2015-01-01 03:00:00+01:00                        NaN
# 2015-01-01 04:00:00+01:00                        NaN
# ...                                              ...
# 2018-12-31 19:00:00+01:00                  -0.005071
# 2018-12-31 20:00:00+01:00                  -0.004129
# 2018-12-31 21:00:00+01:00                   0.000862
# 2018-12-31 22:00:00+01:00                   0.003233
# 2018-12-31 23:00:00+01:00                  -0.002987
#
# [35064 rows x 48 columns]

# %%
time_df
# Out:
#                            month  day  weekend  hour
# 2015-01-01 00:00:00+01:00      1    1        0     0
# 2015-01-01 01:00:00+01:00      1    1        0     1
# 2015-01-01 02:00:00+01:00      1    1        0     2
# 2015-01-01 03:00:00+01:00      1    1        0     3
# 2015-01-01 04:00:00+01:00      1    1        0     4
# ...                          ...  ...      ...   ...
# 2018-12-31 19:00:00+01:00     12   31        0    19
# 2018-12-31 20:00:00+01:00     12   31        0    20
# 2018-12-31 21:00:00+01:00     12   31        0    21
# 2018-12-31 22:00:00+01:00     12   31        0    22
# 2018-12-31 23:00:00+01:00     12   31        0    23
#
# [35064 rows x 4 columns]

# %%
final_df = pd.concat([extended_df,diff_df,time_df],axis=1)
final_df.index = final_df.index.tz_convert('Europe/Berlin')
final_df
# Out:
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               451.8
# 2015-01-01 01:00:00+01:00               446.9
# 2015-01-01 02:00:00+01:00               442.0
# 2015-01-01 03:00:00+01:00               434.6
# 2015-01-01 04:00:00+01:00               425.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               295.2
# 2018-12-31 20:00:00+01:00               294.2
# 2018-12-31 21:00:00+01:00               293.6
# 2018-12-31 22:00:00+01:00               291.9
# 2018-12-31 23:00:00+01:00               290.2
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 355.8
# 2015-01-01 01:00:00+01:00                                 320.0
# 2015-01-01 02:00:00+01:00                                 284.2
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 04:00:00+01:00                                 222.8
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00                 5130.2                       4942.8
# 2015-01-01 01:00:00+01:00                 4899.2                       4684.2
# 2015-01-01 02:00:00+01:00                 4668.2                       4425.6
# 2015-01-01 03:00:00+01:00                 4507.0                       4179.4
# 2015-01-01 04:00:00+01:00                 4275.8                       3902.0
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7277.0                       2560.6
# 2018-12-31 20:00:00+01:00                 7211.0                       2502.6
# 2018-12-31 21:00:00+01:00                 7077.6                       2415.0
# 2018-12-31 22:00:00+01:00                 6868.1                       2295.3
# 2018-12-31 23:00:00+01:00                 6658.6                       2175.6
#
#                            generation fossil oil  \
# 2015-01-01 00:00:00+01:00                  160.6
# 2015-01-01 01:00:00+01:00                  159.6
# 2015-01-01 02:00:00+01:00                  158.6
# 2015-01-01 03:00:00+01:00                  157.4
# 2015-01-01 04:00:00+01:00                  157.4
# ...                                          ...
# 2018-12-31 19:00:00+01:00                  175.0
# 2018-12-31 20:00:00+01:00                  172.2
# 2018-12-31 21:00:00+01:00                  169.2
# 2018-12-31 22:00:00+01:00                  165.1
# 2018-12-31 23:00:00+01:00                  161.0
#
#                            generation hydro pumped storage  \
# 2015-01-01 00:00:00+01:00                            753.4
# 2015-01-01 01:00:00+01:00                           1004.3
# 2015-01-01 02:00:00+01:00                           1255.2
# 2015-01-01 03:00:00+01:00                           1504.4
# 2015-01-01 04:00:00+01:00                           1742.0
# ...                                                    ...
# 2018-12-31 19:00:00+01:00                             35.4
# 2018-12-31 20:00:00+01:00                             32.2
# 2018-12-31 21:00:00+01:00                             53.6
# 2018-12-31 22:00:00+01:00                             85.7
# 2018-12-31 23:00:00+01:00                            117.8
#
#                            generation hydro run-of-river and poundage  \
# 2015-01-01 00:00:00+01:00                                      1038.2
# 2015-01-01 01:00:00+01:00                                      1012.6
# 2015-01-01 02:00:00+01:00                                       987.0
# 2015-01-01 03:00:00+01:00                                       967.2
# 2015-01-01 04:00:00+01:00                                       957.6
# ...                                                               ...
# 2018-12-31 19:00:00+01:00                                      1134.8
# 2018-12-31 20:00:00+01:00                                      1142.8
# 2018-12-31 21:00:00+01:00                                      1130.4
# 2018-12-31 22:00:00+01:00                                      1112.8
# 2018-12-31 23:00:00+01:00                                      1095.2
#
#                            generation hydro water reservoir  \
# 2015-01-01 00:00:00+01:00                            1932.8
# 2015-01-01 01:00:00+01:00                            1609.1
# 2015-01-01 02:00:00+01:00                            1285.4
# 2015-01-01 03:00:00+01:00                            1054.2
# 2015-01-01 04:00:00+01:00                             892.2
# ...                                                     ...
# 2018-12-31 19:00:00+01:00                            3653.4
# 2018-12-31 20:00:00+01:00                            3534.2
# 2018-12-31 21:00:00+01:00                            3070.4
# 2018-12-31 22:00:00+01:00                            2254.1
# 2018-12-31 23:00:00+01:00                            1437.8
#
#                            generation nuclear  generation other  ...  \
# 2015-01-01 00:00:00+01:00              7096.4              43.0  ...
# 2015-01-01 01:00:00+01:00              7096.8              43.0  ...
# 2015-01-01 02:00:00+01:00              7097.2              43.0  ...
# 2015-01-01 03:00:00+01:00              7097.6              43.0  ...
# 2015-01-01 04:00:00+01:00              7098.0              43.0  ...
# ...                                       ...               ...  ...
# 2018-12-31 19:00:00+01:00              6073.4              61.6  ...
# 2018-12-31 20:00:00+01:00              6074.0              61.6  ...
# 2018-12-31 21:00:00+01:00              6074.6              61.6  ...
# 2018-12-31 22:00:00+01:00              6075.1              61.1  ...
# 2018-12-31 23:00:00+01:00              6075.6              60.6  ...
#
#                            price actual_mean_48_diff  \
# 2015-01-01 00:00:00+01:00                        NaN
# 2015-01-01 01:00:00+01:00                        NaN
# 2015-01-01 02:00:00+01:00                        NaN
# 2015-01-01 03:00:00+01:00                        NaN
# 2015-01-01 04:00:00+01:00                        NaN
# ...                                              ...
# 2018-12-31 19:00:00+01:00                   0.139458
# 2018-12-31 20:00:00+01:00                   0.099042
# 2018-12-31 21:00:00+01:00                   0.075917
# 2018-12-31 22:00:00+01:00                   0.048229
# 2018-12-31 23:00:00+01:00                   0.059708
#
#                            price actual_std_48_diff  \
# 2015-01-01 00:00:00+01:00                       NaN
# 2015-01-01 01:00:00+01:00                       NaN
# 2015-01-01 02:00:00+01:00                       NaN
# 2015-01-01 03:00:00+01:00                       NaN
# 2015-01-01 04:00:00+01:00                       NaN
# ...                                             ...
# 2018-12-31 19:00:00+01:00                  0.160275
# 2018-12-31 20:00:00+01:00                  0.107968
# 2018-12-31 21:00:00+01:00                  0.067861
# 2018-12-31 22:00:00+01:00                  0.031132
# 2018-12-31 23:00:00+01:00                  0.014845
#
#                            price actual_mean_168_diff  \
# 2015-01-01 00:00:00+01:00                         NaN
# 2015-01-01 01:00:00+01:00                         NaN
# 2015-01-01 02:00:00+01:00                         NaN
# 2015-01-01 03:00:00+01:00                         NaN
# 2015-01-01 04:00:00+01:00                         NaN
# ...                                               ...
# 2018-12-31 19:00:00+01:00                    0.007238
# 2018-12-31 20:00:00+01:00                    0.005607
# 2018-12-31 21:00:00+01:00                    0.003869
# 2018-12-31 22:00:00+01:00                   -0.004411
# 2018-12-31 23:00:00+01:00                   -0.011036
#
#                            price actual_std_168_diff  \
# 2015-01-01 00:00:00+01:00                        NaN
# 2015-01-01 01:00:00+01:00                        NaN
# 2015-01-01 02:00:00+01:00                        NaN
# 2015-01-01 03:00:00+01:00                        NaN
# 2015-01-01 04:00:00+01:00                        NaN
# ...                                              ...
# 2018-12-31 19:00:00+01:00                   0.009267
# 2018-12-31 20:00:00+01:00                   0.006304
# 2018-12-31 21:00:00+01:00                   0.003432
# 2018-12-31 22:00:00+01:00                  -0.002904
# 2018-12-31 23:00:00+01:00                  -0.004503
#
#                            price actual_mean_336_diff  \
# 2015-01-01 00:00:00+01:00                         NaN
# 2015-01-01 01:00:00+01:00                         NaN
# 2015-01-01 02:00:00+01:00                         NaN
# 2015-01-01 03:00:00+01:00                         NaN
# 2015-01-01 04:00:00+01:00                         NaN
# ...                                               ...
# 2018-12-31 19:00:00+01:00                   -0.003315
# 2018-12-31 20:00:00+01:00                   -0.003071
# 2018-12-31 21:00:00+01:00                    0.000893
# 2018-12-31 22:00:00+01:00                    0.007902
# 2018-12-31 23:00:00+01:00                    0.016185
#
#                            price actual_std_336_diff  month  day  weekend  \
# 2015-01-01 00:00:00+01:00                        NaN      1    1        0
# 2015-01-01 01:00:00+01:00                        NaN      1    1        0
# 2015-01-01 02:00:00+01:00                        NaN      1    1        0
# 2015-01-01 03:00:00+01:00                        NaN      1    1        0
# 2015-01-01 04:00:00+01:00                        NaN      1    1        0
# ...                                              ...    ...  ...      ...
# 2018-12-31 19:00:00+01:00                  -0.005071     12   31        0
# 2018-12-31 20:00:00+01:00                  -0.004129     12   31        0
# 2018-12-31 21:00:00+01:00                   0.000862     12   31        0
# 2018-12-31 22:00:00+01:00                   0.003233     12   31        0
# 2018-12-31 23:00:00+01:00                  -0.002987     12   31        0
#
#                            hour
# 2015-01-01 00:00:00+01:00     0
# 2015-01-01 01:00:00+01:00     1
# 2015-01-01 02:00:00+01:00     2
# 2015-01-01 03:00:00+01:00     3
# 2015-01-01 04:00:00+01:00     4
# ...                         ...
# 2018-12-31 19:00:00+01:00    19
# 2018-12-31 20:00:00+01:00    20
# 2018-12-31 21:00:00+01:00    21
# 2018-12-31 22:00:00+01:00    22
# 2018-12-31 23:00:00+01:00    23
#
# [35064 rows x 100 columns]

# %%
final_df.dropna(axis=0,inplace=True)
final_df
# Out:
#                            generation biomass  \
# 2015-01-15 00:00:00+01:00               492.4
# 2015-01-15 01:00:00+01:00               484.4
# 2015-01-15 02:00:00+01:00               476.8
# 2015-01-15 03:00:00+01:00               470.0
# 2015-01-15 04:00:00+01:00               470.4
# ...                                       ...
# 2018-12-31 19:00:00+01:00               295.2
# 2018-12-31 20:00:00+01:00               294.2
# 2018-12-31 21:00:00+01:00               293.6
# 2018-12-31 22:00:00+01:00               291.9
# 2018-12-31 23:00:00+01:00               290.2
#
#                            generation fossil brown coal/lignite  \
# 2015-01-15 00:00:00+01:00                                 785.2
# 2015-01-15 01:00:00+01:00                                 707.6
# 2015-01-15 02:00:00+01:00                                 643.0
# 2015-01-15 03:00:00+01:00                                 605.0
# 2015-01-15 04:00:00+01:00                                 584.2
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-15 00:00:00+01:00                 4402.8                       6223.6
# 2015-01-15 01:00:00+01:00                 3830.4                       5626.2
# 2015-01-15 02:00:00+01:00                 3556.2                       5122.0
# 2015-01-15 03:00:00+01:00                 3476.0                       4849.4
# 2015-01-15 04:00:00+01:00                 3468.2                       4816.6
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7277.0                       2560.6
# 2018-12-31 20:00:00+01:00                 7211.0                       2502.6
# 2018-12-31 21:00:00+01:00                 7077.6                       2415.0
# 2018-12-31 22:00:00+01:00                 6868.1                       2295.3
# 2018-12-31 23:00:00+01:00                 6658.6                       2175.6
#
#                            generation fossil oil  \
# 2015-01-15 00:00:00+01:00                  308.0
# 2015-01-15 01:00:00+01:00                  298.0
# 2015-01-15 02:00:00+01:00                  289.0
# 2015-01-15 03:00:00+01:00                  291.2
# 2015-01-15 04:00:00+01:00                  295.8
# ...                                          ...
# 2018-12-31 19:00:00+01:00                  175.0
# 2018-12-31 20:00:00+01:00                  172.2
# 2018-12-31 21:00:00+01:00                  169.2
# 2018-12-31 22:00:00+01:00                  165.1
# 2018-12-31 23:00:00+01:00                  161.0
#
#                            generation hydro pumped storage  \
# 2015-01-15 00:00:00+01:00                           1139.2
# 2015-01-15 01:00:00+01:00                           1751.2
# 2015-01-15 02:00:00+01:00                           2369.4
# 2015-01-15 03:00:00+01:00                           2779.0
# 2015-01-15 04:00:00+01:00                           2708.2
# ...                                                    ...
# 2018-12-31 19:00:00+01:00                             35.4
# 2018-12-31 20:00:00+01:00                             32.2
# 2018-12-31 21:00:00+01:00                             53.6
# 2018-12-31 22:00:00+01:00                             85.7
# 2018-12-31 23:00:00+01:00                            117.8
#
#                            generation hydro run-of-river and poundage  \
# 2015-01-15 00:00:00+01:00                                       911.2
# 2015-01-15 01:00:00+01:00                                       869.8
# 2015-01-15 02:00:00+01:00                                       832.4
# 2015-01-15 03:00:00+01:00                                       811.4
# 2015-01-15 04:00:00+01:00                                       816.2
# ...                                                               ...
# 2018-12-31 19:00:00+01:00                                      1134.8
# 2018-12-31 20:00:00+01:00                                      1142.8
# 2018-12-31 21:00:00+01:00                                      1130.4
# 2018-12-31 22:00:00+01:00                                      1112.8
# 2018-12-31 23:00:00+01:00                                      1095.2
#
#                            generation hydro water reservoir  \
# 2015-01-15 00:00:00+01:00                            1414.2
# 2015-01-15 01:00:00+01:00                             927.4
# 2015-01-15 02:00:00+01:00                             763.6
# 2015-01-15 03:00:00+01:00                             673.2
# 2015-01-15 04:00:00+01:00                             620.6
# ...                                                     ...
# 2018-12-31 19:00:00+01:00                            3653.4
# 2018-12-31 20:00:00+01:00                            3534.2
# 2018-12-31 21:00:00+01:00                            3070.4
# 2018-12-31 22:00:00+01:00                            2254.1
# 2018-12-31 23:00:00+01:00                            1437.8
#
#                            generation nuclear  generation other  ...  \
# 2015-01-15 00:00:00+01:00              7103.0              80.2  ...
# 2015-01-15 01:00:00+01:00              7103.2              79.8  ...
# 2015-01-15 02:00:00+01:00              7103.6              79.8  ...
# 2015-01-15 03:00:00+01:00              7103.4              79.6  ...
# 2015-01-15 04:00:00+01:00              7103.2              79.2  ...
# ...                                       ...               ...  ...
# 2018-12-31 19:00:00+01:00              6073.4              61.6  ...
# 2018-12-31 20:00:00+01:00              6074.0              61.6  ...
# 2018-12-31 21:00:00+01:00              6074.6              61.6  ...
# 2018-12-31 22:00:00+01:00              6075.1              61.1  ...
# 2018-12-31 23:00:00+01:00              6075.6              60.6  ...
#
#                            price actual_mean_48_diff  \
# 2015-01-15 00:00:00+01:00                  -0.095958
# 2015-01-15 01:00:00+01:00                  -0.129833
# 2015-01-15 02:00:00+01:00                  -0.150167
# 2015-01-15 03:00:00+01:00                  -0.156875
# 2015-01-15 04:00:00+01:00                  -0.159208
# ...                                              ...
# 2018-12-31 19:00:00+01:00                   0.139458
# 2018-12-31 20:00:00+01:00                   0.099042
# 2018-12-31 21:00:00+01:00                   0.075917
# 2018-12-31 22:00:00+01:00                   0.048229
# 2018-12-31 23:00:00+01:00                   0.059708
#
#                            price actual_std_48_diff  \
# 2015-01-15 00:00:00+01:00                  0.133405
# 2015-01-15 01:00:00+01:00                  0.228025
# 2015-01-15 02:00:00+01:00                  0.296315
# 2015-01-15 03:00:00+01:00                  0.317424
# 2015-01-15 04:00:00+01:00                  0.309572
# ...                                             ...
# 2018-12-31 19:00:00+01:00                  0.160275
# 2018-12-31 20:00:00+01:00                  0.107968
# 2018-12-31 21:00:00+01:00                  0.067861
# 2018-12-31 22:00:00+01:00                  0.031132
# 2018-12-31 23:00:00+01:00                  0.014845
#
#                            price actual_mean_168_diff  \
# 2015-01-15 00:00:00+01:00                   -0.117452
# 2015-01-15 01:00:00+01:00                   -0.133750
# 2015-01-15 02:00:00+01:00                   -0.142119
# 2015-01-15 03:00:00+01:00                   -0.142869
# 2015-01-15 04:00:00+01:00                   -0.140417
# ...                                               ...
# 2018-12-31 19:00:00+01:00                    0.007238
# 2018-12-31 20:00:00+01:00                    0.005607
# 2018-12-31 21:00:00+01:00                    0.003869
# 2018-12-31 22:00:00+01:00                   -0.004411
# 2018-12-31 23:00:00+01:00                   -0.011036
#
#                            price actual_std_168_diff  \
# 2015-01-15 00:00:00+01:00                   0.081578
# 2015-01-15 01:00:00+01:00                   0.139332
# 2015-01-15 02:00:00+01:00                   0.181370
# 2015-01-15 03:00:00+01:00                   0.195567
# 2015-01-15 04:00:00+01:00                   0.187871
# ...                                              ...
# 2018-12-31 19:00:00+01:00                   0.009267
# 2018-12-31 20:00:00+01:00                   0.006304
# 2018-12-31 21:00:00+01:00                   0.003432
# 2018-12-31 22:00:00+01:00                  -0.002904
# 2018-12-31 23:00:00+01:00                  -0.004503
#
#                            price actual_mean_336_diff  \
# 2015-01-15 00:00:00+01:00                   -0.039839
# 2015-01-15 01:00:00+01:00                   -0.049036
# 2015-01-15 02:00:00+01:00                   -0.052845
# 2015-01-15 03:00:00+01:00                   -0.050393
# 2015-01-15 04:00:00+01:00                   -0.042030
# ...                                               ...
# 2018-12-31 19:00:00+01:00                   -0.003315
# 2018-12-31 20:00:00+01:00                   -0.003071
# 2018-12-31 21:00:00+01:00                    0.000893
# 2018-12-31 22:00:00+01:00                    0.007902
# 2018-12-31 23:00:00+01:00                    0.016185
#
#                            price actual_std_336_diff  month  day  weekend  \
# 2015-01-15 00:00:00+01:00                   0.035426      1   15        0
# 2015-01-15 01:00:00+01:00                   0.061336      1   15        0
# 2015-01-15 02:00:00+01:00                   0.080418      1   15        0
# 2015-01-15 03:00:00+01:00                   0.084844      1   15        0
# 2015-01-15 04:00:00+01:00                   0.074789      1   15        0
# ...                                              ...    ...  ...      ...
# 2018-12-31 19:00:00+01:00                  -0.005071     12   31        0
# 2018-12-31 20:00:00+01:00                  -0.004129     12   31        0
# 2018-12-31 21:00:00+01:00                   0.000862     12   31        0
# 2018-12-31 22:00:00+01:00                   0.003233     12   31        0
# 2018-12-31 23:00:00+01:00                  -0.002987     12   31        0
#
#                            hour
# 2015-01-15 00:00:00+01:00     0
# 2015-01-15 01:00:00+01:00     1
# 2015-01-15 02:00:00+01:00     2
# 2015-01-15 03:00:00+01:00     3
# 2015-01-15 04:00:00+01:00     4
# ...                         ...
# 2018-12-31 19:00:00+01:00    19
# 2018-12-31 20:00:00+01:00    20
# 2018-12-31 21:00:00+01:00    21
# 2018-12-31 22:00:00+01:00    22
# 2018-12-31 23:00:00+01:00    23
#
# [34728 rows x 100 columns]

# %% [markdown]
# # Encode- Decoder + LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = final_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.MinMaxScaler(feature_range=(0,1),copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
train_start = '2015-01-14'
validation_start = '2018-10-01'
test_start = '2018-11-01'
test_end = '2018-12-01'
feature = 'price actual_diff'
namespace= 'MS_EDLSTM_bigdf2'
modeltype = 'EDLSTM'

batch_size = 64
num_epochs = 40

feature_df = final_df[[feature]]

data_x_train0, data_y_train0 = create_split(scaled_df,feature_df,train_start,validation_start)
data_x_val0, data_y_val0 = create_split(scaled_df,feature_df,validation_start,test_start)
data_x_test0, data_y_test0 = create_split(scaled_df,feature_df,test_start,test_end)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,24*14,24,batch_size)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,24*14,24,batch_size)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,24*14,24,batch_size)

# %%
print(data_x_train.shape,data_y_train.shape,idx_train.shape)
print(data_x_val.shape,data_y_val.shape,idx_val.shape)
print(data_x_test.shape,data_y_test.shape,idx_test.shape)
# Out:
# (32128, 336, 100) (32128, 24) (32128,)
# (320, 336, 100) (320, 24) (320,)
# (320, 336, 100) (320, 24) (320,)

# %% [markdown]
# Define LSTM Model

# %%
def build_model_ED_LSTM():
    n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
    model = models.Sequential()
    # Encoder
    model.add(layers.LSTM(90, return_sequences=True,input_shape=(None, n_features), stateful=False))
    model.add(layers.BatchNormalization())
    
    model.add(layers.Bidirectional(layers.LSTM(90, return_sequences=True, stateful=False))) 
    model.add(layers.BatchNormalization())  
    
    model.add(layers.LSTM(90, return_sequences=False, stateful=False)) 
    model.add(layers.BatchNormalization())  
    
    # Repeat Vector
    model.add(layers.RepeatVector(n_outputs))
    
    # Decoder
    model.add(layers.Bidirectional(layers.LSTM(90, return_sequences=True,stateful=False)))
    model.add(layers.BatchNormalization())
    model.add(layers.Bidirectional(layers.LSTM(90, return_sequences=True,stateful=False)))
    model.add(layers.BatchNormalization())

    # End
    model.add(layers.TimeDistributed(layers.Dense(90, kernel_regularizer=regularizers.l2(0.001), kernel_initializer="he_normal")))
    model.add(layers.TimeDistributed(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), kernel_initializer="he_normal")))
    
    model.add(layers.TimeDistributed(layers.LeakyReLU(alpha=0.1)))                     
    model.add(layers.TimeDistributed(layers.BatchNormalization()))
    model.add(layers.TimeDistributed(layers.Dense(1)))                     
                
    model.compile(optimizer='Adam',loss='mse',metrics='mae') 
    return model

# %%
myCheckpointLSTM= keras.callbacks.ModelCheckpoint(f"./{modeltype}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingLSTM = keras.callbacks.EarlyStopping(patience=20,restore_best_weights=True)

# %%
initial_learning_rate = 0.001

decay = initial_learning_rate/num_epochs

def scheduler(epoch,lr):
    return lr*1/(1+decay*epoch)

myLearningRate_LSTM = keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# model_ED_LSTM= build_model_ED_LSTM()
# history_ED_LSTM = model_ED_LSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) ,
#                                  callbacks=[myCheckpointLSTM,myEarly_stoppingLSTM,myLearningRate_LSTM])

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# histEDLSTM = pd.DataFrame(history_ED_LSTM.history)
# histEDLSTM['epoch'] = history_ED_LSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# fig = plot_learning_curves(histEDLSTM,modeltype,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# Load best model

# %%
model_best_ED_LSTM = keras.models.load_model(f"./{modeltype}/my_best_model_{namespace}.h5")
model_best_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 90)          68760
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 90)          360
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 180)         130320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 180)         720
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 90)                97560
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 90)                360
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 90)            0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 24, 180)           130320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 180)           720
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 24, 180)           195120
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 180)           720
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 90)            16290
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 24, 64)            5824
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 24, 64)            0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 24, 64)            256
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 24, 1)             65
# =================================================================
# Total params: 647,395
# Trainable params: 645,827
# Non-trainable params: 1,568
# _________________________________________________________________

# %% [markdown]
# Evaluate differencing performance on validation data

# %%
i=0
case_val = data_x_val[i].reshape((1,data_x_val[0].shape[0], data_x_val[0].shape[1]))
Y_val_predictions_diff = pd.Series(model_best_ED_LSTM.predict(case_val).flatten(),index=pd.date_range(start=idx_val[i],freq='h',periods=24))
y_val_filtered_diff = data_y_val0.loc[Y_val_predictions_diff.index]
y_val_filtered_diff = y_val_filtered_diff.squeeze(axis=1)

# %%
eval_df_diff = create_eval_df(Y_val_predictions_diff,y_val_filtered_diff)

# %%
fig = plot_evaluation(eval_df_diff)
# Out:
# R^2 score is  0.89

# %%
df_pred_diff = make_multiple_predictions(model_best_ED_LSTM,idx_val,data_x_val,data_y_val0,feature,convert=False)

# %%
eval_df_diff = create_eval_df(df_pred_diff['mean'],df_pred_diff['Actual'])

# %%
fig = plot_evaluation(eval_df_diff)
# Out:
# R^2 score is  0.86

# %% [markdown]
# Reverting differencing on validation data

# %%
df_pred = make_multiple_predictions(model_best_ED_LSTM,idx_val,data_x_val,extended_df,'price actual',convert=True)

# %%
eval_df = create_eval_df(df_pred['mean'],df_pred['Actual'])

# %%
fig = plot_evaluation(eval_df)
# Out:
# R^2 score is  0.82

# %%
r2 = calculate_r2_scores(df_pred)
plt.figure()
plt.plot(r2)

# %% [markdown]
# Evaluate differencing Performance on test data

# %%
i=0
case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
Y_test_predictions_diff = pd.Series(model_best_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
y_test_filtered_diff = data_y_test0.loc[Y_test_predictions_diff.index]
y_test_filtered_diff = y_test_filtered_diff.squeeze(axis=1)

# %%
eval_df_diff = create_eval_df(Y_test_predictions_diff,y_test_filtered_diff)

# %%
fig = plot_evaluation(eval_df_diff)
# Out:
# R^2 score is  0.92

# %%
df_pred_diff = make_multiple_predictions(model_best_ED_LSTM,idx_test,data_x_test,data_y_test0,feature,convert=False)

# %%
eval_df_diff = create_eval_df(df_pred_diff['mean'],df_pred_diff['Actual'])

# %%
fig = plot_evaluation(eval_df_diff)
# Out:
# R^2 score is  0.80

# %% [markdown]
# Reverting differencing on test data

# %%
df_pred = make_multiple_predictions(model_best_ED_LSTM,idx_test,data_x_test,extended_df,'price actual',convert=True)

# %%
eval_df = create_eval_df(df_pred['mean'],df_pred['Actual'])

# %%
fig = plot_evaluation(eval_df)
# Out:
# R^2 score is  0.67

# %%
def calculate_metrics(df_pred):
    r2_list=[]
    mpe_list= []
    mae_list= []
    for column in df_pred.columns:
        if column not in ['Actual','mean']:
            pred = df_pred[column].dropna()
            act = df_pred.loc[pred.index,'Actual']
            r2= r2_score(pred,act)
            mpe = (act-pred)/act
        
            mae = sklearn.metrics.mean_absolute_error(act,pred)
            r2_list.append(r2)
            mpe_list.append(mpe.mean())
            mae_list.append(mae)
    return r2_list,mpe_list,mae_list      

def plot_metrics(df_pred):
    fig= plt.figure(figsize = (16,16))
    gs = fig.add_gridspec(3,1)
    r2_list,mpe_list,mae_list = calculate_metrics(df_pred)
    ax1 = fig.add_subplot(gs[0,0],)
    ax2 = fig.add_subplot(gs[1,0],sharex=ax1)
    ax3 = fig.add_subplot(gs[2,0],sharex=ax1)
    ax1.plot(r2_list)
    ax1.set_title('R2 Score')
    ax2.plot(mpe_list)
    ax2.set_title('RMSE')
    ax3.plot(mae_list)
    ax3.set_title('MAE')
    ax1.set_xticks(ticks=range(0,len(r2_list),24))
    return fig

# %%
fig = plot_metrics(df_pred)
