# %%
import numpy as np
import pandas as pd
from datetime import date
import plotly.express as px
import plotly.graph_objects as go
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing as pp
import matplotlib as mpl
from sklearn.decomposition import PCA
from pandas.plotting import lag_plot, autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
import statsmodels.api as smw
from datetime import timedelta
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.svm import SVR
from sklearn.metrics import r2_score
# ML Algorithms to be used
import tensorflow as tf
from tensorflow import keras
from keras import optimizers, models, layers, regularizers
tf.__version__
from utils.dde_preprocessing_utils import (set_timestamp_index,
remove_duplicates,
remove_columns,
extract_correlations,
prepare_data_sarimax,
create_test_train_split,
create_sarimax_test_train_split,
create_eval_df,
convert_to_sample_time_feature)
from utils.dde_plotting_utils import(
display_double_timestamps,
display_seasonal_decomposition,
plot_predictions,
plot_accuracy,
plot_error_variations,
plot_learning_curves,
)
# %load_ext skip_kernel_extension

# %%
import keras_tuner as kt

# %%
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
mpl.rcParams['figure.figsize'] = [8.0, 8.0]
tf.random.set_seed(2022)

# %%
SKIP_RETRAIN_NN =True
SKIP_RETRAIN_RNN = True
SKIP_RETRAIN_LSTM = True
SKIP_RETRAIN_ED_LSTM = False

# %% [markdown]
# ## Loading Data

# %%
combined_df = pd.read_csv("extended_preprocessed_data.csv")
combined_df = set_timestamp_index(combined_df,"Unnamed: 0")

# %%
combined_df
# Out:
#                              temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 01:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 02:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 03:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 04:00:00+01:00  -3.464    1002.0        78         0.0        23
# ...                           ...       ...       ...         ...       ...
# 2018-12-31 19:00:00+01:00  12.490    1028.0        62         2.0       140
# 2018-12-31 20:00:00+01:00   9.990    1029.0        71         1.0       242
# 2018-12-31 21:00:00+01:00   8.510    1029.0        81         3.0       300
# 2018-12-31 22:00:00+01:00   6.990    1029.0        81         2.0       310
# 2018-12-31 23:00:00+01:00   5.990    1029.0        75         2.0       300
#
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               447.0
# 2015-01-01 01:00:00+01:00               449.0
# 2015-01-01 02:00:00+01:00               448.0
# 2015-01-01 03:00:00+01:00               438.0
# 2015-01-01 04:00:00+01:00               428.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               297.0
# 2018-12-31 20:00:00+01:00               296.0
# 2018-12-31 21:00:00+01:00               292.0
# 2018-12-31 22:00:00+01:00               293.0
# 2018-12-31 23:00:00+01:00               290.0
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 329.0
# 2015-01-01 01:00:00+01:00                                 328.0
# 2015-01-01 02:00:00+01:00                                 323.0
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 04:00:00+01:00                                 187.0
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00                 4844.0                       4821.0
# 2015-01-01 01:00:00+01:00                 5196.0                       4755.0
# 2015-01-01 02:00:00+01:00                 4857.0                       4581.0
# 2015-01-01 03:00:00+01:00                 4314.0                       4131.0
# 2015-01-01 04:00:00+01:00                 4130.0                       3840.0
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7634.0                       2628.0
# 2018-12-31 20:00:00+01:00                 7241.0                       2566.0
# 2018-12-31 21:00:00+01:00                 7025.0                       2422.0
# 2018-12-31 22:00:00+01:00                 6562.0                       2293.0
# 2018-12-31 23:00:00+01:00                 6926.0                       2166.0
#
#                            generation fossil oil  ...  \
# 2015-01-01 00:00:00+01:00                  162.0  ...
# 2015-01-01 01:00:00+01:00                  158.0  ...
# 2015-01-01 02:00:00+01:00                  157.0  ...
# 2015-01-01 03:00:00+01:00                  160.0  ...
# 2015-01-01 04:00:00+01:00                  156.0  ...
# ...                                          ...  ...
# 2018-12-31 19:00:00+01:00                  178.0  ...
# 2018-12-31 20:00:00+01:00                  174.0  ...
# 2018-12-31 21:00:00+01:00                  168.0  ...
# 2018-12-31 22:00:00+01:00                  163.0  ...
# 2018-12-31 23:00:00+01:00                  163.0  ...
#
#                            generation wind onshore  total load actual  \
# 2015-01-01 00:00:00+01:00                   6378.0            25385.0
# 2015-01-01 01:00:00+01:00                   5890.0            24382.0
# 2015-01-01 02:00:00+01:00                   5461.0            22734.0
# 2015-01-01 03:00:00+01:00                   5238.0            21286.0
# 2015-01-01 04:00:00+01:00                   4935.0            20264.0
# ...                                            ...                ...
# 2018-12-31 19:00:00+01:00                   3113.0            30653.0
# 2018-12-31 20:00:00+01:00                   3288.0            29735.0
# 2018-12-31 21:00:00+01:00                   3503.0            28071.0
# 2018-12-31 22:00:00+01:00                   3586.0            25801.0
# 2018-12-31 23:00:00+01:00                   3651.0            24455.0
#
#                            price actual  generation  energy_difference  \
# 2015-01-01 00:00:00+01:00         65.41     28251.0             2866.0
# 2015-01-01 01:00:00+01:00         64.92     27818.0             3436.0
# 2015-01-01 02:00:00+01:00         64.48     26796.0             4062.0
# 2015-01-01 03:00:00+01:00         59.32     25223.0             3937.0
# 2015-01-01 04:00:00+01:00         56.04     24620.0             4356.0
# ...                                 ...         ...                ...
# 2018-12-31 19:00:00+01:00         77.02     26415.0            -4238.0
# 2018-12-31 20:00:00+01:00         76.16     25213.0            -4522.0
# 2018-12-31 21:00:00+01:00         74.30     23987.0            -4084.0
# 2018-12-31 22:00:00+01:00         69.89     22748.0            -3053.0
# 2018-12-31 23:00:00+01:00         69.88     22605.0            -1850.0
#
#                            energy_stored  month  day  weekend  hour
# 2015-01-01 00:00:00+01:00         2866.0      1    1        0     0
# 2015-01-01 01:00:00+01:00         6302.0      1    1        0     1
# 2015-01-01 02:00:00+01:00        10364.0      1    1        0     2
# 2015-01-01 03:00:00+01:00        14301.0      1    1        0     3
# 2015-01-01 04:00:00+01:00        18657.0      1    1        0     4
# ...                                  ...    ...  ...      ...   ...
# 2018-12-31 19:00:00+01:00     -2062312.5     12   31        0    19
# 2018-12-31 20:00:00+01:00     -2066834.5     12   31        0    20
# 2018-12-31 21:00:00+01:00     -2070918.5     12   31        0    21
# 2018-12-31 22:00:00+01:00     -2073971.5     12   31        0    22
# 2018-12-31 23:00:00+01:00     -2075821.5     12   31        0    23
#
# [35064 rows x 28 columns]

# %% [markdown]
# # Encode- Decoder + LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = combined_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.StandardScaler(copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
train_start = '2015-01-01'
validation_start = '2017-01-01'
test_start = '2017-03-01'
test_end = '2017-03-28'
feature = 'total load actual'
namespace= 'MS_EDLSTM_WL4'
modeltype = 'EDLSTM'
feature_df = combined_df[[feature]]
data_x_train0,data_x_val0,data_x_test0,data_y_train0,data_y_val0,data_y_test0 = create_test_train_split(scaled_df,feature_df,train_start,test_start,test_end,validation_start=validation_start)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,24*14,24,32)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,24*14,24,32)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,24*14,24,32)

# %%
print(data_x_train.shape,data_y_train.shape)
print(data_x_val.shape,data_y_val.shape)
print(data_x_test.shape,data_y_test.shape)
# Out:
# (17152, 336, 28) (17152, 24)
# (1024, 336, 28) (1024, 24)
# (256, 336, 28) (256, 24)

# %% [markdown]
# Define LSTM Model

# %%
def build_model_ED_LSTM():
    n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
    model = models.Sequential()
    # Encoder
    model.add(layers.LSTM(64, return_sequences=True,input_shape=(None, n_features), stateful=False)) 
    model.add(layers.BatchNormalization())
    
    for i in range(2):
        model.add(layers.LSTM(64, return_sequences=True, stateful=False))
        model.add(layers.BatchNormalization())
      
    model.add(layers.LSTM(64, return_sequences=False, stateful=False)) 
    model.add(layers.BatchNormalization())  
    
    # Repeat Vector
    model.add(layers.RepeatVector(n_outputs))
    
    # Decoder
    model.add(layers.LSTM(64, return_sequences=True,stateful=False))
    model.add(layers.BatchNormalization())

    for i in range(2):
        model.add(layers.LSTM(64, return_sequences=True, stateful=False))
        model.add(layers.BatchNormalization())

    model.add(layers.LSTM(64, return_sequences=True,stateful=False))
    model.add(layers.BatchNormalization())

    # End
    model.add(layers.TimeDistributed(layers.Dense(64, kernel_regularizer=regularizers.l2(0.0001), kernel_initializer="he_normal")))
    
    model.add(layers.TimeDistributed(layers.LeakyReLU(alpha=0.1)))                     
    model.add(layers.TimeDistributed(layers.BatchNormalization()))
    model.add(layers.TimeDistributed(layers.Dense(1)))                     
                
    model.compile(optimizer='Adam',loss='mse',metrics='mae') 
    return model

# %%
myCheckpointLSTM= keras.callbacks.ModelCheckpoint(f"./{modeltype}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingLSTM = keras.callbacks.EarlyStopping(patience=20,restore_best_weights=True)

# %%
num_epochs = 150
batch_size = 32

# %%
model_ED_LSTM= build_model_ED_LSTM()
history_ED_LSTM = model_ED_LSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) , 
                                 callbacks=[myCheckpointLSTM,myEarly_stoppingLSTM])
# Out:
# Epoch 1/150
# 536/536 [==============================] - 60s 94ms/step - loss: 828826048.0000 - mae: 28432.5840 - val_loss: 931266304.0000 - val_mae: 30101.9395
# Epoch 2/150
# 536/536 [==============================] - 62s 115ms/step - loss: 822437184.0000 - mae: 28340.3789 - val_loss: 920534080.0000 - val_mae: 29952.3125
# Epoch 3/150
# 536/536 [==============================] - 51s 96ms/step - loss: 810296000.0000 - mae: 28165.2891 - val_loss: 905865728.0000 - val_mae: 29751.0176
# Epoch 4/150
# 536/536 [==============================] - 55s 103ms/step - loss: 794389760.0000 - mae: 27924.0020 - val_loss: 883560128.0000 - val_mae: 29404.1250
# Epoch 5/150
# 536/536 [==============================] - 56s 104ms/step - loss: 775372096.0000 - mae: 27626.3359 - val_loss: 858506368.0000 - val_mae: 29013.6211
# Epoch 6/150
# 536/536 [==============================] - 62s 116ms/step - loss: 753791232.0000 - mae: 27278.5879 - val_loss: 827616576.0000 - val_mae: 28521.4004
# Epoch 7/150
# 536/536 [==============================] - 62s 115ms/step - loss: 730174272.0000 - mae: 26885.3477 - val_loss: 800420160.0000 - val_mae: 28069.6426
# Epoch 8/150
# 536/536 [==============================] - 62s 116ms/step - loss: 704844800.0000 - mae: 26449.8574 - val_loss: 767020672.0000 - val_mae: 27510.2734
# Epoch 9/150
# 536/536 [==============================] - 57s 106ms/step - loss: 678160768.0000 - mae: 25974.1035 - val_loss: 737125632.0000 - val_mae: 26981.6523
# Epoch 10/150
# 536/536 [==============================] - 59s 111ms/step - loss: 650420352.0000 - mae: 25460.5508 - val_loss: 700583616.0000 - val_mae: 26315.3398
# Epoch 11/150
# 536/536 [==============================] - 60s 111ms/step - loss: 621795392.0000 - mae: 24910.4023 - val_loss: 660065280.0000 - val_mae: 25543.9766
# Epoch 12/150
# 536/536 [==============================] - 60s 112ms/step - loss: 592430144.0000 - mae: 24324.0547 - val_loss: 621889600.0000 - val_mae: 24795.3145
# Epoch 13/150
# 536/536 [==============================] - 59s 111ms/step - loss: 562535744.0000 - mae: 23702.1348 - val_loss: 597170752.0000 - val_mae: 24274.7168
# Epoch 14/150
# 536/536 [==============================] - 58s 109ms/step - loss: 531623392.0000 - mae: 23044.3223 - val_loss: 561536640.0000 - val_mae: 23535.7637
# Epoch 15/150
# 536/536 [==============================] - 60s 112ms/step - loss: 500008480.0000 - mae: 22348.4316 - val_loss: 534127904.0000 - val_mae: 22947.8145
# Epoch 16/150
# 536/536 [==============================] - 60s 112ms/step - loss: 467884448.0000 - mae: 21617.6699 - val_loss: 493825120.0000 - val_mae: 22047.6328
# Epoch 17/150
# 536/536 [==============================] - 65s 121ms/step - loss: 435522304.0000 - mae: 20854.0234 - val_loss: 455747680.0000 - val_mae: 21161.8047
# Epoch 18/150
# 536/536 [==============================] - 60s 112ms/step - loss: 402840000.0000 - mae: 20057.5664 - val_loss: 430153280.0000 - val_mae: 20546.8789
# Epoch 19/150
# 536/536 [==============================] - 61s 114ms/step - loss: 370364288.0000 - mae: 19230.4199 - val_loss: 391370656.0000 - val_mae: 19586.8906
# Epoch 20/150
# 536/536 [==============================] - 65s 121ms/step - loss: 338133344.0000 - mae: 18374.2793 - val_loss: 364646016.0000 - val_mae: 18877.5742
# Epoch 21/150
# 536/536 [==============================] - 67s 124ms/step - loss: 306429664.0000 - mae: 17489.1660 - val_loss: 321234624.0000 - val_mae: 17706.0586
# Epoch 22/150
# 536/536 [==============================] - 68s 126ms/step - loss: 275331648.0000 - mae: 16576.8848 - val_loss: 291347936.0000 - val_mae: 16842.0820
# Epoch 23/150
# 536/536 [==============================] - 67s 125ms/step - loss: 245122864.0000 - mae: 15639.9668 - val_loss: 260035072.0000 - val_mae: 15905.7168
# Epoch 24/150
# 536/536 [==============================] - 68s 126ms/step - loss: 216061696.0000 - mae: 14678.3643 - val_loss: 237822672.0000 - val_mae: 15159.5938
# Epoch 25/150
# 536/536 [==============================] - 66s 123ms/step - loss: 188059776.0000 - mae: 13695.4033 - val_loss: 203512688.0000 - val_mae: 14012.9639
# Epoch 26/150
# 536/536 [==============================] - 66s 123ms/step - loss: 161623936.0000 - mae: 12693.9189 - val_loss: 172787888.0000 - val_mae: 12859.7197
# Epoch 27/150
# 536/536 [==============================] - 67s 124ms/step - loss: 136785408.0000 - mae: 11673.7031 - val_loss: 151386432.0000 - val_mae: 11992.6221
# Epoch 28/150
# 536/536 [==============================] - 65s 120ms/step - loss: 114015992.0000 - mae: 10641.9980 - val_loss: 122535984.0000 - val_mae: 10757.7822
# Epoch 29/150
# 536/536 [==============================] - 68s 126ms/step - loss: 92714496.0000 - mae: 9602.7812 - val_loss: 103461440.0000 - val_mae: 9826.1104
# Epoch 30/150
# 536/536 [==============================] - 67s 124ms/step - loss: 73675544.0000 - mae: 8557.5889 - val_loss: 84424432.0000 - val_mae: 8803.2617
# Epoch 31/150
# 536/536 [==============================] - 67s 126ms/step - loss: 56987468.0000 - mae: 7513.2114 - val_loss: 66011260.0000 - val_mae: 7674.5146
# Epoch 32/150
# 536/536 [==============================] - 66s 124ms/step - loss: 42424716.0000 - mae: 6480.5425 - val_loss: 51731368.0000 - val_mae: 6717.2310
# Epoch 33/150
# 536/536 [==============================] - 66s 124ms/step - loss: 30365590.0000 - mae: 5464.9458 - val_loss: 39921948.0000 - val_mae: 5809.2510
# Epoch 34/150
# 536/536 [==============================] - 66s 123ms/step - loss: 20516842.0000 - mae: 4482.9829 - val_loss: 29162706.0000 - val_mae: 4835.3296
# Epoch 35/150
# 536/536 [==============================] - 66s 122ms/step - loss: 12952549.0000 - mae: 3544.1128 - val_loss: 22496184.0000 - val_mae: 4141.8848
# Epoch 36/150
# 536/536 [==============================] - 65s 121ms/step - loss: 7735932.0000 - mae: 2683.5320 - val_loss: 18244118.0000 - val_mae: 3549.2676
# Epoch 37/150
# 536/536 [==============================] - 60s 112ms/step - loss: 4000539.0000 - mae: 1894.0065 - val_loss: 13650855.0000 - val_mae: 3004.4089
# Epoch 38/150
# 536/536 [==============================] - 48s 89ms/step - loss: 1911260.7500 - mae: 1248.7251 - val_loss: 11220710.0000 - val_mae: 2631.2620
# Epoch 39/150
# 536/536 [==============================] - 45s 84ms/step - loss: 900175.0625 - mae: 790.2097 - val_loss: 10308472.0000 - val_mae: 2419.6492
# Epoch 40/150
# 536/536 [==============================] - 44s 82ms/step - loss: 473417.7500 - mae: 540.1310 - val_loss: 9189128.0000 - val_mae: 2236.1995
# Epoch 41/150
# 536/536 [==============================] - 44s 82ms/step - loss: 367475.6562 - mae: 468.8130 - val_loss: 8713744.0000 - val_mae: 2146.2385
# Epoch 42/150
# 536/536 [==============================] - 44s 82ms/step - loss: 333502.4375 - mae: 443.7325 - val_loss: 8621479.0000 - val_mae: 2146.9260
# Epoch 43/150
# 536/536 [==============================] - 44s 81ms/step - loss: 387989.7188 - mae: 474.1190 - val_loss: 9391543.0000 - val_mae: 2253.3950
# Epoch 44/150
# 536/536 [==============================] - 43s 81ms/step - loss: 374456.0938 - mae: 466.2871 - val_loss: 8524203.0000 - val_mae: 2067.4321
# Epoch 45/150
# 536/536 [==============================] - 44s 82ms/step - loss: 329315.6250 - mae: 436.9244 - val_loss: 8650309.0000 - val_mae: 2108.5549
# Epoch 46/150
# 536/536 [==============================] - 44s 82ms/step - loss: 360510.2188 - mae: 453.4167 - val_loss: 9631395.0000 - val_mae: 2288.3635
# Epoch 47/150
# 536/536 [==============================] - 45s 83ms/step - loss: 324940.6875 - mae: 437.2844 - val_loss: 8721083.0000 - val_mae: 2157.1504
# Epoch 48/150
# 536/536 [==============================] - 44s 82ms/step - loss: 326764.7500 - mae: 439.7731 - val_loss: 8223008.5000 - val_mae: 2071.2747
# Epoch 49/150
# 536/536 [==============================] - 43s 80ms/step - loss: 533016.6250 - mae: 534.9735 - val_loss: 7814599.0000 - val_mae: 2147.2305
# Epoch 50/150
# 536/536 [==============================] - 43s 80ms/step - loss: 377019.6875 - mae: 472.4258 - val_loss: 7541880.0000 - val_mae: 2103.1357
# Epoch 51/150
# 536/536 [==============================] - 44s 82ms/step - loss: 345929.5000 - mae: 448.6749 - val_loss: 7973971.0000 - val_mae: 2192.3921
# Epoch 52/150
# 536/536 [==============================] - 44s 83ms/step - loss: 315267.0938 - mae: 430.1218 - val_loss: 8280962.0000 - val_mae: 2219.8833
# Epoch 53/150
# 536/536 [==============================] - 44s 82ms/step - loss: 356941.6562 - mae: 456.5415 - val_loss: 8610670.0000 - val_mae: 2232.7893
# Epoch 54/150
# 536/536 [==============================] - 44s 81ms/step - loss: 305052.3438 - mae: 427.4265 - val_loss: 8325090.5000 - val_mae: 2199.9529
# Epoch 55/150
# 536/536 [==============================] - 44s 81ms/step - loss: 330978.1875 - mae: 447.7668 - val_loss: 8929290.0000 - val_mae: 2296.0090
# Epoch 56/150
# 536/536 [==============================] - 43s 81ms/step - loss: 492320.1562 - mae: 518.9402 - val_loss: 10341138.0000 - val_mae: 2394.8928
# Epoch 57/150
# 536/536 [==============================] - 44s 81ms/step - loss: 355085.2188 - mae: 460.5909 - val_loss: 10176228.0000 - val_mae: 2357.7627
# Epoch 58/150
# 536/536 [==============================] - 44s 82ms/step - loss: 330015.0312 - mae: 443.4510 - val_loss: 10168108.0000 - val_mae: 2403.0415
# Epoch 59/150
# 536/536 [==============================] - 43s 80ms/step - loss: 300440.3438 - mae: 428.8736 - val_loss: 10261738.0000 - val_mae: 2402.9875
# Epoch 60/150
# 536/536 [==============================] - 43s 80ms/step - loss: 307035.7812 - mae: 434.2319 - val_loss: 9998002.0000 - val_mae: 2345.0574
# Epoch 61/150
# 536/536 [==============================] - 44s 82ms/step - loss: 352123.0000 - mae: 451.5526 - val_loss: 10919261.0000 - val_mae: 2536.5076
# Epoch 62/150
# 536/536 [==============================] - 44s 82ms/step - loss: 350857.3750 - mae: 447.8933 - val_loss: 9745421.0000 - val_mae: 2490.0640
# Epoch 63/150
# 536/536 [==============================] - 43s 80ms/step - loss: 440265.6562 - mae: 496.9679 - val_loss: 9735776.0000 - val_mae: 2444.1833
# Epoch 64/150
# 536/536 [==============================] - 43s 79ms/step - loss: 323742.8750 - mae: 445.2474 - val_loss: 9531843.0000 - val_mae: 2423.1365
# Epoch 65/150
# 536/536 [==============================] - 44s 82ms/step - loss: 293313.5625 - mae: 420.8460 - val_loss: 9602996.0000 - val_mae: 2432.5713
# Epoch 66/150
# 536/536 [==============================] - 44s 81ms/step - loss: 284855.4375 - mae: 417.7725 - val_loss: 9582449.0000 - val_mae: 2454.6367
# Epoch 67/150
# 536/536 [==============================] - 43s 80ms/step - loss: 349201.1875 - mae: 449.1645 - val_loss: 8647372.0000 - val_mae: 2291.0850
# Epoch 68/150
# 536/536 [==============================] - 43s 80ms/step - loss: 407571.2188 - mae: 482.5851 - val_loss: 8390633.0000 - val_mae: 2330.0745
# Epoch 69/150
# 536/536 [==============================] - 43s 81ms/step - loss: 313016.4375 - mae: 440.7690 - val_loss: 8214876.0000 - val_mae: 2332.3279
# Epoch 70/150
# 536/536 [==============================] - 44s 82ms/step - loss: 414577.0625 - mae: 482.6125 - val_loss: 10550064.0000 - val_mae: 2624.6228

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
histEDLSTM = pd.DataFrame(history_ED_LSTM.history)
histEDLSTM['epoch'] = history_ED_LSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
fig = plot_learning_curves(histEDLSTM,modeltype,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# Load best model

# %%
model_best_ED_LSTM = keras.models.load_model(f"./{modeltype}/my_best_model_{namespace}.h5")
model_best_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 64)          23808
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 64)          256
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64)          256
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 64)          256
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 64)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 24, 64)            256
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 64)            4160
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 24, 64)            0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 24, 64)            256
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 24, 1)             65
# =================================================================
# Total params: 261,505
# Trainable params: 260,353
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
i=1
case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
Y_test_predictions = pd.Series(model_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
y_test_filtered = data_y_test0.loc[Y_test_predictions.index]
y_test_filtered = y_test_filtered.squeeze(axis=1)

# %%
eval_df = create_eval_df(Y_test_predictions,y_test_filtered)

# %%
fig = plot_accuracy(eval_df,modeltype,f"./{modeltype}/accuracy_{namespace}.png")

# %%
fig = plot_error_variations(eval_df,modeltype,f"./{modeltype}/error_variations_{namespace}.png")

# %%
abs_error_ED_LSTM = abs(Y_test_predictions - y_test_filtered)/y_test_filtered*100
np.average(abs_error_ED_LSTM)
# Out:
# 5.882906268033888

# %%
r2_test = r2_score(y_test_filtered, Y_test_predictions)
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.70

# %%
fig=plot_predictions(eval_df,1,modeltype,feature,f"./{modeltype}/predictions_{namespace}.png")

# %%
idx_prediction = pd.date_range(start=idx_test[0],freq='h',periods=len(idx_test)+24)
y_test_filtered2 = data_y_test0.loc[idx_prediction]

# %%
def make_twoweek_predictions(idx_test,data_y_test0,data_x_test):
    idx_prediction = pd.date_range(start=idx_test[0],freq='h',periods=len(idx_test)+24)
    y_test_filtered2 = data_y_test0.loc[idx_prediction]
    df_pred =pd.DataFrame(index=y_test_filtered2.index)
        
    for i in range(len(data_x_test)):
        case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
        date_range = pd.date_range(start=idx_test[i],freq='h',periods=24)
        Y_test_predictions = pd.Series(model_ED_LSTM.predict(case_test).flatten(),index=date_range)
        df_pred[f'pred_{i}'] = Y_test_predictions
        
    df_pred['mean'] = df_pred.mean(axis=1)
    df_pred['Actual'] = y_test_filtered2
    return df_pred

def calculate_r2_scores(df_pred):
    r2_list=[]
    for column in df_pred.columns:
        if column not in ['Actual','mean']:
            pred = df_pred[column].dropna()
            act = df_pred.loc[pred.index,'Actual']
            r2= r2_score(pred,act)
            r2_list.append(r2)
    return r2_list      
    
def plot_twoweek_predictions(df_pred,path,add_traces = False):
    mpl.rcParams['figure.figsize'] = [16, 8.0]
    fig,ax = plt.subplots(1)
    ax.plot(df_pred.index,df_pred['Actual'])
    ax.plot(df_pred.index,df_pred['mean'])
    if add_traces:
        for column in df_pred.columns:
            if column not in ['Actual','mean']:
                ax.plot(df_pred[column],'o')
    fig.savefig(path)
    return fig
    pass

# %%
df_pred = make_twoweek_predictions(idx_test=idx_test,data_y_test0=data_y_test0,data_x_test=data_x_test)
fig = plot_twoweek_predictions(df_pred,f'./{modeltype}/twoweek_predictions_{namespace}.png',add_traces=False)

# %%
r2 = calculate_r2_scores(df_pred)
plt.figure()
plt.plot(r2)

# %%
sum(r2)/len(r2)
# Out:
# 0.7459503545665219

# %%
r2_test = r2_score(y_test_filtered2[:-1],df_pred['mean'][:-1])
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.85

# %%
eval_df2 = create_eval_df(df_pred['mean'][:-1],y_test_filtered2[:-1])

# %%
fig = plot_accuracy(eval_df2,modeltype,f"./{modeltype}/accuracy3_{namespace}.png")

# %%
fig = plot_error_variations(eval_df2,modeltype,f"./{modeltype}/error_variations3_{namespace}.png")
