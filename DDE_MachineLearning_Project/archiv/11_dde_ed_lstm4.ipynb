# %%
import numpy as np
from datetime import timedelta
import pandas as pd
from pandas.plotting import lag_plot, autocorrelation_plot
from datetime import date

import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import matplotlib as mpl

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
import statsmodels.api as smw
from statsmodels.tsa.statespace.sarimax import SARIMAX

from scipy.signal import savgol_filter
import sklearn
from sklearn import preprocessing as pp
from sklearn.decomposition import PCA
from sklearn.svm import SVR
from sklearn.metrics import r2_score

import tensorflow as tf
from tensorflow import keras
from keras import optimizers, models, layers, regularizers
import keras_tuner as kt
tf.__version__
# Out:
# '2.6.0'

# %%
# %load_ext skip_kernel_extension

# %%
from utils.dde_preprocessing_utils import (set_timestamp_index,
remove_duplicates,
remove_columns,
extract_correlations,
prepare_data_sarimax,
create_test_train_split,
create_sarimax_test_train_split,
create_eval_df,
convert_to_sample_time_feature,
convert_from_differencing,
make_multiple_predictions,
calculate_r2_scores,
apply_differencing,
create_split,
apply_savgol_filter)
from utils.dde_plotting_utils import(
display_double_timestamps,
display_seasonal_decomposition,
plot_predictions,
plot_accuracy,
plot_error_variations,
plot_learning_curves,
plot_multiple_predictions,
plot_evaluation
)

# %%
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
mpl.rcParams['figure.figsize'] = [16.0, 8.0]
tf.random.set_seed(2022)

# %%
SKIP_RETRAIN_NN =True
SKIP_RETRAIN_RNN = True
SKIP_RETRAIN_LSTM = True
SKIP_RETRAIN_ED_LSTM = False

# %% [markdown]
# ## Loading Data

# %% [markdown]
# Benchmark data set

# %%
bench_df = pd.read_csv("energy_dataset.csv")
bench_df = set_timestamp_index(bench_df,"time")
bench_df = bench_df['price day ahead']
bench_df = bench_df.rename('Benchmark')

# %% [markdown]
# Base data set

# %%
base_df = pd.read_csv("extended_preprocessed_data3.csv")
base_df = set_timestamp_index(base_df,"Unnamed: 0")

# %%
base_df
# Out:
#                              temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 01:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 02:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 03:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 04:00:00+01:00  -3.464    1002.0        78         0.0        23
# ...                           ...       ...       ...         ...       ...
# 2018-12-31 19:00:00+01:00  12.490    1028.0        62         2.0       140
# 2018-12-31 20:00:00+01:00   9.990    1029.0        71         1.0       242
# 2018-12-31 21:00:00+01:00   8.510    1029.0        81         3.0       300
# 2018-12-31 22:00:00+01:00   6.990    1029.0        81         2.0       310
# 2018-12-31 23:00:00+01:00   5.990    1029.0        75         2.0       300
#
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               447.0
# 2015-01-01 01:00:00+01:00               449.0
# 2015-01-01 02:00:00+01:00               448.0
# 2015-01-01 03:00:00+01:00               438.0
# 2015-01-01 04:00:00+01:00               428.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               297.0
# 2018-12-31 20:00:00+01:00               296.0
# 2018-12-31 19:00:00+01:00        -1206.428571        -2611.190476     12   31
# 2018-12-31 20:00:00+01:00        -1499.761905        -3041.952381     12   31
# 2018-12-31 21:00:00+01:00        -1156.071429        -3647.690476     12   31
# 2018-12-31 22:00:00+01:00         -636.714286        -3831.904762     12   31
# 2018-12-31 23:00:00+01:00         -139.690476        -3193.761905     12   31
#
#                            weekend  hour
# 2015-01-01 00:00:00+01:00        0     0
# 2015-01-01 01:00:00+01:00        0     1
# 2015-01-01 02:00:00+01:00        0     2
# 2015-01-01 03:00:00+01:00        0     3
# 2015-01-01 04:00:00+01:00        0     4
# ...                            ...   ...
# 2018-12-31 19:00:00+01:00        0    19
# 2018-12-31 20:00:00+01:00        0    20
# 2018-12-31 21:00:00+01:00        0    21
# 2018-12-31 22:00:00+01:00        0    22
# 2018-12-31 23:00:00+01:00        0    23
#
# [35064 rows x 44 columns]

# %% [markdown]
# Apply Differencing

# %%
diff_df = apply_differencing(savgol_df,['month','day','weekend','hour'])
diff_df.index = diff_df.index.tz_convert('utc')
# diff_df = apply_savgol_filter(base_df,7,3,deriv=1,excluded=['month','day','weekend','hour'])

# %%
diff_df
# Out:
#                                temp  pressure   humidity    wind_speed  \
# 2015-01-01 00:00:00+00:00 -0.447857  0.238095   1.309524 -7.142857e-01
# 2015-01-01 01:00:00+00:00 -0.281786  0.357143   0.357143 -3.571429e-01
# 2015-01-01 02:00:00+00:00 -0.115714  0.476190  -0.595238 -1.443290e-15
# 2015-01-01 03:00:00+00:00  0.060429  0.714286  -1.857143  4.285714e-01
# 2015-01-01 04:00:00+00:00 -0.133238  0.476190  -2.428571  8.571429e-01
# ...                             ...       ...        ...           ...
# 2018-12-31 18:00:00+00:00 -3.331905  0.285714  15.666667 -2.380952e-01
# 2018-12-31 19:00:00+00:00 -2.857143  0.333333  13.190476 -1.904762e-01
# 2018-12-31 20:00:00+00:00 -1.795476  0.357143   7.500000  9.523810e-02
# 2018-12-31 21:00:00+00:00 -1.322857  0.142857   1.285714  7.142857e-02
# 2018-12-31 22:00:00+00:00 -1.020238 -0.238095  -6.428571 -1.190476e-01
#
#                              wind_deg  generation biomass  \
# 2015-01-01 00:00:00+00:00  -54.047619            4.238095
# 2015-01-01 01:00:00+00:00  -13.928571           -3.428571
# 2015-01-01 02:00:00+00:00   26.190476           -8.928571
# 2015-01-01 03:00:00+00:00   79.571429          -13.619048
# 2015-01-01 04:00:00+00:00  104.380952          -12.238095
# ...                               ...                 ...
# 2018-12-31 18:00:00+00:00   26.000000           -1.809524
# 2018-12-31 19:00:00+00:00   53.904762           -0.428571
# 2018-12-31 20:00:00+00:00   64.666667           -0.666667
# 2018-12-31 21:00:00+00:00   33.285714           -1.428571
# 2018-12-31 22:00:00+00:00  -29.761905           -2.690476
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+00:00                             13.047619
# 2015-01-01 01:00:00+00:00                            -30.928571
# 2015-01-01 02:00:00+00:00                            -53.404762
# 2015-01-01 03:00:00+00:00                            -46.095238
# 2018-12-31 19:00:00+00:00         -293.333333         -430.761905     12   31
# 2018-12-31 20:00:00+00:00          343.690476         -605.738095     12   31
# 2018-12-31 21:00:00+00:00          519.357143         -184.214286     12   31
# 2018-12-31 22:00:00+00:00          497.023810          638.142857     12   31
#
#                            weekend  hour
# 2015-01-01 00:00:00+00:00        0     1
# 2015-01-01 01:00:00+00:00        0     2
# 2015-01-01 02:00:00+00:00        0     3
# 2015-01-01 03:00:00+00:00        0     4
# 2015-01-01 04:00:00+00:00        0     5
# ...                            ...   ...
# 2018-12-31 18:00:00+00:00        0    19
# 2018-12-31 19:00:00+00:00        0    20
# 2018-12-31 20:00:00+00:00        0    21
# 2018-12-31 21:00:00+00:00        0    22
# 2018-12-31 22:00:00+00:00        0    23
#
# [35063 rows x 44 columns]

# %%
diff_df.index = diff_df.index.tz_convert('utc')
base_df.index = base_df.index.tz_convert('utc')
bench_df.index = bench_df.index.tz_convert('utc')

# %% [markdown]
# # Encode- Decoder + LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = diff_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.MinMaxScaler(feature_range=(-1,1),copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
train_start = '2015-01-01'
validation_start = '2018-10-01'
test_start = '2018-11-01'
test_end = '2018-12-01'
feature = 'price actual'
namespace= 'MS_EDLSTM_Price4'
modeltype = 'EDLSTM'

batch_size = 64
num_epochs = 40

feature_df = diff_df[[feature]]

data_x_train0, data_y_train0 = create_split(scaled_df,feature_df,train_start,validation_start)
data_x_val0, data_y_val0 = create_split(scaled_df,feature_df,validation_start,test_start)
data_x_test0, data_y_test0 = create_split(scaled_df,feature_df,test_start,test_end)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,24*14,24,batch_size)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,24*14,24,batch_size)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,24*14,24,batch_size)

# %%
print(data_x_train.shape,data_y_train.shape,idx_train.shape)
print(data_x_val.shape,data_y_val.shape,idx_val.shape)
print(data_x_test.shape,data_y_test.shape,idx_test.shape)
# Out:
# (32448, 336, 44) (32448, 24) (32448,)
# (320, 336, 44) (320, 24) (320,)
# (320, 336, 44) (320, 24) (320,)

# %% [markdown]
# Define LSTM Model

# %%
def build_model_ED_LSTM():
    n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
    model = models.Sequential()
    # Encoder
    model.add(layers.LSTM(64, return_sequences=True,input_shape=(None, n_features), stateful=False)) 
    model.add(layers.BatchNormalization())
    model.add(layers.LSTM(64, return_sequences=False, stateful=False)) 
    model.add(layers.BatchNormalization())  
    
    # Repeat Vector
    model.add(layers.RepeatVector(n_outputs))
    
    # Decoder
    model.add(layers.LSTM(64, return_sequences=True,stateful=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LSTM(64, return_sequences=True,stateful=False))
    model.add(layers.BatchNormalization())

    # End
    model.add(layers.TimeDistributed(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), kernel_initializer="he_normal")))
    model.add(layers.TimeDistributed(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), kernel_initializer="he_normal")))
    
    model.add(layers.TimeDistributed(layers.LeakyReLU(alpha=0.1)))                     
    model.add(layers.TimeDistributed(layers.BatchNormalization()))
    model.add(layers.TimeDistributed(layers.Dense(1)))                     
                
    model.compile(optimizer='Adam',loss='mse',metrics='mae') 
    return model

# %%
myCheckpointLSTM= keras.callbacks.ModelCheckpoint(f"./{modeltype}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingLSTM = keras.callbacks.EarlyStopping(patience=20,restore_best_weights=True)

# %%
initial_learning_rate = 0.001

decay = initial_learning_rate/num_epochs

def scheduler(epoch,lr):
    return lr*1/(1+decay*epoch)

myLearningRate_LSTM = keras.callbacks.LearningRateScheduler(scheduler, verbose=1)

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# model_ED_LSTM= build_model_ED_LSTM()
# history_ED_LSTM = model_ED_LSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) ,
#                                  callbacks=[myCheckpointLSTM,myEarly_stoppingLSTM,myLearningRate_LSTM])#
# Out:
# Epoch 1/40
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 507/507 [==============================] - 40s 64ms/step - loss: 6.4721 - mae: 1.8407 - val_loss: 5.3956 - val_mae: 1.7706
# Epoch 2/40
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0009999750481212483.
# 507/507 [==============================] - 32s 64ms/step - loss: 3.3394 - mae: 1.2929 - val_loss: 2.4115 - val_mae: 1.1514
# Epoch 3/40
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0009999250219521608.
# 507/507 [==============================] - 31s 61ms/step - loss: 2.5347 - mae: 1.1290 - val_loss: 2.1861 - val_mae: 1.0953
# Epoch 4/40
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0009998500872736493.
# 507/507 [==============================] - 30s 60ms/step - loss: 2.2623 - mae: 1.0674 - val_loss: 2.2882 - val_mae: 1.1372
# Epoch 5/40
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0009997501295499831.
# 507/507 [==============================] - 30s 60ms/step - loss: 2.1474 - mae: 1.0423 - val_loss: 2.1738 - val_mae: 1.1130
# Epoch 6/40
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0009996251506576568.
# 507/507 [==============================] - 31s 60ms/step - loss: 1.9724 - mae: 1.0021 - val_loss: 2.0695 - val_mae: 1.0899
# Epoch 7/40
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0009994752688708378.
# 507/507 [==============================] - 31s 61ms/step - loss: 1.8675 - mae: 0.9802 - val_loss: 2.0784 - val_mae: 1.0862
# Epoch 8/40
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009993003696619645.
# 507/507 [==============================] - 31s 61ms/step - loss: 1.7596 - mae: 0.9546 - val_loss: 1.9276 - val_mae: 1.0569
# Epoch 9/40
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0009991005712990117.
# 507/507 [==============================] - 32s 62ms/step - loss: 1.6433 - mae: 0.9261 - val_loss: 1.9237 - val_mae: 1.0688
# Epoch 10/40
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0009988758756489956.
# 507/507 [==============================] - 30s 60ms/step - loss: 1.5689 - mae: 0.9086 - val_loss: 1.7824 - val_mae: 1.0275
# Epoch 11/40
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0009986261681925203.
# 507/507 [==============================] - 29s 57ms/step - loss: 1.4544 - mae: 0.8781 - val_loss: 1.8199 - val_mae: 1.0420
# Epoch 12/40
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000998351567188273.
# 507/507 [==============================] - 31s 60ms/step - loss: 1.3951 - mae: 0.8630 - val_loss: 1.8334 - val_mae: 1.0335
# Epoch 13/40
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.000998052190883117.
# 507/507 [==============================] - 30s 59ms/step - loss: 1.3178 - mae: 0.8416 - val_loss: 1.9039 - val_mae: 1.0605
# Epoch 14/40
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.000997727924757097.
# 507/507 [==============================] - 30s 60ms/step - loss: 1.2353 - mae: 0.8176 - val_loss: 1.7713 - val_mae: 1.0127
# Epoch 15/40
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.000997378887050887.
# 507/507 [==============================] - 30s 60ms/step - loss: 1.2007 - mae: 0.8073 - val_loss: 1.8575 - val_mae: 1.0408
# Epoch 16/40
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0009970049632499773.
# 507/507 [==============================] - 31s 60ms/step - loss: 1.1525 - mae: 0.7925 - val_loss: 1.8239 - val_mae: 1.0344
# Epoch 17/40
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0009966062715888525.
# 507/507 [==============================] - 31s 60ms/step - loss: 1.0797 - mae: 0.7699 - val_loss: 2.0835 - val_mae: 1.0928
# Epoch 18/40
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0009961829302901793.
# 507/507 [==============================] - 30s 60ms/step - loss: 1.0394 - mae: 0.7566 - val_loss: 1.8274 - val_mae: 1.0301
# Epoch 19/40
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0009957348248388904.
# 507/507 [==============================] - 30s 59ms/step - loss: 1.0283 - mae: 0.7524 - val_loss: 1.7796 - val_mae: 1.0326
# Epoch 20/40
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0009952620734514667.
# 507/507 [==============================] - 31s 61ms/step - loss: 0.9564 - mae: 0.7286 - val_loss: 1.7945 - val_mae: 1.0214
# Epoch 21/40
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0009947646779754292.
# 507/507 [==============================] - 31s 62ms/step - loss: 0.9396 - mae: 0.7224 - val_loss: 1.8357 - val_mae: 1.0315
# Epoch 22/40
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0009942427566123507.
# 507/507 [==============================] - 30s 60ms/step - loss: 0.8915 - mae: 0.7048 - val_loss: 1.7504 - val_mae: 1.0220
# Epoch 23/40
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0009936961948493331.
# 507/507 [==============================] - 31s 61ms/step - loss: 0.8713 - mae: 0.6976 - val_loss: 1.7600 - val_mae: 1.0219
# Epoch 24/40
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0009931251108817659.
# 507/507 [==============================] - 30s 60ms/step - loss: 0.8368 - mae: 0.6836 - val_loss: 1.8813 - val_mae: 1.0421
# Epoch 25/40
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0009925296228932257.
# 507/507 [==============================] - 31s 61ms/step - loss: 0.8050 - mae: 0.6726 - val_loss: 1.7874 - val_mae: 1.0175
# Epoch 26/40
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0009919097327128713.
# 507/507 [==============================] - 30s 60ms/step - loss: 0.7752 - mae: 0.6602 - val_loss: 1.8868 - val_mae: 1.0520
# Epoch 27/40
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0009912654421696781.
# 507/507 [==============================] - 31s 61ms/step - loss: 0.7444 - mae: 0.6473 - val_loss: 1.9247 - val_mae: 1.0632
# Epoch 28/40
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.000990596753092439.
# 507/507 [==============================] - 30s 60ms/step - loss: 0.7331 - mae: 0.6418 - val_loss: 2.0596 - val_mae: 1.0946
# Epoch 29/40
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000989903783643652.
# 507/507 [==============================] - 31s 60ms/step - loss: 0.7079 - mae: 0.6324 - val_loss: 2.0107 - val_mae: 1.0784
# Epoch 30/40
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0009891866519740073.
# 507/507 [==============================] - 31s 60ms/step - loss: 0.6725 - mae: 0.6173 - val_loss: 2.0419 - val_mae: 1.0908
# Epoch 31/40
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.000988445359894314.
# 507/507 [==============================] - 31s 61ms/step - loss: 0.6824 - mae: 0.6211 - val_loss: 2.1134 - val_mae: 1.1025
# Epoch 32/40
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.000987679909215199.
# 507/507 [==============================] - 30s 59ms/step - loss: 0.6502 - mae: 0.6075 - val_loss: 2.0012 - val_mae: 1.0806
# Epoch 33/40
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.0009868904180693732.
# 507/507 [==============================] - 30s 60ms/step - loss: 0.6205 - mae: 0.5940 - val_loss: 1.9914 - val_mae: 1.0744
# Epoch 34/40
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.000986076888258385.
# 507/507 [==============================] - 30s 60ms/step - loss: 0.6172 - mae: 0.5921 - val_loss: 1.9839 - val_mae: 1.0658
# Epoch 35/40
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.0009852394379000567.
# 507/507 [==============================] - 29s 58ms/step - loss: 0.6074 - mae: 0.5874 - val_loss: 2.2415 - val_mae: 1.1295
# Epoch 36/40
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0009843780687868603.
# 507/507 [==============================] - 28s 56ms/step - loss: 0.5858 - mae: 0.5771 - val_loss: 1.9374 - val_mae: 1.0570
# Epoch 37/40
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0009834928990217317.
# 507/507 [==============================] - 32s 64ms/step - loss: 0.5686 - mae: 0.5689 - val_loss: 2.2846 - val_mae: 1.1414
# Epoch 38/40
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0009825840466958075.
# 507/507 [==============================] - 31s 61ms/step - loss: 0.5476 - mae: 0.5590 - val_loss: 1.9933 - val_mae: 1.0918
# Epoch 39/40
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0009816515135835939.
# 507/507 [==============================] - 32s 63ms/step - loss: 0.5461 - mae: 0.5577 - val_loss: 2.1006 - val_mae: 1.1040
# Epoch 40/40
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0009806953014594197.
# 507/507 [==============================] - 31s 62ms/step - loss: 0.5324 - mae: 0.5511 - val_loss: 2.1875 - val_mae: 1.1410

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# histEDLSTM = pd.DataFrame(history_ED_LSTM.history)
# histEDLSTM['epoch'] = history_ED_LSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
# fig = plot_learning_curves(histEDLSTM,modeltype,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# Load best model

# %%
model_best_ED_LSTM = keras.models.load_model(f"./{modeltype}/my_best_model_{namespace}.h5")
model_best_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 64)          27904
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 64)          256
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 64)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 24, 64)            256
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 64)            4160
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 24, 64)            4160
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 24, 64)            0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 24, 64)            256
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 24, 1)             65
# =================================================================
# Total params: 136,641
# Trainable params: 136,001
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# Evaluate differencing performance on validation data

# %%
i=0
case_val = data_x_val[i].reshape((1,data_x_val[0].shape[0], data_x_val[0].shape[1]))
Y_val_predictions_diff = pd.Series(model_best_ED_LSTM.predict(case_val).flatten(),index=pd.date_range(start=idx_val[i],freq='h',periods=24))
y_val_filtered_diff = data_y_val0.loc[Y_val_predictions_diff.index]
y_val_filtered_diff = y_val_filtered_diff.squeeze(axis=1)

# %%
eval_df_diff = create_eval_df(Y_val_predictions_diff,y_val_filtered_diff)

# %%
fig = plot_evaluation(eval_df_diff)
# Out:
# R^2 score is  0.83

# %%
df_pred_diff = make_multiple_predictions(model_best_ED_LSTM,idx_val,data_x_val,data_y_val0,feature,convert=False)

# %%
eval_df_diff = create_eval_df(df_pred_diff['mean'],df_pred_diff['Actual'])

# %%
fig = plot_evaluation(eval_df_diff)
# Out:
# R^2 score is  0.84

# %% [markdown]
# Reverting differencing on validation data

# %%
df_pred = make_multiple_predictions(model_best_ED_LSTM,idx_val,data_x_val,savgol_df,feature,convert=True)

# %%
eval_df = create_eval_df(df_pred['mean'],df_pred['Actual'])

# %%
fig = plot_evaluation(eval_df)
# Out:
# R^2 score is  0.83

# %%
r2 = calculate_r2_scores(df_pred)
plt.figure()
plt.plot(r2)

# %% [markdown]
# Evaluate differencing Performance on test data

# %%
i=0
case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
Y_test_predictions_diff = pd.Series(model_best_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
y_test_filtered_diff = data_y_test0.loc[Y_test_predictions_diff.index]
y_test_filtered_diff = y_test_filtered_diff.squeeze(axis=1)

# %%
eval_df_diff = create_eval_df(Y_test_predictions_diff,y_test_filtered_diff)

# %%
fig = plot_evaluation(eval_df_diff)
# Out:
# R^2 score is  0.86

# %%
df_pred_diff = make_multiple_predictions(model_best_ED_LSTM,idx_test,data_x_test,data_y_test0,feature,convert=False)

# %%
eval_df_diff = create_eval_df(df_pred_diff['mean'],df_pred_diff['Actual'])

# %%
fig = plot_evaluation(eval_df_diff)
# Out:
# R^2 score is  0.82

# %% [markdown]
# Reverting differencing on test data

# %%
df_pred = make_multiple_predictions(model_best_ED_LSTM,idx_test,data_x_test,savgol_df,feature,convert=True)

# %%
eval_df = create_eval_df(df_pred['mean'],df_pred['Actual'])

# %%
fig = plot_evaluation(eval_df)
# Out:
# R^2 score is  0.80

# %%
def calculate_metrics(df_pred):
    r2_list=[]
    mpe_list= []
    mae_list= []
    for column in df_pred.columns:
        if column not in ['Actual','mean']:
            pred = df_pred[column].dropna()
            act = df_pred.loc[pred.index,'Actual']
            r2= r2_score(pred,act)
            mpe = (act-pred)/act
        
            mae = sklearn.metrics.mean_absolute_error(act,pred)
            r2_list.append(r2)
            mpe_list.append(mpe.mean())
            mae_list.append(mae)
    return r2_list,mpe_list,mae_list      

def plot_metrics(df_pred):
    fig= plt.figure(figsize = (16,16))
    gs = fig.add_gridspec(3,1)
    r2_list,mpe_list,mae_list = calculate_metrics(df_pred)
    ax1 = fig.add_subplot(gs[0,0],)
    ax2 = fig.add_subplot(gs[1,0],sharex=ax1)
    ax3 = fig.add_subplot(gs[2,0],sharex=ax1)
    ax1.plot(r2_list)
    ax1.set_title('R2 Score')
    ax2.plot(mpe_list)
    ax2.set_title('RMSE')
    ax3.plot(mae_list)
    ax3.set_title('MAE')
    ax1.set_xticks(ticks=range(0,len(r2_list),24))
    return fig

# %%
fig = plot_metrics(df_pred)

# %%
eval_df
# Out:
#                            Prediction     Actual
# 2018-11-15 00:00:00+00:00   55.204391  56.630000
# 2018-11-15 01:00:00+00:00   52.373259  54.530476
# 2018-11-15 02:00:00+00:00   50.849077  52.900476
# 2018-11-15 03:00:00+00:00   52.330337  55.404286
# 2018-11-15 04:00:00+00:00   57.793342  59.702857
# ...                               ...        ...
# 2018-11-29 02:00:00+00:00   52.442015  50.097143
# 2018-11-29 03:00:00+00:00   52.635556  50.937143
# 2018-11-29 04:00:00+00:00   56.174093  54.822381
# 2018-11-29 05:00:00+00:00   61.900413  61.214762
# 2018-11-29 06:00:00+00:00   67.287329  67.415238
#
# [343 rows x 2 columns]

# %% [markdown]
# Comparing to Benchmark

# %%
def extend_eval_df_benchmark(eval_df,bench_df):
    bench_df=bench_df[eval_df.index]
    extended_eval_df = pd.concat([eval_df,bench_df],axis=1)
    return extended_eval_df

# %%
extended_eval_df = extend_eval_df_benchmark(eval_df,bench_df)
extended_eval_df
# Out:
#                            Prediction     Actual  Benchmark
# 2018-11-15 00:00:00+00:00   55.204391  56.630000      51.95
# 2018-11-15 01:00:00+00:00   52.373259  54.530476      51.27
# 2018-11-15 02:00:00+00:00   50.849077  52.900476      50.29
# 2018-11-15 03:00:00+00:00   52.330337  55.404286      51.03
# 2018-11-15 04:00:00+00:00   57.793342  59.702857      53.17
# ...                               ...        ...        ...
# 2018-11-29 02:00:00+00:00   52.442015  50.097143      47.00
# 2018-11-29 03:00:00+00:00   52.635556  50.937143      46.67
# 2018-11-29 04:00:00+00:00   56.174093  54.822381      49.64
# 2018-11-29 05:00:00+00:00   61.900413  61.214762      58.33
# 2018-11-29 06:00:00+00:00   67.287329  67.415238      65.24
#
# [343 rows x 3 columns]

# %%
r2_bench = r2_score(extended_eval_df['Actual'],extended_eval_df['Benchmark'],)
print('R^2 score is  %3.2f' %r2_bench)
# Out:
# R^2 score is  0.58

# %%
r2_test = r2_score(extended_eval_df['Actual'], extended_eval_df['Prediction'])
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.80

# %%
df_pred_24h = df_pred.iloc[:,0::24]
df_pred_24h['total'] = df_pred_24h.mean(axis=1)

# %%
fig = plt.figure(figsize=(16,8))
plt.plot(extended_eval_df['Actual'],label = 'Actual')
plt.plot(extended_eval_df['Prediction'], label= f'Prediction R^2 score: {round(r2_test,2)}')
plt.plot(extended_eval_df['Benchmark'], label = f'Benchmark R^2 score: {round(r2_bench,2)}')
plt.xlabel('Time Index')
plt.ylabel('Price')
plt.title('Averaged Prediction with 24h horizon for 14 days')
plt.legend()
# plt.xlim(idx_test[0],idx_test[0]+timedelta(hours=24*14-1))
