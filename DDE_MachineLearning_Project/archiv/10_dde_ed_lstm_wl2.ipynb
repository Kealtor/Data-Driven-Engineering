# %%
import numpy as np
import pandas as pd
from datetime import date
import plotly.express as px
import plotly.graph_objects as go
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing as pp
import matplotlib as mpl
from sklearn.decomposition import PCA
from pandas.plotting import lag_plot, autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf 
import statsmodels.api as smw
from datetime import timedelta
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.svm import SVR
from sklearn.metrics import r2_score
# ML Algorithms to be used
import tensorflow as tf
from tensorflow import keras
from keras import optimizers, models, layers, regularizers
tf.__version__
from utils.dde_preprocessing_utils import (set_timestamp_index,
remove_duplicates,
remove_columns,
extract_correlations,
prepare_data_sarimax,
create_test_train_split,
create_sarimax_test_train_split,
create_eval_df,
convert_to_sample_time_feature)
from utils.dde_plotting_utils import(
display_double_timestamps,
display_seasonal_decomposition,
plot_predictions,
plot_accuracy,
plot_error_variations,
plot_learning_curves,
)
# %load_ext skip_kernel_extension

# %%
import keras_tuner as kt

# %%
config = tf.compat.v1.ConfigProto(gpu_options=tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.8))
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
tf.compat.v1.keras.backend.set_session(session)
mpl.rcParams['figure.figsize'] = [8.0, 8.0]
tf.random.set_seed(2022)

# %%
SKIP_RETRAIN_NN =True
SKIP_RETRAIN_RNN = True
SKIP_RETRAIN_LSTM = True
SKIP_RETRAIN_ED_LSTM = False

# %% [markdown]
# ## Loading Data

# %%
combined_df = pd.read_csv("preprocessed_data.csv")
combined_df = set_timestamp_index(combined_df,"Unnamed: 0")

# %%
combined_df
# Out:
#                              temp  pressure  humidity  wind_speed  wind_deg  \
# 2015-01-01 00:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 01:00:00+01:00  -2.675    1001.0        77         1.0        62
# 2015-01-01 02:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 03:00:00+01:00  -3.464    1002.0        78         0.0        23
# 2015-01-01 04:00:00+01:00  -3.464    1002.0        78         0.0        23
# ...                           ...       ...       ...         ...       ...
# 2018-12-31 19:00:00+01:00  12.490    1028.0        62         2.0       140
# 2018-12-31 20:00:00+01:00   9.990    1029.0        71         1.0       242
# 2018-12-31 21:00:00+01:00   8.510    1029.0        81         3.0       300
# 2018-12-31 22:00:00+01:00   6.990    1029.0        81         2.0       310
# 2018-12-31 23:00:00+01:00   5.990    1029.0        75         2.0       300
#
#                            generation biomass  \
# 2015-01-01 00:00:00+01:00               447.0
# 2015-01-01 01:00:00+01:00               449.0
# 2015-01-01 02:00:00+01:00               448.0
# 2015-01-01 03:00:00+01:00               438.0
# 2015-01-01 04:00:00+01:00               428.0
# ...                                       ...
# 2018-12-31 19:00:00+01:00               297.0
# 2018-12-31 20:00:00+01:00               296.0
# 2018-12-31 21:00:00+01:00               292.0
# 2018-12-31 22:00:00+01:00               293.0
# 2018-12-31 23:00:00+01:00               290.0
#
#                            generation fossil brown coal/lignite  \
# 2015-01-01 00:00:00+01:00                                 329.0
# 2015-01-01 01:00:00+01:00                                 328.0
# 2015-01-01 02:00:00+01:00                                 323.0
# 2015-01-01 03:00:00+01:00                                 254.0
# 2015-01-01 04:00:00+01:00                                 187.0
# ...                                                         ...
# 2018-12-31 19:00:00+01:00                                   0.0
# 2018-12-31 20:00:00+01:00                                   0.0
# 2018-12-31 21:00:00+01:00                                   0.0
# 2018-12-31 22:00:00+01:00                                   0.0
# 2018-12-31 23:00:00+01:00                                   0.0
#
#                            generation fossil gas  generation fossil hard coal  \
# 2015-01-01 00:00:00+01:00                 4844.0                       4821.0
# 2015-01-01 01:00:00+01:00                 5196.0                       4755.0
# 2015-01-01 02:00:00+01:00                 4857.0                       4581.0
# 2015-01-01 03:00:00+01:00                 4314.0                       4131.0
# 2015-01-01 04:00:00+01:00                 4130.0                       3840.0
# ...                                          ...                          ...
# 2018-12-31 19:00:00+01:00                 7634.0                       2628.0
# 2018-12-31 20:00:00+01:00                 7241.0                       2566.0
# 2018-12-31 21:00:00+01:00                 7025.0                       2422.0
# 2018-12-31 22:00:00+01:00                 6562.0                       2293.0
# 2018-12-31 23:00:00+01:00                 6926.0                       2166.0
#
#                            generation fossil oil  ...  generation solar  \
# 2015-01-01 00:00:00+01:00                  162.0  ...              49.0
# 2015-01-01 01:00:00+01:00                  158.0  ...              50.0
# 2015-01-01 02:00:00+01:00                  157.0  ...              50.0
# 2015-01-01 03:00:00+01:00                  160.0  ...              50.0
# 2015-01-01 04:00:00+01:00                  156.0  ...              42.0
# ...                                          ...  ...               ...
# 2018-12-31 19:00:00+01:00                  178.0  ...              85.0
# 2018-12-31 20:00:00+01:00                  174.0  ...              33.0
# 2018-12-31 21:00:00+01:00                  168.0  ...              31.0
# 2018-12-31 22:00:00+01:00                  163.0  ...              31.0
# 2018-12-31 23:00:00+01:00                  163.0  ...              31.0
#
#                            generation waste  generation wind onshore  \
# 2015-01-01 00:00:00+01:00             196.0                   6378.0
# 2015-01-01 01:00:00+01:00             195.0                   5890.0
# 2015-01-01 02:00:00+01:00             196.0                   5461.0
# 2015-01-01 03:00:00+01:00             191.0                   5238.0
# 2015-01-01 04:00:00+01:00             189.0                   4935.0
# ...                                     ...                      ...
# 2018-12-31 19:00:00+01:00             277.0                   3113.0
# 2018-12-31 20:00:00+01:00             280.0                   3288.0
# 2018-12-31 21:00:00+01:00             286.0                   3503.0
# 2018-12-31 22:00:00+01:00             287.0                   3586.0
# 2018-12-31 23:00:00+01:00             287.0                   3651.0
#
#                            total load actual  price actual  generation  \
# 2015-01-01 00:00:00+01:00            25385.0         65.41     28251.0
# 2015-01-01 01:00:00+01:00            24382.0         64.92     27818.0
# 2015-01-01 02:00:00+01:00            22734.0         64.48     26796.0
# 2015-01-01 03:00:00+01:00            21286.0         59.32     25223.0
# 2015-01-01 04:00:00+01:00            20264.0         56.04     24620.0
# ...                                      ...           ...         ...
# 2018-12-31 19:00:00+01:00            30653.0         77.02     26415.0
# 2018-12-31 20:00:00+01:00            29735.0         76.16     25213.0
# 2018-12-31 21:00:00+01:00            28071.0         74.30     23987.0
# 2018-12-31 22:00:00+01:00            25801.0         69.89     22748.0
# 2018-12-31 23:00:00+01:00            24455.0         69.88     22605.0
#
#                            energy_difference  month  day  weekend
# 2015-01-01 00:00:00+01:00             2866.0      1    1        0
# 2015-01-01 01:00:00+01:00             3436.0      1    1        0
# 2015-01-01 02:00:00+01:00             4062.0      1    1        0
# 2015-01-01 03:00:00+01:00             3937.0      1    1        0
# 2015-01-01 04:00:00+01:00             4356.0      1    1        0
# ...                                      ...    ...  ...      ...
# 2018-12-31 19:00:00+01:00            -4238.0     12   31        0
# 2018-12-31 20:00:00+01:00            -4522.0     12   31        0
# 2018-12-31 21:00:00+01:00            -4084.0     12   31        0
# 2018-12-31 22:00:00+01:00            -3053.0     12   31        0
# 2018-12-31 23:00:00+01:00            -1850.0     12   31        0
#
# [35064 rows x 26 columns]

# %% [markdown]
# # Encode- Decoder + LSTM

# %% [markdown]
# Scale the input data

# %%
scaled_df = combined_df.copy(deep=True)
featuresToScale = scaled_df.columns
sX = pp.StandardScaler(copy=True)
scaled_df.loc[:,featuresToScale] = sX.fit_transform(scaled_df[featuresToScale])

# %% [markdown]
# Create Train Validation Test Split

# %%
train_start = '2015-01-01'
validation_start = '2017-01-01'
test_start = '2017-03-01'
test_end = '2017-03-28'
feature = 'total load actual'
namespace= 'MS_EDLSTM_WL2'
modeltype = 'EDLSTM'
feature_df = combined_df[[feature]]
data_x_train0,data_x_val0,data_x_test0,data_y_train0,data_y_val0,data_y_test0 = create_test_train_split(scaled_df,feature_df,train_start,test_start,test_end,validation_start=validation_start)

# %% [markdown]
# Convert to (sample,timestep,feature) format

# %%
data_x_train,data_y_train,idx_train = convert_to_sample_time_feature(data_x_train0,data_y_train0,24*14,24,32)
data_x_test,data_y_test,idx_test = convert_to_sample_time_feature(data_x_test0,data_y_test0,24*14,24,32)
data_x_val,data_y_val,idx_val = convert_to_sample_time_feature(data_x_val0,data_y_val0,24*14,24,32)

# %%
print(data_x_train.shape,data_y_train.shape)
print(data_x_val.shape,data_y_val.shape)
print(data_x_test.shape,data_y_test.shape)
# Out:
# (17152, 336, 26) (17152, 24)
# (1024, 336, 26) (1024, 24)
# (256, 336, 26) (256, 24)

# %% [markdown]
# Define LSTM Model

# %%
def build_model_ED_LSTM():
    n_timesteps, n_features, n_outputs = data_x_train.shape[1], data_x_train.shape[2], data_y_train.shape[1]
    model = models.Sequential()
    # Encoder
    model.add(layers.LSTM(64, return_sequences=True,input_shape=(None, n_features), stateful=False)) 
    model.add(layers.BatchNormalization())
    
    for i in range(2):
        model.add(layers.LSTM(64, return_sequences=True, stateful=False))
        model.add(layers.BatchNormalization())
      
    model.add(layers.LSTM(64, return_sequences=False, stateful=False)) 
    model.add(layers.BatchNormalization())  
    
    # Repeat Vector
    model.add(layers.RepeatVector(n_outputs))
    
    # Decoder
    model.add(layers.LSTM(64, return_sequences=True,stateful=False))
    model.add(layers.BatchNormalization())

    for i in range(2):
        model.add(layers.LSTM(64, return_sequences=True, stateful=False))
        model.add(layers.BatchNormalization())

    model.add(layers.LSTM(64, return_sequences=True,stateful=False))
    model.add(layers.BatchNormalization())

    # End
    model.add(layers.TimeDistributed(layers.Dense(64, kernel_regularizer=regularizers.l2(0.0001), kernel_initializer="he_normal")))
    
    model.add(layers.TimeDistributed(layers.LeakyReLU(alpha=0.1)))                     
    model.add(layers.TimeDistributed(layers.BatchNormalization()))
    model.add(layers.TimeDistributed(layers.Dense(1)))                     
                
    model.compile(optimizer='Adam',loss='mse',metrics='mae') 
    return model

# %%
myCheckpointLSTM= keras.callbacks.ModelCheckpoint(f"./{modeltype}/my_best_model_{namespace}.h5", save_best_only=True)
myEarly_stoppingLSTM = keras.callbacks.EarlyStopping(patience=20,restore_best_weights=True)

# %%
num_epochs = 150
batch_size = 32

# %%
model_ED_LSTM= build_model_ED_LSTM()
history_ED_LSTM = model_ED_LSTM.fit(data_x_train, data_y_train, epochs=num_epochs, batch_size=batch_size, validation_data=(data_x_val, data_y_val) , 
                                 callbacks=[myCheckpointLSTM,myEarly_stoppingLSTM])
# Out:
# Epoch 1/150
# 536/536 [==============================] - 50s 81ms/step - loss: 828814016.0000 - mae: 28432.5781 - val_loss: 930247360.0000 - val_mae: 30089.7715
# Epoch 2/150
# 536/536 [==============================] - 42s 78ms/step - loss: 822359040.0000 - mae: 28340.1699 - val_loss: 919607680.0000 - val_mae: 29944.8867
# Epoch 3/150
# 536/536 [==============================] - 42s 78ms/step - loss: 810349312.0000 - mae: 28165.7090 - val_loss: 900145536.0000 - val_mae: 29658.5645
# Epoch 4/150
# 536/536 [==============================] - 42s 78ms/step - loss: 794484160.0000 - mae: 27924.9531 - val_loss: 875893760.0000 - val_mae: 29288.1660
# Epoch 5/150
# 536/536 [==============================] - 42s 79ms/step - loss: 775506048.0000 - mae: 27627.6328 - val_loss: 840897152.0000 - val_mae: 28728.1328
# Epoch 6/150
# 536/536 [==============================] - 42s 79ms/step - loss: 753937728.0000 - mae: 27280.1270 - val_loss: 815209088.0000 - val_mae: 28321.6816
# Epoch 7/150
# 536/536 [==============================] - 42s 79ms/step - loss: 730307200.0000 - mae: 26887.0254 - val_loss: 777964288.0000 - val_mae: 27685.7598
# Epoch 8/150
# 536/536 [==============================] - 42s 79ms/step - loss: 704967360.0000 - mae: 26451.6641 - val_loss: 754236608.0000 - val_mae: 27285.1250
# Epoch 9/150
# 536/536 [==============================] - 41s 77ms/step - loss: 678330304.0000 - mae: 25976.0215 - val_loss: 696955392.0000 - val_mae: 26253.8887
# Epoch 10/150
# 536/536 [==============================] - 41s 77ms/step - loss: 650608768.0000 - mae: 25462.6855 - val_loss: 680743232.0000 - val_mae: 25947.0195
# Epoch 11/150
# 536/536 [==============================] - 42s 79ms/step - loss: 621909760.0000 - mae: 24912.5840 - val_loss: 626330432.0000 - val_mae: 24895.4375
# Epoch 12/150
# 536/536 [==============================] - 42s 79ms/step - loss: 592567872.0000 - mae: 24326.3203 - val_loss: 588862528.0000 - val_mae: 24112.6309
# Epoch 13/150
# 536/536 [==============================] - 41s 77ms/step - loss: 562558400.0000 - mae: 23704.4629 - val_loss: 566455872.0000 - val_mae: 23642.5547
# Epoch 14/150
# 536/536 [==============================] - 42s 77ms/step - loss: 531950464.0000 - mae: 23047.0703 - val_loss: 533223200.0000 - val_mae: 22959.6562
# Epoch 15/150
# 536/536 [==============================] - 42s 79ms/step - loss: 500167680.0000 - mae: 22351.3066 - val_loss: 506836032.0000 - val_mae: 22362.2070
# Epoch 16/150
# 536/536 [==============================] - 42s 78ms/step - loss: 468022464.0000 - mae: 21620.6426 - val_loss: 460969408.0000 - val_mae: 21320.6484
# Epoch 17/150
# 536/536 [==============================] - 42s 78ms/step - loss: 435596736.0000 - mae: 20857.1113 - val_loss: 436127168.0000 - val_mae: 20687.0801
# Epoch 18/150
# 536/536 [==============================] - 41s 77ms/step - loss: 402987392.0000 - mae: 20060.7949 - val_loss: 395032672.0000 - val_mae: 19683.5879
# Epoch 19/150
# 536/536 [==============================] - 42s 79ms/step - loss: 370482528.0000 - mae: 19233.7363 - val_loss: 367490432.0000 - val_mae: 18974.8848
# Epoch 20/150
# 536/536 [==============================] - 42s 79ms/step - loss: 338294016.0000 - mae: 18377.6973 - val_loss: 333065792.0000 - val_mae: 18041.3379
# Epoch 21/150
# 536/536 [==============================] - 42s 79ms/step - loss: 306581696.0000 - mae: 17492.7090 - val_loss: 305039104.0000 - val_mae: 17269.2656
# Epoch 22/150
# 536/536 [==============================] - 42s 79ms/step - loss: 275461664.0000 - mae: 16580.5391 - val_loss: 269128608.0000 - val_mae: 16190.5723
# Epoch 23/150
# 536/536 [==============================] - 41s 77ms/step - loss: 245284048.0000 - mae: 15643.6992 - val_loss: 241268576.0000 - val_mae: 15333.7412
# Epoch 24/150
# 536/536 [==============================] - 41s 77ms/step - loss: 216221968.0000 - mae: 14682.1748 - val_loss: 214984880.0000 - val_mae: 14389.5332
# Epoch 25/150
# 536/536 [==============================] - 42s 78ms/step - loss: 188290992.0000 - mae: 13699.3047 - val_loss: 189249536.0000 - val_mae: 13493.9307
# Epoch 26/150
# 536/536 [==============================] - 42s 78ms/step - loss: 161743152.0000 - mae: 12697.8652 - val_loss: 156004656.0000 - val_mae: 12201.6748
# Epoch 27/150
# 536/536 [==============================] - 43s 81ms/step - loss: 136909888.0000 - mae: 11677.7139 - val_loss: 134894880.0000 - val_mae: 11277.8730
# Epoch 28/150
# 536/536 [==============================] - 43s 80ms/step - loss: 113911520.0000 - mae: 10646.0059 - val_loss: 111944000.0000 - val_mae: 10224.0840
# Epoch 29/150
# 536/536 [==============================] - 43s 80ms/step - loss: 92779952.0000 - mae: 9606.8506 - val_loss: 95772696.0000 - val_mae: 9435.1289
# Epoch 30/150
# 536/536 [==============================] - 43s 80ms/step - loss: 73892768.0000 - mae: 8561.6611 - val_loss: 78263688.0000 - val_mae: 8464.7969
# Epoch 31/150
# 536/536 [==============================] - 43s 80ms/step - loss: 57011156.0000 - mae: 7517.2554 - val_loss: 59079984.0000 - val_mae: 7256.0864
# Epoch 32/150
# 536/536 [==============================] - 44s 82ms/step - loss: 42522588.0000 - mae: 6484.5244 - val_loss: 46940472.0000 - val_mae: 6279.0239
# Epoch 33/150
# 536/536 [==============================] - 44s 82ms/step - loss: 30407214.0000 - mae: 5468.8281 - val_loss: 36338148.0000 - val_mae: 5365.2979
# Epoch 34/150
# 536/536 [==============================] - 43s 81ms/step - loss: 20544568.0000 - mae: 4486.7354 - val_loss: 28509904.0000 - val_mae: 4590.9248
# Epoch 35/150
# 536/536 [==============================] - 43s 81ms/step - loss: 13016291.0000 - mae: 3547.6409 - val_loss: 20595706.0000 - val_mae: 3751.9441
# Epoch 36/150
# 536/536 [==============================] - 44s 82ms/step - loss: 7565608.0000 - mae: 2680.8506 - val_loss: 13405017.0000 - val_mae: 2942.4590
# Epoch 37/150
# 536/536 [==============================] - 43s 81ms/step - loss: 4211188.0000 - mae: 1908.5557 - val_loss: 10000862.0000 - val_mae: 2422.2800
# Epoch 38/150
# 536/536 [==============================] - 44s 81ms/step - loss: 1904159.0000 - mae: 1249.3397 - val_loss: 8629206.0000 - val_mae: 2052.9927
# Epoch 39/150
# 536/536 [==============================] - 43s 81ms/step - loss: 972139.3125 - mae: 810.2827 - val_loss: 6577547.5000 - val_mae: 1845.1040
# Epoch 40/150
# 536/536 [==============================] - 43s 81ms/step - loss: 453945.8750 - mae: 531.1868 - val_loss: 6722731.0000 - val_mae: 1795.4425
# Epoch 41/150
# 536/536 [==============================] - 44s 82ms/step - loss: 366762.5938 - mae: 468.7441 - val_loss: 7167466.0000 - val_mae: 1860.0560
# Epoch 42/150
# 536/536 [==============================] - 43s 81ms/step - loss: 395905.8438 - mae: 476.1941 - val_loss: 6028585.0000 - val_mae: 1729.1587
# Epoch 43/150
# 536/536 [==============================] - 43s 80ms/step - loss: 402950.0938 - mae: 484.3223 - val_loss: 5828184.5000 - val_mae: 1737.2208
# Epoch 44/150
# 536/536 [==============================] - 46s 85ms/step - loss: 382825.4688 - mae: 470.8980 - val_loss: 6302113.0000 - val_mae: 1777.1279
# Epoch 45/150
# 536/536 [==============================] - 46s 86ms/step - loss: 536094.4375 - mae: 534.9368 - val_loss: 6919536.0000 - val_mae: 1821.2651
# Epoch 46/150
# 536/536 [==============================] - 45s 83ms/step - loss: 368339.0000 - mae: 458.8493 - val_loss: 6985342.0000 - val_mae: 1851.7061
# Epoch 47/150
# 536/536 [==============================] - 45s 83ms/step - loss: 318493.5625 - mae: 434.8486 - val_loss: 6751221.5000 - val_mae: 1812.4534
# Epoch 48/150
# 536/536 [==============================] - 44s 83ms/step - loss: 345277.0312 - mae: 449.3776 - val_loss: 7179466.5000 - val_mae: 1838.8246
# Epoch 49/150
# 536/536 [==============================] - 45s 83ms/step - loss: 370822.4375 - mae: 469.5947 - val_loss: 6766568.5000 - val_mae: 1789.7067
# Epoch 50/150
# 536/536 [==============================] - 42s 79ms/step - loss: 416950.8750 - mae: 489.3050 - val_loss: 9101450.0000 - val_mae: 2065.1548
# Epoch 51/150
# 536/536 [==============================] - 44s 82ms/step - loss: 478677.2812 - mae: 508.7356 - val_loss: 6988042.5000 - val_mae: 1761.6218
# Epoch 52/150
# 536/536 [==============================] - 42s 79ms/step - loss: 317769.9062 - mae: 432.5587 - val_loss: 7229889.0000 - val_mae: 1788.4003
# Epoch 53/150
# 536/536 [==============================] - 43s 81ms/step - loss: 309334.6250 - mae: 432.6107 - val_loss: 7376914.5000 - val_mae: 1810.2893
# Epoch 54/150
# 536/536 [==============================] - 43s 80ms/step - loss: 378945.7188 - mae: 464.0648 - val_loss: 8126491.0000 - val_mae: 1938.3201
# Epoch 55/150
# 536/536 [==============================] - 43s 81ms/step - loss: 406764.9688 - mae: 485.4544 - val_loss: 6265558.5000 - val_mae: 1693.2810
# Epoch 56/150
# 536/536 [==============================] - 42s 79ms/step - loss: 319810.0938 - mae: 436.0726 - val_loss: 6106545.0000 - val_mae: 1690.1783
# Epoch 57/150
# 536/536 [==============================] - 43s 80ms/step - loss: 358702.2500 - mae: 460.7893 - val_loss: 7834195.0000 - val_mae: 1918.9460
# Epoch 58/150
# 536/536 [==============================] - 43s 80ms/step - loss: 352654.5625 - mae: 457.3465 - val_loss: 5997012.0000 - val_mae: 1724.5704
# Epoch 59/150
# 536/536 [==============================] - 43s 80ms/step - loss: 322991.9375 - mae: 441.3474 - val_loss: 5370169.5000 - val_mae: 1601.7933
# Epoch 60/150
# 536/536 [==============================] - 43s 81ms/step - loss: 323142.2188 - mae: 442.5251 - val_loss: 5801177.0000 - val_mae: 1705.7695
# Epoch 61/150
# 536/536 [==============================] - 43s 80ms/step - loss: 463261.0312 - mae: 504.7303 - val_loss: 6759717.5000 - val_mae: 1846.8853
# Epoch 62/150
# 536/536 [==============================] - 43s 80ms/step - loss: 324708.1250 - mae: 440.4456 - val_loss: 6468470.0000 - val_mae: 1754.8596
# Epoch 63/150
# 536/536 [==============================] - 43s 81ms/step - loss: 320956.4062 - mae: 441.8521 - val_loss: 6339115.0000 - val_mae: 1699.0708
# Epoch 64/150
# 536/536 [==============================] - 44s 81ms/step - loss: 307848.3125 - mae: 438.7098 - val_loss: 6375948.0000 - val_mae: 1705.0247
# Epoch 65/150
# 536/536 [==============================] - 43s 80ms/step - loss: 387051.0000 - mae: 468.9059 - val_loss: 6863344.5000 - val_mae: 1763.2177
# Epoch 66/150
# 536/536 [==============================] - 42s 79ms/step - loss: 312922.3125 - mae: 431.6596 - val_loss: 6753700.0000 - val_mae: 1742.1414
# Epoch 67/150
# 536/536 [==============================] - 43s 80ms/step - loss: 358052.9688 - mae: 454.3945 - val_loss: 6756106.5000 - val_mae: 1801.5715
# Epoch 68/150
# 536/536 [==============================] - 42s 79ms/step - loss: 313336.9688 - mae: 436.3482 - val_loss: 6581873.0000 - val_mae: 1723.6553
# Epoch 69/150
# 536/536 [==============================] - 44s 82ms/step - loss: 318219.7812 - mae: 442.4832 - val_loss: 7229227.5000 - val_mae: 1855.1150
# Epoch 70/150
# 536/536 [==============================] - 42s 79ms/step - loss: 400727.1875 - mae: 474.0582 - val_loss: 7656828.0000 - val_mae: 1831.8632
# Epoch 71/150
# 536/536 [==============================] - 43s 79ms/step - loss: 394515.5000 - mae: 481.8260 - val_loss: 6252520.5000 - val_mae: 1722.3872
# Epoch 72/150
# 536/536 [==============================] - 43s 80ms/step - loss: 309804.4062 - mae: 433.8634 - val_loss: 6528111.5000 - val_mae: 1761.8242
# Epoch 73/150
# 536/536 [==============================] - 43s 80ms/step - loss: 298008.6562 - mae: 421.7209 - val_loss: 6655624.5000 - val_mae: 1800.5391
# Epoch 74/150
# 536/536 [==============================] - 43s 81ms/step - loss: 343232.0625 - mae: 449.5667 - val_loss: 6937998.0000 - val_mae: 1833.7214
# Epoch 75/150
# 536/536 [==============================] - 43s 81ms/step - loss: 292407.5625 - mae: 427.3702 - val_loss: 6865229.0000 - val_mae: 1825.8571
# Epoch 76/150
# 536/536 [==============================] - 44s 81ms/step - loss: 319509.0000 - mae: 444.4488 - val_loss: 6939215.0000 - val_mae: 1843.6482
# Epoch 77/150
# 536/536 [==============================] - 43s 80ms/step - loss: 443033.0000 - mae: 489.6982 - val_loss: 8220911.5000 - val_mae: 2223.1943
# Epoch 78/150
# 536/536 [==============================] - 43s 80ms/step - loss: 428110.5000 - mae: 495.1224 - val_loss: 5796768.5000 - val_mae: 1710.6089
# Epoch 79/150
# 536/536 [==============================] - 43s 79ms/step - loss: 370736.2188 - mae: 464.0876 - val_loss: 5718534.5000 - val_mae: 1691.3027

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
histEDLSTM = pd.DataFrame(history_ED_LSTM.history)
histEDLSTM['epoch'] = history_ED_LSTM.epoch

# %%
# %%skip $SKIP_RETRAIN_ED_LSTM
fig = plot_learning_curves(histEDLSTM,modeltype,f"./{modeltype}/learningcurve_{namespace}.png")

# %% [markdown]
# Load best model

# %%
model_best_ED_LSTM = keras.models.load_model(f"./{modeltype}/my_best_model_{namespace}.h5")
model_best_ED_LSTM.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, None, 64)          23296
# _________________________________________________________________
# batch_normalization (BatchNo (None, None, 64)          256
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# batch_normalization_1 (Batch (None, None, 64)          256
# _________________________________________________________________
# lstm_2 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 64)          256
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 24, 64)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 24, 64)            256
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 24, 64)            33024
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 24, 64)            256
# _________________________________________________________________
# time_distributed (TimeDistri (None, 24, 64)            4160
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 24, 64)            0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 24, 64)            256
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 24, 1)             65
# =================================================================
# Total params: 260,993
# Trainable params: 259,841
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
i=1
case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
Y_test_predictions = pd.Series(model_ED_LSTM.predict(case_test).flatten(),index=pd.date_range(start=idx_test[i],freq='h',periods=24))
y_test_filtered = data_y_test0.loc[Y_test_predictions.index]
y_test_filtered = y_test_filtered.squeeze(axis=1)

# %%
eval_df = create_eval_df(Y_test_predictions,y_test_filtered)

# %%
fig = plot_accuracy(eval_df,modeltype,f"./{modeltype}/accuracy_{namespace}.png")

# %%
fig = plot_error_variations(eval_df,modeltype,f"./{modeltype}/error_variations_{namespace}.png")

# %%
abs_error_ED_LSTM = abs(Y_test_predictions - y_test_filtered)/y_test_filtered*100
np.average(abs_error_ED_LSTM)
# Out:
# 4.892648386736151

# %%
r2_test = r2_score(y_test_filtered, Y_test_predictions)
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.82

# %%
fig=plot_predictions(eval_df,1,modeltype,feature,f"./{modeltype}/predictions_{namespace}.png")

# %%
idx_prediction = pd.date_range(start=idx_test[0],freq='h',periods=len(idx_test)+24)
y_test_filtered2 = data_y_test0.loc[idx_prediction]

# %%
def make_twoweek_predictions(idx_test,data_y_test0,data_x_test):
    idx_prediction = pd.date_range(start=idx_test[0],freq='h',periods=len(idx_test)+24)
    y_test_filtered2 = data_y_test0.loc[idx_prediction]
    df_pred =pd.DataFrame(index=y_test_filtered2.index)
        
    for i in range(len(data_x_test)):
        case_test = data_x_test[i].reshape((1,data_x_test[0].shape[0], data_x_test[0].shape[1]))
        date_range = pd.date_range(start=idx_test[i],freq='h',periods=24)
        Y_test_predictions = pd.Series(model_ED_LSTM.predict(case_test).flatten(),index=date_range)
        df_pred[f'pred_{i}'] = Y_test_predictions
        
    df_pred['mean'] = df_pred.mean(axis=1)
    df_pred['Actual'] = y_test_filtered2
    return df_pred

def calculate_r2_scores(df_pred):
    r2_list=[]
    for column in df_pred.columns:
        if column not in ['Actual','mean']:
            pred = df_pred[column].dropna()
            act = df_pred.loc[pred.index,'Actual']
            r2= r2_score(pred,act)
            r2_list.append(r2)
    return r2_list      
    
def plot_twoweek_predictions(df_pred,path,add_traces = False):
    mpl.rcParams['figure.figsize'] = [16, 8.0]
    fig,ax = plt.subplots(1)
    ax.plot(df_pred.index,df_pred['Actual'])
    ax.plot(df_pred.index,df_pred['mean'])
    if add_traces:
        for column in df_pred.columns:
            if column not in ['Actual','mean']:
                ax.plot(df_pred[column],'o')
    fig.savefig(path)
    return fig
    pass

# %%
df_pred = make_twoweek_predictions(idx_test=idx_test,data_y_test0=data_y_test0,data_x_test=data_x_test)
fig = plot_twoweek_predictions(df_pred,f'./{modeltype}/twoweek_predictions_{namespace}.png',add_traces=False)

# %%
r2 = calculate_r2_scores(df_pred)
plt.figure()
plt.plot(r2)

# %%
r2_test = r2_score(y_test_filtered2[:-1],df_pred['mean'][:-1])
print('R^2 score is  %3.2f' %r2_test)
# Out:
# R^2 score is  0.83

# %%
eval_df2 = create_eval_df(df_pred['mean'][:-1],y_test_filtered2[:-1])

# %%
fig = plot_accuracy(eval_df2,modeltype,f"./{modeltype}/accuracy3_{namespace}.png")

# %%
fig = plot_error_variations(eval_df2,modeltype,f"./{modeltype}/error_variations3_{namespace}.png")
